# %% [markdown]
# # setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import pickle
import json

# %% [markdown]
# # 78k scholar

# %% [markdown]
# # process

# %%
from process import *

# %%
scholar_search = ScholarSearch()

# %%
scholar_search.reviewer_profile.keys()
# Out:
# dict_keys(['~Prasad_Tadepalli3', '~Shikui_Tu1', '~Alberto_Castellini1', '~Zhiao_Huang1', '~Alessandra_Russo1', '~Anthony_Hunter1', '~Peter_Flach1', '~Wannes_Meert1', '~Lu_Cheng2', '~Yue_Zhang7', "~Claudia_d'Amato1", '~Giorgio_Corani1', '~Badong_Chen1', '~Luigi_Gresele1', '~Thomas_Krak1', '~William_Herlands1', '~Shuang_Li3', '~Loizos_Michael1', '~Esra_Erdem1', '~Zhe_Zeng1', '~Heiner_Stuckenschmidt2', '~Linbo_Liu1', '~Yuliya_Shapovalova1', '~Gherardo_Varando1', '~Roger_Baker_Grosse1', '~David_Bindel1', '~Maria_Lomeli2', '~Nico_Piatkowski1', '~Lili_Mou1', '~Taro_Watanabe1', '~Bo_Pang4', '~Kevin_Small1', '~Paulius_Dilkas1', '~Aurélie_Beynier2', '~Leonard_Henckel1', '~Salvatore_Ruggieri1', '~Santtu_Henrik_Tikka1', '~Sofia_Triantafillou2', '~Yuexia_Zhang1', '~Bryan_Andrews1', '~Kristian_Kersting1', '~Jussi_Rintanen1', '~David_Benjamin_Belanger1', '~Wen_Dong1', '~Jiajun_Zhang1', '~YIPING_SONG1', '~Benito_van_der_Zander1', '~Rohit_Bhattacharya1', '~Razieh_Nabi1', '~Sebastian_M_Schmon1', '~Ge
# ...

# %%
scholar_search.reviewer_profile['~KunHong_Liu1']
# Out:
# {'profile': {'id': '~KunHong_Liu1',
#   'number': None,
#   'tcdate': 1646448060201,
#   'tmdate': 1646448351255,
#   'referent': None,
#   'packaging': None,
#   'invitation': '~/-/profiles',
#   'readers': ['OpenReview.net', '~KunHong_Liu1'],
#   'nonreaders': None,
#   'signatures': ['~KunHong_Liu1'],
#   'writers': ['OpenReview.net'],
#   'content': {'preferredEmail': 'lkhqz@xmu.edu.cn',
#    'gender': 'Male',
#    'homepage': 'https://cdmc.xmu.edu.cn/info/1010/1055.htm',
#    'dblp': 'https://dblp.uni-trier.de/pid/147/8501-1.html',
#    'emails': ['lkhqz@xmu.edu.cn'],
#    'names': [{'first': 'KunHong',
#      'middle': '',
#      'last': 'Liu',
#      'preferred': True,
#      'username': '~KunHong_Liu1'}],
#    'history': [{'position': 'Full Professor',
#      'start': 2018,
#      'end': None,
#      'institution': {'domain': 'xmu.edu.cn', 'name': 'Xiamen University'}},
#     {'position': 'PhD student',
#      'start': 2005,
#      'end': 2008,
# ...

# %%
tmp = {
        "profile": {
            "id": "~jianguo_Li1",
            "tcdate": 1538125166532,
            "tmdate": 1622028231391,
            "invitation": "~/-/profiles",
            "readers": [
                "OpenReview.net",
                "~jianguo_Li1"
            ],
            "signatures": [
                "~jianguo_Li1"
            ],
            "writers": [
                "OpenReview.net"
            ],
            "content": {
                "preferredEmail": "jglee@outlook.com",
                "gender": "Male",
                "gscholar": "https://scholar.google.com/citations?user=n44GlFcAAAAJ&hl=en",
                "dblp": "https://dblp.org/pid/70/6237",
                "homepage": "https://sites.google.com/site/leeplus/",
                "emails": [
                    "jianguo.li@intel.com",
                    "jglee@outlook.com",
                    "lijg.zero@antgroup.com"
                ],
                "names": [
                    {
                        "first": "jianguo",
                        "middle": "",
                        "last": "Li",
                        "username": "~jianguo_Li1",
                    },
                    {
                        "first": "Jianguo",
                        "middle": "",
                        "last": "Li",
                        "username": "~Jianguo_Li2",
                    }
                ],
                "history": [
                    {
                        "position": "Director",
                        "start": 2020,
                        "institution": {
                            "domain": "antgroup.com",
                            "name": "Ant Group"
                        }
                    },
                    {
                        "position": "Senior Staff Research Scientist",
                        "start": 2006,
                        "end": 2020,
                        "institution": {
                            "domain": "intel.com",
                            "name": "Intel Labs"
                        }
                    },
                    {
                        "position": "PhD student",
                        "start": 2001,
                        "end": 2006,
                        "institution": {
                            "domain": "tsinghua.edu.cn",
                            "name": "Tsinghua University"
                        }
                    }
                ],
                "expertise": [
                    {
                        "keywords": [
                            "deep learning"
                        ],
                        "start": 2014,
                    },
                    {
                        "keywords": [
                            "computer vision"
                        ],
                        "start": 2005,
                    },
                    {
                        "keywords": [
                            "machine learning"
                        ],
                        "start": 2001,
                    }
                ],
                "relations": [
                    {
                        "name": "Mingjie Sun",
                        "email": "mingjies@cs.cmu.edu",
                        "relation": "Coauthor",
                        "start": 2019,
                        "readers": [
                            "everyone"
                        ]
                    },
                    {
                        "name": "Weiyao Lin",
                        "email": "wylin@sjtu.edu.cn",
                        "relation": "Coauthor",
                        "start": 2018,
                        "readers": [
                            "everyone"
                        ]
                    },
                    {
                        "name": "Tianhong Li",
                        "email": "tianhong@csail.mit.edu",
                        "relation": "Coauthor",
                        "start": 2018,
                        "readers": [
                            "everyone"
                        ]
                    },
                    {
                        "name": "Zhuang Liu",
                        "email": "zhuangl@berkeley.edu",
                        "relation": "Coauthor",
                        "start": 2017,
                        "readers": [
                            "everyone"
                        ]
                    },
                    {
                        "name": "Yinpeng Dong",
                        "email": "dongyinpeng@gmail.com",
                        "relation": "Coauthor",
                        "start": 2017,
                        "readers": [
                            "everyone"
                        ]
                    },
                    {
                        "name": "Jun Zhu",
                        "email": "dcszj@mail.tsinghua.edu.cn",
                        "relation": "Coauthor",
                        "start": 2017,
                        "readers": [
                            "everyone"
                        ]
                    },
                    {
                        "name": "Hang Su",
                        "email": "suhangss@mail.tsinghua.edu.cn",
                        "relation": "Coauthor",
                        "start": 2017,
                        "readers": [
                            "everyone"
                        ]
                    },
                    {
                        "name": "Yu-gang Jiang",
                        "email": "ygj@fudan.edu.cn",
                        "relation": "Coauthor",
                        "start": 2014,
                        "readers": [
                            "everyone"
                        ]
                    },
                    {
                        "name": "Changshui Zhang",
                        "email": "zcs@mail.tsinghua.edu.cn",
                        "relation": "Advisor",
                        "start": 2001,
                        "readers": [
                            "everyone"
                        ]
                    },
                    {
                        "name": "Tianyu Pang",
                        "email": "pty17@mails.tsinghua.edu.cn",
                        "relation": "Coauthor",
                        "start": 2018,
                        "end": 2019,
                        "readers": [
                            "everyone"
                        ]
                    },
                    {
                        "name": "Gao Huang",
                        "email": "gaohuang@tsinghua.edu.cn",
                        "relation": "Coauthor",
                        "start": 2017,
                        "end": 2018,
                        "readers": [
                            "everyone"
                        ]
                    },
                    {
                        "name": "Chen Zhu",
                        "email": "chenzhu@cs.umd.edu",
                        "relation": "Coauthor",
                        "start": 2016,
                        "end": 2018,
                        "readers": [
                            "everyone"
                        ]
                    },
                    {
                        "name": "Jingdong Wang",
                        "email": "jingdw@microsoft.com",
                        "relation": "Coauthor",
                        "start": 2003,
                        "end": 2017,
                        "readers": [
                            "everyone"
                        ]
                    },
                    {
                        "name": "Yurong Chen",
                        "email": "yurong.chen@intel.com",
                        "relation": "Coauthor",
                        "start": 2011,
                        "end": 2016,
                        "readers": [
                            "everyone"
                        ]
                    },
                    {
                        "name": "Jianfei Cai",
                        "email": "asjfcai@ntu.edu.sg",
                        "relation": "Coauthor",
                        "start": 2011,
                        "end": 2014,
                        "readers": [
                            "everyone"
                        ]
                    },
                    {
                        "name": "Haizhou Ai",
                        "email": "ahz@mail.tsinghua.edu.cn",
                        "relation": "Coauthor",
                        "start": 2008,
                        "end": 2010,
                        "readers": [
                            "everyone"
                        ]
                    }
                ],
            },
            "metaContent": {
                "preferredEmail": {
                    "signatures": [
                        "~Zhou_Dawei1"
                    ]
                },
                "gender": {
                    "signatures": [
                        "~Zhou_Dawei1"
                    ]
                },
                "homepage": {
                    "signatures": [
                        "~Zhou_Dawei1"
                    ]
                },
                "dblp": {
                    "signatures": [
                        "~Zhou_Dawei1"
                    ]
                },
                "emails": [
                    {
                        "signatures": [
                            "~Zhou_Dawei1"
                        ]
                    }
                ],
                "names": [
                    {
                        "signatures": [
                            "~Zhou_Dawei1"
                        ]
                    },
                    {
                        "signatures": [
                            "~Zhou_Dawei1"
                        ]
                    }
                ],
                "history": [
                    {
                        "signatures": [
                            "~Zhou_Dawei1"
                        ]
                    },
                    {
                        "signatures": [
                            "~Zhou_Dawei1"
                        ]
                    },
                    {
                        "signatures": [
                            "~Zhou_Dawei1"
                        ]
                    }
                ]
            },
            "tauthor": "OpenReview.net"
        },
        "papers": [
            {
                "id": "ndtLe66Saq6",
                "number": 9563,
                "cdate": 1649643443088,
                "mdate": 1649643443088,
                "tcdate": 1649643443088,
                "tmdate": 1649643443088,
                "content": {
                    "title": "Towards Defending against Adversarial Examples via Attack-Invariant Features",
                    "authorids": [
                        "~Dawei_Zhou3",
                        "~Tongliang_Liu1",
                        "~Bo_Han1",
                        "~Nannan_Wang1",
                        "~Chunlei_Peng1",
                        "~Xinbo_Gao5"
                    ],
                    "authors": [
                        "Dawei Zhou",
                        "Tongliang Liu",
                        "Bo Han",
                        "Nannan Wang",
                        "Chunlei Peng",
                        "Xinbo Gao"
                    ],
                    "abstract": "Deep neural networks (DNNs) are vulnerable to\nadversarial noise. Their adversarial robustness\ncan be improved by exploiting adversarial exam\u0002ples. However, given the continuously evolving at\u0002tacks, models trained on seen types of adversarial\nexamples generally cannot generalize well to un\u0002seen types of adversarial examples. To solve this\nproblem, in this paper, we propose to remove ad\u0002versarial noise by learning generalizable invariant\nfeatures across attacks which maintain semantic\nclassification information. Specifically, we intro\u0002duce an adversarial feature learning mechanism\nto disentangle invariant features from adversarial\nnoise. A normalization term has been proposed in\nthe encoded space of the attack-invariant features\nto address the bias issue between the seen and\nunseen types of attacks. Empirical evaluations\ndemonstrate that our method could provide better\nprotection in comparison to previous state-of-the\u0002art approaches, especially against unseen types of\nattacks and adaptive attacks",
                    "pdf": "/pdf/04814901c81eaaeff4cd357c1486d2bd3bbeddb3.pdf",
                    "paperhash": "zhou|towards_defending_against_adversarial_examples_via_attackinvariant_features"
                },
                "forum": "ndtLe66Saq6",
                "invitation": "OpenReview.net/Archive/-/Direct_Upload",
                "readers": [
                    "everyone"
                ],
                "nonreaders": [],
                "signatures": [
                    "~Nannan_Wang1"
                ],
                "writers": [
                    "~Nannan_Wang1"
                ]
            },
            
        ]
    }

# %%
_ = scholar_search.get_scholar(query=tmp, simple=True, top_n=3)
# Out:
# [Info] In total 1 scholar is found:
# [
#   {
#     "academic": false,
#     "academic_age": 20.0,
#     "academic_lifespan": 19.0,
#     "cit_sum_before_year": {
#       "2008": 44,
#       "2009": 117,
#       "2010": 192,
#       "2011": 259,
#       "2012": 330,
#       "2013": 419,
#       "2014": 516,
#       "2015": 657,
#       "2016": 803,
#       "2017": 997,
#       "2018": 1417,
#       "2019": 2291,
#       "2020": 3647,
#       "2021": 5302
#     },
#     "citation_table": [
#       "5797",
#       "29"
#     ],
#     "domain_labels": [
#       "machine_learning",
#       "deep_learning",
#       "computer_vision",
#       "data_mining"
#     ],
#     "gender": "M",
#     "gs_sid": "n44GlFcAAAAJ",
#     "organization": "Director, Ant Group",
#     "organization_code": null,
#     "paper_num": 100,
#     "cites": {
#       "years": [
#         "2008",
#         "2009",
#         "2010",
#         "2011",
#         "2012",
#         "2013",
#         "2014",
# ...

# %%
scholar_search.search_78k.df.loc[scholar_search.search_78k.df['name'] == 'Jianguo Li']
# Out:
#        academic  academic_age  academic_lifespan  \
# 73040     False          20.0               19.0
#
#                                      cit_sum_before_year citation_table  \
# 73040  {'2008': 44, '2009': 117, '2010': 192, '2011':...     [5797, 29]
#
#                                            domain_labels gender        gs_sid  \
# 73040  [machine_learning, deep_learning, computer_vis...      M  n44GlFcAAAAJ
#
#               organization organization_code  ...  co_authors        name  \
# 73040  Director, Ant Group              None  ...        None  Jianguo Li
#
#                                                   papers  \
# 73040  [[https://scholar.google.com/citations?view_op...
#
#                                                      url top_num_coauthors  \
# 73040  https://scholar.google.com/citations?hl=en&use...               NaN
#
#       num_domain  top_topic_diversity  \
# 73040        4.0                  NaN
#
# ...

# %%
df = pd.DataFrame.from_records(np.load('source/gs_scholars.npy', allow_pickle=True))

# %%
df_all = pd.DataFrame.from_records(np.load('source/gs_scholars_all_upd.npy', allow_pickle=True))

# %%
for idx, row in df.iterrows():
    df_all.at[idx, 'citation_table'] = [row['citations_table'][0], row['citations_table'][2]]

# %%
np.save('source/gs_scholars_all_upd.npy', df_all.to_dict('records'), allow_pickle=True)

# %%
df['name'].head(10)
# Out:
# 0               Theresa Swift
# 1       George Andrei Mihaila
# 2                      Ben He
# 3                   Shizhu He
# 4              Nguyen Le Minh
# 5                Baobao CHANG
# 6              Doug Beeferman
# 7                Mark Yatskar
# 8    William A Baumgartner Jr
# 9           Monojit Choudhury
# Name: name, dtype: object

# %%
'Theresa Swift' in df['name'].values
# Out:
# True

# %%
name_list = ['Zhijing', 'Jin']
name_list_df = df_all.loc[df_all['name'].str.contains(pat = f'^{name_list[0].capitalize()}.*{name_list[-1].capitalize()}$', regex=True, case=False)].copy()
name_list_df
# Out:
#       academic  academic_age  academic_lifespan  \
# 2020      True           5.0                5.0
#
#                          cit_sum_before_year citation_table  \
# 2020  {'2019': 16, '2020': 159, '2021': 488}       [591, 8]
#
#                                           domain_labels gender        gs_sid  \
# 2020  [natural_language_processing, causal_inference...      -  RkI8h-wAAAAJ
#
#                            organization organization_code  ...  \
# 2020  Max Planck Institute & ETH Zürich              None  ...
#
#                                              co_authors         name  \
# 2020  [[https://scholar.google.com/citations?user=x5...  Zhijing Jin
#
#                                                  papers  \
# 2020  [[https://scholar.google.com/citations?view_op...
#
#                                                     url top_num_coauthors  \
# 2020  https://scholar.google.com/citations?hl=en&use...              16.0
#
#      num_domain  top_topic_diversity  \
# ...

# %%
'Artificial Intelligence'.strip().lower().replace(' ', '_')
# Out:
# [autoreload of process failed: Traceback (most recent call last):
#   File "/home/ljrjerry/miniconda3/envs/env37/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/ljrjerry/miniconda3/envs/env37/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/ljrjerry/miniconda3/envs/env37/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/home/ljrjerry/miniconda3/envs/env37/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
#   File "<frozen importlib._bootstrap_external>", line 791, in source_to_code
# ...

# %%
name_list_df.to_dict(orient='records')
# Out:
# [{'academic': True,
#   'academic_age': 5.0,
#   'academic_lifespan': 5.0,
#   'cit_sum_before_year': {'2019': 16, '2020': 159, '2021': 488},
#   'citation_table': ['591', '8'],
#   'domain_labels': ['natural_language_processing',
#    'causal_inference',
#    'machine_learning',
#    'computational_social_science',
#    'artificial_intelligence'],
#   'gender': '-',
#   'gs_sid': 'RkI8h-wAAAAJ',
#   'organization': 'Max Planck Institute & ETH Zürich',
#   'organization_code': None,
#   'paper_num': 27,
#   'cites': {'years': ['2019', '2020', '2021', '2022'],
#    'cites': ['16', '143', '329', '103']},
#   'co_authors': [['https://scholar.google.com/citations?user=x5QTK9YAAAAJ&hl=en',
#     'Di Jin',
#     'Applied Scientist of Amazon Alexa AI',
#     'Verified email at mit.edu'],
#    ['https://scholar.google.com/citations?user=1LuGqFQAAAAJ&hl=en',
#     'Peter Szolovits',
#     'Professor of Computer Science and Engineering, MIT',
#     'Verified email at mit.edu'],
# ...

# %%
tmp = [1,2,3,4,5]
for i in tmp:
    i = 6
tmp
# Out:
# [1, 2, 3, 4, 5]

# %%
df_tmp = df.loc[df['name'].str.contains('zhiJing', case=False)]

# %%
df_tmp
# Out:
#                                                      url  \
# 2020   https://scholar.google.com/citations?hl=en&use...
# 28265  https://scholar.google.com/citations?hl=en&use...
#
#                                               co_authors  \
# 2020   [[https://scholar.google.com/citations?user=x5...
# 28265  [[https://scholar.google.com/citations?user=Xr...
#
#               citations_table  \
# 2020   [591, 591, 8, 8, 8, 8]
# 28265  [227, 208, 8, 8, 8, 8]
#
#                                                    cites         name  \
# 2020   {'years': ['2019', '2020', '2021', '2022'], 'c...  Zhijing Jin
# 28265  {'years': ['2015', '2016', '2017', '2018', '20...   Zhijing Li
#
#                                               extra_info  \
# 2020   [Max Planck Institute &amp; ETH Zürich, Verifi...
# 28265  [Facebook, Verified email at cs.ucsb.edu - <a ...
#
#                                                   papers
# 2020   [[https://scholar.google.com/citations?view_op...
# ...

# %%
tmp = df_tmp.loc[:, df_tmp.columns != 'papers']

# %%
tmp_dict = tmp.to_dict(orient='records')

# %%
type(tmp_dict)
# Out:
# list

# %%
tmp_dict[0]
# Out:
# {'url': 'https://scholar.google.com/citations?hl=en&user=ZKuRZaEAAAAJ',
#  'co_authors': [['https://scholar.google.com/citations?user=ocmAN4YAAAAJ&hl=en',
#    'Emine Yilmaz',
#    'University College London',
#    'Verified email at ucl.ac.uk'],
#   ['https://scholar.google.com/citations?user=fyHjfEgAAAAJ&hl=en',
#    'Aldo Lipani',
#    'Assistant Professor at UCL',
#    'Verified email at ucl.ac.uk'],
#   ['https://scholar.google.com/citations?user=5jJKFVcAAAAJ&hl=en',
#    'Zaiqiao Meng',
#    'University of Cambridge, University of Glasgow, Sun Yat-sen University',
#    'Verified email at cam.ac.uk'],
#   ['https://scholar.google.com/citations?user=5AnhSDQAAAAJ&hl=en',
#    'Rui Luo',
#    'PhD student, University College London',
#    'Verified email at cs.ucl.ac.uk'],
#   ['https://scholar.google.com/citations?user=LOWJnPsAAAAJ&hl=en',
#    'Jinyuan Fang',
#    'Sun Yat-sen University',
#    'Verified email at mail2.sysu.edu.cn'],
# ...

# %%
import requests

# %%
response = requests.get("https://openreview.net/profile?id=~Rachel_K._E._Bellamy1")

# %%
not response.ok
# Out:
# False

# %%
'Dsfds_Sdfsd_asds'.upper()
# Out:
# 'DSFDS_SDFSD_ASDS'

# %%
from bs4 import BeautifulSoup

# %%
resp_str = response.content.decode('utf-8')

# %%
soup = BeautifulSoup(resp_str, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1" name="viewport"/><meta content="Promoting openness in scientific communication and the peer-review process" name="description"/><link href="/favicon.ico" rel="icon"/><meta content="OpenReview" property="og:title"/><meta content="" property="og:description"/><meta content="https://openreview.net/images/openreview_logo_512.png" property="og:image"/><meta content="website" property="og:type"/><meta content="OpenReview" property="og:site_name"/><meta content="summary" name="twitter:card"/><meta content="@openreviewnet" name="twitter:site"/><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-108703919-1"></script><script>window.dataLayer = window.dataLayer || [];
# function gtag() { dataLayer.push(arguments); }
# gtag('js', new Date());
# gtag('config', 'UA-108703919-1', {
#   page_path: window.location.pathname + window.location.search,
# ...

# %%
tmp = json.loads(soup.find_all('script', id="__NEXT_DATA__")[0].string)

# %%
tmp
# Out:
# {'props': {'pageProps': {'profile': {'names': [{'first': 'Rachel',
#       'middle': 'K. E.',
#       'last': 'Bellamy',
#       'username': '~Rachel_K._E._Bellamy1',
#       'altUsernames': []}],
#     'emails': [],
#     'links': [{'name': 'DBLP',
#       'key': 'dblp',
#       'url': 'https://dblp.org/pid/33/3184',
#       'meta': None}],
#     'relations': [],
#     'id': '~Rachel_K._E._Bellamy1',
#     'preferredId': '~Rachel_K._E._Bellamy1',
#     'preferredName': 'Rachel K. E. Bellamy',
#     'currentInstitution': None},
#    'publicProfile': True}},
#  'page': '/profile',
#  'query': {'id': '~Rachel_K._E._Bellamy1'},
#  'buildId': 'v1.5.0-1-g2b07894',
#  'isFallback': False,
#  'gip': True,
#  'scriptLoader': []}

# %%
json.loads(soup.find_all('script', id="__NEXT_DATA__")[0].string)
# Out:
# {'props': {'pageProps': {'profile': {'names': [{'first': 'Jiarui',
#       'middle': '',
#       'last': 'Gan',
#       'username': '~Jiarui_Gan1',
#       'preferred': True,
#       'altUsernames': []}],
#     'emails': [{'email': '****@gmail.com',
#       'confirmed': True,
#       'preferred': True}],
#     'links': [{'name': 'Homepage',
#       'key': 'homepage',
#       'url': 'http://jgan.neocities.org',
#       'meta': None},
#      {'name': 'Google Scholar',
#       'key': 'gscholar',
#       'url': 'https://scholar.google.com/citations?user=25GYJiwAAAAJ&hl=en',
#       'meta': None},
#      {'name': 'DBLP',
#       'key': 'dblp',
#       'url': 'https://dblp.org/pid/133/1975',
#       'meta': None}],
#     'history': [{'position': 'Postdoc',
#       'start': 2021,
#       'end': None,
#       'institution': {'domain': 'mpi-sws.org', 'name': 'MPI-SWS'}},
#      {'position': 'PhD student',
#       'start': 2016,
#       'end': 2021,
# ...

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1" name="viewport"/><meta content="Promoting openness in scientific communication and the peer-review process" name="description"/><link href="/favicon.ico" rel="icon"/><meta content="OpenReview" property="og:title"/><meta content="" property="og:description"/><meta content="https://openreview.net/images/openreview_logo_512.png" property="og:image"/><meta content="website" property="og:type"/><meta content="OpenReview" property="og:site_name"/><meta content="summary" name="twitter:card"/><meta content="@openreviewnet" name="twitter:site"/><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-108703919-1"></script><script>window.dataLayer = window.dataLayer || [];
# function gtag() { dataLayer.push(arguments); }
# gtag('js', new Date());
# gtag('config', 'UA-108703919-1', {
#   page_path: window.location.pathname + window.location.search,
# ...

# %%
soup.title.string
# Out:
# 'Jiarui Gan | OpenReview'
