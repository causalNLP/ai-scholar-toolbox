# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import pickle
import json

# %%
from process import *

# %%
scholar_search = ScholarSearch()
# Out:
# 644

# %%
83/644
# Out:
# 0.12888198757763975

# %%
resp_list = []
for id in scholar_search.openreview_profile.keys():
    resp = scholar_search.get_scholar(query=id, simple=True, top_n=3, print_true=True)
    resp_list.append(resp)
# Out:
# [Info] In total 1 scholar is found:
# [
#   {
#     "academic": false,
#     "academic_age": 9.0,
#     "academic_lifespan": 9.0,
#     "cit_sum_before_year": {
#       "2015": 4,
#       "2016": 12,
#       "2017": 25,
#       "2018": 96,
#       "2019": 259,
#       "2020": 585,
#       "2021": 981
#     },
#     "citation_table": [
#       "1064",
#       "14"
#     ],
#     "domain_labels": [
#       "optimization",
#       "machine_learning"
#     ],
#     "gender": "-",
#     "gs_sid": "DeFL5Q8AAAAJ",
#     "organization": "Research Staff Member at IBM Research, Thomas J. Watson Research Center; PI of MIT-IBM Watson AI Lab",
#     "organization_code": null,
#     "paper_num": 56,
#     "cites": {
#       "years": [
#         "2015",
#         "2016",
#         "2017",
#         "2018",
#         "2019",
#         "2020",
#         "2021",
#         "2022"
#       ],
#       "cites": [
#         "4",
#         "8",
#         "13",
#         "71",
#         "163",
# ...

# %%
cnt = 0
for resp in resp_list:
    if len(resp) != 0:
        cnt += 1

# %%
cnt
# Out:
# 353

# %%
scholar_search.cnt_find_gs_78k, scholar_search.cnt_find_gs_crawl
# Out:
# (270, 174)

# %%
scholar_gs = ScholarGsSearch()

# %%
total_list = scholar_search.openreview_profile.keys()

# %%
scholar_gs.get_scholar(total_list)

# %%
import requests
_AUTHSEARCH = 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors={0}'
# _AUTHSEARCH.format(requests.utils.quote('Marty Banks, Berkeley'))

# %%
url_list = []
for key in total_list:
    url_item = []
    name = change_name(key)
    if 'gscholar' in total_list[key]['profile']['content']['gscholar']:
        
    position, school = None, None
    if 'position' in total_list[key]['profile']['content']['history'][0]:
        position = total_list[key]['profile']['content']['history'][0]['position']
    if ('institution' in total_list[key]['profile']['content']['history'][0] and 
        'name' in total_list[key]['profile']['content']['history'][0]['institution']):
        school = total_list[key]['profile']['content']['history'][0]['institution']['name']
    url_item.append('authsearch')
    url_item.append(_AUTHSEARCH.format(requests.utils.quote(name)))
    url_list.append()

# %%
import json
import requests
from bs4 import BeautifulSoup

# %%
with open('tmp/url_list.json', 'w') as file:
    json.dump(url_list, file, indent=2)

# %%
'https://scholar.google.com/citations?hl=en&user={0}'.format('what')
# Out:
# 'https://scholar.google.com/citations?hl=en&user=what'

# %%
res = BeautifulSoup('https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=Marty%20Banks%2C%20Berkeley', 'html.parser')
# Out:
# /home/ljrjerry/miniconda3/envs/env37/lib/python3.7/site-packages/bs4/__init__.py:408: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning

# %%
response = requests.get('https://scholar.google.com/citations?user=RkI8h-wAAAAJ&hl=en')
resp_str = response.content.decode('utf-8', errors='ignore')
soup = BeautifulSoup(resp_str, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
def get_signle_author(element):
            li=[]
            li.append(element.find_elements_by_tag_name("a")[0].get_attribute('href'))
            li.append(element.find_elements_by_tag_name("a")[0].get_attribute('textContent'))
            for i in element.find_elements_by_class_name("gsc_rsb_a_ext"):
                li.append(i.get_attribute('textContent'))
            return li

# %%
qwq = soup.find_all(class_='gsc_g_hist_wrp')
if (len(qwq)==0):
    pass
else:
    idx_list = qwq[0].find_all(class_="gsc_md_hist_b")[0]
    years =  [i.text for i in idx_list.find_all(class_="gsc_g_t")] # str
    cites =  [i.text for i in idx_list.find_all(class_="gsc_g_al")] # str
    rsb = soup.find_all(class_="gsc_rsb")[0]
    Citations_table=[i.text for i in rsb.find_all(class_="gsc_rsb_std")]
    Co_authors = rsb.find_all(class_="gsc_rsb_a")
    if len(Co_authors) == 0:
        Co_authors = None
    else:
        Co_authors = [i for i in rsb.find_all(class_="gsc_rsb_a")[0].find_all(class_="gsc_rsb_a_desc")]

# %%
sgs = ScholarGsSearch()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# /tmp/ipykernel_2436017/1027640411.py in <module>
# ----> 1 sgs = ScholarGsSearch()
#
# /home/public/twitter_politics/openreview/process.py in __init__(self)
#     411 class ScholarGsSearch():
#     412     def __init__(self):
# --> 413         self.setup()
#     414
#     415     def setup(self):
#
# /home/public/twitter_politics/openreview/process.py in setup(self)
#     421         options.add_experimental_option('useAutomationExtension', False)
#     422
# --> 423         self.driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
#     424
#     425         # 修改 webdriver 值
#
# ~/miniconda3/envs/env37/lib/python3.7/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
# ...

# %%
sgs.search_gsid('RkI8h-wAAAAJ')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# /tmp/ipykernel_2436017/697642173.py in <module>
# ----> 1 sgs.search_gsid('RkI8h-wAAAAJ')
#
# /home/public/twitter_politics/openreview/process.py in search_gsid(self, gs_id)
#     446         # resp_str = resp.content.decode('utf-8', errors='ignore')
#     447         # soup = BeautifulSoup(resp_str, 'html.parser')
# --> 448         driver = webdriver.Chrome('../chromedriver')
#     449         driver.get(url)
#     450         scholar_dict = self._search_gsid_helper(driver, url)
#
# ~/miniconda3/envs/env37/lib/python3.7/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      70                          port, options,
#      71                          service_args, desired_capabilities,
# ...
