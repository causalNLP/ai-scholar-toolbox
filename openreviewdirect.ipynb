# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import pickle
import json

# %%
from process import *

# %%
scholar_search = ScholarSearch()
# Out:
# 644

# %%
scholar_search.search_78k.df
# Out:
#        academic  academic_age  academic_lifespan  \
# 0         False          31.0               28.0
# 1         False          27.0               24.0
# 2          True          20.0               19.0
# 3          True          10.0               10.0
# 4          True          21.0               21.0
# ...         ...           ...                ...
# 78061      True           5.0                4.0
# 78062      True          12.0               12.0
# 78063      True          10.0                9.0
# 78064     False          44.0               43.0
# 78065      True           9.0                8.0
#
#                                      cit_sum_before_year citation_table  \
# 0      {'1994': 39, '1995': 86, '1996': 187, '1997': ...     [3563, 27]
# 1      {'1996': 10, '1997': 58, '1998': 203, '1999': ...     [3524, 30]
# 2      {'2004': 15, '2005': 64, '2006': 146, '2007': ...     [3508, 29]
# 3      {'2014': 14, '2015': 45, '2016': 172, '2017': ...     [3858, 23]
# ...

# %%
scholar_search.search_78k.df.columns
# Out:
# Index(['academic', 'academic_age', 'academic_lifespan', 'cit_sum_before_year',
#        'citation_table', 'domain_labels', 'gender', 'gs_sid', 'organization',
#        'organization_code', 'paper_num', 'cites', 'co_authors', 'name', 'url',
#        'top_num_coauthors', 'num_domain', 'top_topic_diversity',
#        'co_authors_all', 'num_coauthors_all_wwo_ai', 'organization_top'],
#       dtype='object')

# %%
for idx, row in scholar_search.search_78k.df.iterrows():
    dl = row['domain_labels']
    new_dl = []
    for dl_item in dl:
        new_dl.append(dl_item.replace('_', ' '))
    scholar_search.search_78k.df.at[idx, 'domain_labels'] = new_dl

# %%
df_dict = scholar_search.search_78k.df.to_dict(orient='records')
np.save('source/gs_wo_papers.npy', df_dict)

# %%
pd.set_option('display.max_columns', 500)

# %%
with open('review_data/test.json', 'r') as file:
    tmp_dict = json.load(file)

# %%
{'academic': True, 'academic_age': 19.0, 'academic_lifespan': 18.0, 'cit_sum_before_year': {'2005': 15, '2006': 40, '2007': 81, '2008': 114, '2009': 158, '2010': 205, '2011': 295, '2012': 422, '2013': 527, '2014': 689, '2015': 882, '2016': 1090, '2017': 1291, '2018': 1487, '2019': 1651, '2020': 1851, '2021': 2043}, 'citation_table': ['2082', '26'], 'domain_labels': ['artificial_intelligence', 'graphical_models', 'machine_learning', 'probabilistic_inference', 'statistical_relational_learning'], 'gender': 'M', 'gs_sid': 'pm_dg3cAAAAJ', 'organization': 'The University of Texas at Dallas', 'organization_code': '6037664147916511730', 'paper_num': 100, 'cites': {'years': ['2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], 'cites': ['15', '25', '41', '33', '44', '47', '90', '127', '105', '162', '193', '208', '201', '196', '164', '200', '192', '20']}, 'co_authors': [['https://scholar.google.com/citations?user=PI_3bqEAAAAJ&hl=en', 'Rina Dechter', 'University of California, Irvine', 'Verified email at ics.uci.edu'], ['https://scholar.google.com/citations?user=VDBfmocAAAAJ&hl=en', 'Tahrima Rahman', 'Postdoctoral Research Associate, University of Texas at Dallas', 'Verified email at utdallas.edu'], ['https://scholar.google.com/citations?user=KOrhfVMAAAAJ&hl=en', 'Pedro Domingos', 'Professor of Computer Science and Engineering, University of Washington', 'Verified email at cs.washington.edu'], ['https://scholar.google.com/citations?user=V49BsgMAAAAJ&hl=en', 'Parag Singla', 'Indian Institute of Technology Delhi', 'Verified email at cse.iitd.ac.in'], ['https://scholar.google.com/citations?user=ZrJWmUoAAAAJ&hl=en', 'Somdeb Sarkhel', 'Research Scientist', 'Verified email at adobe.com'], ['https://scholar.google.com/citations?user=UYz4aqIAAAAJ&hl=en', 'Robert Mateescu', 'Western Digital Research', 'Verified email at caltech.edu'], ['https://scholar.google.com/citations?user=sOzdfjYAAAAJ&hl=en', 'Alexandra Meliou', 'University of Massachusetts, Amherst', 'Verified email at cs.umass.edu'], ['https://scholar.google.com/citations?user=SIxd6jgAAAAJ&hl=en', 'Dan Suciu', 'University of Washington', 'Verified email at cs.washington.edu']], 'name': 'Vibhav Gogate', 'url': 'https://scholar.google.com/citations?hl=en&user=pm_dg3cAAAAJ', 'top_num_coauthors': 8.0, 'num_domain': 5.0, 'top_topic_diversity': 11.0, 'num_coauthors_all_wwo_ai': 85, 'organization_top': 0.0}
# Out:
# {'academic': True,
#  'academic_age': 19.0,
#  'academic_lifespan': 18.0,
#  'cit_sum_before_year': {'2005': 15,
#   '2006': 40,
#   '2007': 81,
#   '2008': 114,
#   '2009': 158,
#   '2010': 205,
#   '2011': 295,
#   '2012': 422,
#   '2013': 527,
#   '2014': 689,
#   '2015': 882,
#   '2016': 1090,
#   '2017': 1291,
#   '2018': 1487,
#   '2019': 1651,
#   '2020': 1851,
#   '2021': 2043},
#  'citation_table': ['2082', '26'],
#  'domain_labels': ['artificial_intelligence',
#   'graphical_models',
#   'machine_learning',
#   'probabilistic_inference',
#   'statistical_relational_learning'],
#  'gender': 'M',
#  'gs_sid': 'pm_dg3cAAAAJ',
#  'organization': 'The University of Texas at Dallas',
#  'organization_code': '6037664147916511730',
#  'paper_num': 100,
#  'cites': {'years': ['2005',
#    '2006',
#    '2007',
#    '2008',
#    '2009',
#    '2010',
#    '2011',
#    '2012',
#    '2013',
#    '2014',
#    '2015',
#    '2016',
#    '2017',
#    '2018',
#    '2019',
#    '2020',
# ...

# %%
tmp_wd = scholar_search.search_gs.search_name('Brandon Malone', tmp_dict, wo_full=True, simple=True)
# Out:
# <class 'str'>
# <class 'str'>
# [Info] Find 2 scholars using query without gs_sid in step 2

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import ChromiumOptions
from selenium.webdriver.common.by import By
tmp_wd[0].find_element(By.CLASS_NAME, 'gs_ai_eml').get_attribute('textContent').strip()
# Out:
# ''

# %%
tmp_resp = scholar_search.get_scholar(query=tmp_dict, simple=True, top_n=3, print_true=True)
# Out:
# [Info] Found 1 scholars are in 78k data.
# [Debug] Names: 0    Brandon Malone
# Name: name, dtype: object
# Not find by gs_sid, search from_dict
# [Info] Find 2 scholars using query without gs_sid in step 4
# [Info] In total 1 scholar is found:
# [
#   {
#     "academic": false,
#     "academic_age": 17.0,
#     "academic_lifespan": 17.0,
#     "cit_sum_before_year": {
#       "2011": 10,
#       "2012": 50,
#       "2013": 106,
#       "2014": 204,
#       "2015": 320,
#       "2016": 481,
#       "2017": 620,
#       "2018": 761,
#       "2019": 875,
#       "2020": 1056,
#       "2021": 1492
#     },
#     "citation_table": [
#       "1693",
#       "23"
#     ],
#     "domain_labels": [
#       "artificial intelligence",
#       "bioinformatics",
#       "bayesian networks"
#     ],
#     "gender": "M",
#     "gs_sid": "bJAf_XMAAAAJ",
#     "organization": "NEC Laboratories Europe",
#     "organization_code": null,
#     "paper_num": 96,
#     "cites": {
#       "years": [
# ...

# %%
tmp_long = [{'academic': True, 'academic_age': 19.0, 'academic_lifespan': 19.0, 'cit_sum_before_year': {'2006': 19, '2007': 64, '2008': 124, '2009': 225, '2010': 364, '2011': 524, '2012': 654, '2013': 809, '2014': 980, '2015': 1145, '2016': 1423, '2017': 1870, '2018': 2649, '2019': 3616, '2020': 4744, '2021': 5938}, 'citation_table': ['6267', '36'], 'domain_labels': ['artificial_intelligence', 'natural_language_processing'], 'gender': 'F', 'gs_sid': 'lVhoKNcAAAAJ', 'organization': 'Professor of Computer Science, Tsinghua University', 'organization_code': '15442380624744264287', 'paper_num': 196, 'cites': {'years': ['2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], 'cites': ['19', '45', '60', '101', '139', '160', '130', '155', '171', '165', '278', '447', '779', '967', '1128', '1194', '276']}, 'coauthors': [['https://scholar.google.com/citations?user=zIgT0HMAAAAJ&hl=en', 'Maosong Sun', 'Professor of Computer Science and Technology, Tsinghua University', 'Verified email at tsinghua.edu.cn'], ['https://scholar.google.com/citations?user=2HhiGzcAAAAJ&hl=en', 'Qun Liu', "Noah's Ark Lab, Huawei", 'Verified email at huawei.com'], ['https://scholar.google.com/citations?user=IvE2zRgAAAAJ&hl=en', 'Zhaopeng Tu', 'Principal Researcher, Tencent AI Lab', 'Verified email at tencent.com'], ['https://scholar.google.com/citations?user=rZ0mlMYAAAAJ&hl=en', 'Yong Cheng', 'Google Research', 'Verified email at google.com'], ['https://scholar.google.com/citations?user=w6qCk3sAAAAJ&hl=en', 'Jinsong Su', 'Xiamen University', 'Verified email at xmu.edu.cn'], ['https://scholar.google.com/citations?user=N1dib3cAAAAJ&hl=en', 'Meng Zhang', "Huawei Noah's Ark Lab", 'Verified email at huawei.com'], ['https://scholar.google.com/citations?user=iDFjEO0AAAAJ&hl=en', 'Zhixing Tan', 'Tsinghua University', 'Verified email at tsinghua.edu.cn'], ['https://scholar.google.com/citations?user=G3OMbFSm858C&hl=en', 'Haitao Mi', 'Principal Researcher, Tencent US', 'Verified email at tencent.com'], ['https://scholar.google.com/citations?user=QPLO3myO5PkC&hl=en', 'Deyi Xiong', 'Professor, College of Intelligence and Computing, Tianjin University, China', 'Verified email at tju.edu.cn'], ['https://scholar.google.com/citations?user=vLT3OXgAAAAJ&hl=en', 'Yajuan Lyu (Yajuan Lü)', 'Baidu Inc.', 'Verified email at baidu.com'], ['https://scholar.google.com/citations?user=a-1wSFYAAAAJ&hl=en', 'Zhongjun HE', 'Researcher of Natural Language Processing, Baidu', 'Verified email at baidu.com'], ['https://scholar.google.com/citations?user=CncXH-YAAAAJ&hl=en', 'Min Zhang', 'Professor of Computer Science, Soochow University', 'Verified email at suda.edu.cn'], ['https://scholar.google.com/citations?user=nTl5mSwAAAAJ&hl=en', 'Hang Li', 'AI Lab, Bytedance Technology', 'Verified email at bytedance.com'], ['https://scholar.google.com/citations?user=5vm5yAMAAAAJ&hl=en', 'Shuo Wang', 'Tsinghua University', 'Verified email at mails.tsinghua.edu.cn'], ['https://scholar.google.com/citations?user=e23-LKYAAAAJ&hl=en', 'Shiqi Shen', 'Wechat, Tencent', 'Verified email at tencent.com'], ['https://scholar.google.com/citations?user=lWRYa3wAAAAJ&hl=en', 'Xinyan Xiao', 'Baidu', 'Verified email at baidu.com'], ['https://scholar.google.com/citations?user=OJ-xVYwAAAAJ&hl=en', 'jiali zeng', 'Tencent', 'Verified email at tencent.com'], ['https://scholar.google.com/citations?user=x5lXo2YAAAAJ&hl=en', 'Zhengdong Lu', 'DeeplyCurious.ai', 'Verified email at deeplycurious.ai'], ['https://scholar.google.com/citations?user=UYIw2qAAAAAJ&hl=en', 'Yang Feng', 'Professor of Institute of Computing Technology, Chinese Academy of Sciences', 'Verified email at ict.ac.cn'], ['https://scholar.google.com/citations?user=GQWTo4MAAAAJ&hl=en', 'Li Deng', 'Chief AI Officer, Citadel (former)', 'Verified email at ieee.org']], 'name': 'Yang Liu', 'url': 'https://scholar.google.com/citations?hl=en&user=lVhoKNcAAAAJ', 'top_num_coauthors': 20.0, 'num_domain': 2.0, 'top_topic_diversity': 23.0, 'num_coauthors_all_wwo_ai': 217, 'organization_top': 0.0}, {'academic': False, 'academic_age': 18.0, 'academic_lifespan': 18.0, 'cit_sum_before_year': {'2006': 36, '2007': 79, '2008': 229, '2009': 477, '2010': 773, '2011': 1157, '2012': 1664, '2013': 2377, '2014': 3315, '2015': 4350, '2016': 5584, '2017': 6995, '2018': 8374, '2019': 9724, '2020': 11054, '2021': 12603}, 'citation_table': ['13099', '15'], 'domain_labels': ['computer_science', 'life_science', 'machine_learning', 'reinforcement_learning', 'mathematical_modeling'], 'gender': 'F', 'gs_sid': 'LlLWmkYAAAAJ', 'organization': 'Facebook', 'organization_code': '1978088699341142706', 'paper_num': 19, 'cites': {'years': ['2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], 'cites': ['36', '43', '150', '248', '296', '384', '507', '713', '938', '1035', '1234', '1411', '1379', '1350', '1330', '1549', '394']}, 'coauthors': [['https://scholar.google.com/citations?user=1Vrz-xYAAAAJ&hl=en', 'Yong-Bin Yan', 'Tsinghua University, Beijing', 'Verified email at tsinghua.edu.cn']], 'name': 'Yang Liu', 'url': 'https://scholar.google.com/citations?hl=en&user=LlLWmkYAAAAJ', 'top_num_coauthors': 1.0, 'num_domain': 5.0, 'top_topic_diversity': 0.0, 'num_coauthors_all_wwo_ai': 59, 'organization_top': 1.0}, {'academic': True, 'academic_age': 40.0, 'academic_lifespan': 38.0, 'cit_sum_before_year': {'1988': 28, '1989': 38, '1990': 55, '1991': 101, '1992': 185, '1993': 253, '1994': 305, '1995': 343, '1996': 388, '1997': 441, '1998': 480, '1999': 511, '2000': 553, '2001': 578, '2002': 616, '2003': 649, '2004': 682, '2005': 758, '2006': 860, '2007': 985, '2008': 1130, '2009': 1304, '2010': 1489, '2011': 1701, '2012': 1922, '2013': 2163, '2014': 2466, '2015': 2805, '2016': 3222, '2017': 3629, '2018': 4031, '2019': 4440, '2020': 4795, '2021': 5199}, 'citation_table': ['5429', '35'], 'domain_labels': ['machine_learning', 'computer_vision'], 'gender': 'F', 'gs_sid': '3IC_ZtkAAAAJ', 'organization': 'Computer Science, harbin institute of technology', 'organization_code': '4726995703083099959', 'paper_num': 126, 'cites': {'years': ['1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], 'cites': ['28', '10', '17', '46', '84', '68', '52', '38', '45', '53', '39', '31', '42', '25', '38', '33', '33', '76', '102', '125', '145', '174', '185', '212', '221', '241', '303', '339', '417', '407', '402', '409', '355', '404', '161']}, 'coauthors': None, 'name': 'Yang Liu', 'url': 'https://scholar.google.com/citations?hl=en&user=3IC_ZtkAAAAJ', 'top_num_coauthors': None, 'num_domain': 2.0, 'top_topic_diversity': None, 'num_coauthors_all_wwo_ai': 250, 'organization_top': 0.0}, {'academic': False, 'academic_age': 8.0, 'academic_lifespan': 8.0, 'cit_sum_before_year': {'2015': 13, '2016': 66, '2017': 147, '2018': 297, '2019': 521, '2020': 1101, '2021': 1988}, 'citation_table': ['2152', '16'], 'domain_labels': ['natural_language_processing', 'neural_network'], 'gender': 'F', 'gs_sid': 'HxTr-CtMdrsC', 'organization': 'Microsoft', 'organization_code': '12331530069074480064', 'paper_num': 30, 'cites': {'years': ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], 'cites': ['13', '53', '81', '150', '224', '580', '887', '153']}, 'coauthors': [['https://scholar.google.com/citations?user=j67B9Q4AAAAJ&hl=en', 'Mirella Lapata', 'School of Informatics, Edinburgh University', 'Verified email at inf.ed.ac.uk'], ['https://scholar.google.com/citations?user=RvBDhSwAAAAJ&hl=en', 'Sujian LI', 'Peking Univ.', 'Verified email at pku.edu.cn'], ['https://scholar.google.com/citations?user=1b2kKWoAAAAJ&hl=en', 'Chenguang Zhu', 'Principal Research Manager at Microsoft Research', 'Verified email at microsoft.com'], ['https://scholar.google.com/citations?user=G-V1VpwAAAAJ&hl=en', 'Furu Wei', 'Partner Research Manager, Microsoft Research', 'Verified email at microsoft.com'], ['https://scholar.google.com/citations?user=06ITfcEAAAAJ&hl=en', 'Ziqiang Cao', 'Soochow University', 'Verified email at suda.edu.cn'], ['https://scholar.google.com/citations?user=mnifqeUAAAAJ&hl=en', 'Ming Zhong', 'University of Illinois at Urbana-Champaign', 'Verified email at illinois.edu'], ['https://scholar.google.com/citations?user=SfKdzrUAAAAJ&hl=en', 'Matt Gardner', 'Microsoft Semantic Machines', 'Verified email at microsoft.com'], ['https://scholar.google.com/citations?user=NfJbKJ4AAAAJ&hl=en', 'Liang Wang', 'Microsoft', 'Verified email at microsoft.com']], 'name': 'Yang Liu', 'url': 'https://scholar.google.com/citations?hl=en&user=HxTr-CtMdrsC', 'top_num_coauthors': 8.0, 'num_domain': 2.0, 'top_topic_diversity': 16.0, 'num_coauthors_all_wwo_ai': 52, 'organization_top': 1.0}, {'academic': False, 'academic_age': 21.0, 'academic_lifespan': 21.0, 'cit_sum_before_year': {'2004': 26, '2005': 100, '2006': 246, '2007': 363, '2008': 539, '2009': 749, '2010': 1051, '2011': 1394, '2012': 1732, '2013': 2087, '2014': 2518, '2015': 2956, '2016': 3453, '2017': 3851, '2018': 4375, '2019': 4860, '2020': 5365, '2021': 5941}, 'citation_table': ['6162', '45'], 'domain_labels': ['speech_recognition_natural_language_processing', 'machine_learning'], 'gender': 'F', 'gs_sid': 'w90wOucAAAAJ', 'organization': 'Amazon', 'organization_code': None, 'paper_num': 186, 'cites': {'years': ['2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], 'cites': ['26', '74', '146', '117', '176', '210', '302', '343', '338', '355', '431', '438', '497', '398', '524', '485', '505', '576', '146']}, 'coauthors': [['https://scholar.google.com/citations?user=nRZJYPIAAAAJ&hl=en', 'Elizabeth Shriberg', 'CSO at Ellipsis Health, San Francisco', 'Verified email at ellipsishealth.com'], ['https://scholar.google.com/citations?user=GMcL_9kAAAAJ&hl=en', 'Dilek Hakkani-Tur', 'Amazon Alexa AI', 'Verified email at ieee.org'], ['https://scholar.google.com/citations?user=NK36Tw0AAAAJ&hl=en', 'Andreas Stolcke', 'Sr. Principal Scientist, Amazon and ICSI', 'Verified email at icsi.berkeley.edu'], ['https://scholar.google.com/citations?user=22ohn6AAAAAJ&hl=en', 'Fei Liu', 'Associate Professor of Computer Science, University of Central Florida', 'Verified email at cs.ucf.edu'], ['https://scholar.google.com/citations?user=jl89ugsAAAAJ&hl=en', 'Shasha Xie', 'Tencent', 'Verified email at tencent.com'], ['https://scholar.google.com/citations?user=nPvWFpkAAAAJ&hl=en', 'Chen Li', 'The University of Texas at Dallas', 'Verified email at hlt.utdallas.edu'], ['https://scholar.google.com/citations?user=exS-GecAAAAJ&hl=en', 'Mari Ostendorf', 'Professor, Electrical Engineering, University of Washington', 'Verified email at uw.edu'], ['https://scholar.google.com/citations?user=Gmjwy-IAAAAJ&hl=en', 'Thamar Solorio', 'Bloomberg & University of Houston', 'Verified email at uh.edu'], ['https://scholar.google.com/citations?user=26oErxwAAAAJ&hl=en', 'Rui Xia', 'Bytedance', 'Verified email at bytedance.com'], ['https://scholar.google.com/citations?user=4YEhqioAAAAJ&hl=en', 'Dustin Hillard', 'eSentire', 'Verified email at u.washington.edu'], ['https://scholar.google.com/citations?user=h7xU9DYAAAAJ&hl=en', 'xian qian', 'The University of Texas at Dallas', 'Verified email at hlt.utdallas.edu'], ['https://scholar.google.com/citations?user=4gVbilMMp-AC&hl=en', 'Izhak Shafran', 'Professor, OHSU', 'Verified email at ohsu.edu'], ['https://scholar.google.com/citations?user=KOtHhfgAAAAJ&hl=en', 'Fuliang Weng', '', 'Verified email at ieee.org'], ['https://scholar.google.com/citations?user=qgmiQ5IAAAAJ&hl=en', 'Matt Lease', 'Associate Professor, School of Information, University of Texas at Austin', 'Verified email at utexas.edu'], ['https://scholar.google.com/citations?user=jSjEWosAAAAJ&hl=en', 'Bonnie Dorr', 'University of Florida, IHMC, UMD', 'Verified email at ufl.edu'], ['https://scholar.google.com/citations?user=xPjpSs4AAAAJ&hl=en', 'Brian Roark', 'Google', 'Verified email at google.com'], ['https://scholar.google.com/citations?user=sqUEF0MAAAAJ&hl=en', 'John Hale', 'Linguistics Department, University of Georgia', 'Verified email at uga.edu'], ['https://scholar.google.com/citations?user=85Tj1OwAAAAJ&hl=en', 'Wen Wang', 'Alibaba DAMO Academy', 'Verified email at alibaba-inc.com'], ['https://scholar.google.com/citations?user=LCeRsUcAAAAJ&hl=en', 'Daniel Gillick', 'Research Scientist, Google', 'Verified email at google.com'], ['https://scholar.google.com/citations?user=nyzjv1kAAAAJ&hl=en', 'Lisa Bedore', 'Temple University', 'Verified email at temple.edu']], 'name': 'Yang Liu', 'url': 'https://scholar.google.com/citations?hl=en&user=w90wOucAAAAJ', 'top_num_coauthors': 20.0, 'num_domain': 2.0, 'top_topic_diversity': 22.0, 'num_coauthors_all_wwo_ai': 194, 'organization_top': 0.0}, {'academic': True, 'academic_age': 44.0, 'academic_lifespan': 44.0, 'cit_sum_before_year': {'2004': 88, '2005': 263, '2006': 496, '2007': 797, '2008': 1199, '2009': 1757, '2010': 2634, '2011': 3762, '2012': 5084, '2013': 6628, '2014': 8471, '2015': 10425, '2016': 12498, '2017': 14457, '2018': 16514, '2019': 18836, '2020': 21280, '2021': 24005}, 'citation_table': ['25143', '70'], 'domain_labels': ['artificial_intelligence', 'machine_learning', 'computer_vision'], 'gender': 'F', 'gs_sid': 'zKqjcKMAAAAJ', 'organization': 'Computer science, Harbin institute of technology', 'organization_code': '4726995703083099959', 'paper_num': 852, 'cites': {'years': ['2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], 'cites': ['88', '175', '233', '301', '402', '558', '877', '1128', '1322', '1544', '1843', '1954', '2073', '1959', '2057', '2322', '2444', '2725', '833']}, 'coauthors': None, 'name': 'Yang Liu', 'url': 'https://scholar.google.com/citations?hl=en&user=zKqjcKMAAAAJ', 'top_num_coauthors': None, 'num_domain': 3.0, 'top_topic_diversity': None, 'num_coauthors_all_wwo_ai': 1448, 'organization_top': 0.0}, {'academic': False, 'academic_age': 13.0, 'academic_lifespan': 13.0, 'cit_sum_before_year': {'2014': 9, '2015': 31, '2016': 67, '2017': 121, '2018': 242, '2019': 465, '2020': 810, '2021': 1488}, 'citation_table': ['1664', '22'], 'domain_labels': ['crowdsourcing', 'machine_learning', 'incentive_and_consensus'], 'gender': 'F', 'gs_sid': 'jKrIVCIAAAAJ', 'organization': 'Computer Science and Engineering, UC Santa Cruz', 'organization_code': '6192028974562668508', 'paper_num': 74, 'cites': {'years': ['2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], 'cites': ['9', '22', '36', '54', '121', '223', '345', '678', '153']}, 'coauthors': [['https://scholar.google.com/citations?user=WiIM-MgAAAAJ&hl=en', 'Mingyan Liu', 'Professor of Electrical Engineering and Computer Science, University of Michigan', 'Verified email at umich.edu'], ['https://scholar.google.com/citations?user=JUn8PgwAAAAJ&hl=en', 'David C. Parkes', 'George F. Colony Professor of Computer Science, Harvard University', 'Verified email at eecs.harvard.edu'], ['https://scholar.google.com/citations?user=zxWeH6EAAAAJ&hl=en', 'Armin Sarabi', 'Assistant Research Scientist, University of Michigan', 'Verified email at umich.edu'], ['https://scholar.google.com/citations?user=KBG_JlAAAAAJ&hl=en', 'Goran Radanović', 'Research Group Leader, Max Planck Institute for Software Systems', 'Verified email at mpi-sws.org'], ['https://scholar.google.com/citations?user=uvRJd_sAAAAJ&hl=en', 'Jing Zhang', 'University of Michigan', 'Verified email at umich.edu'], ['https://scholar.google.com/citations?user=sMnocAYAAAAJ&hl=en', 'Michael Donald Bailey', 'University of Illinois', 'Verified email at illinois.edu'], ['https://scholar.google.com/citations?user=6z_XWYcAAAAJ&hl=en', 'Berk Ustun', 'UCSD', 'Verified email at ucsd.edu'], ['https://scholar.google.com/citations?user=x_7xA0UAAAAJ&hl=en', 'Yiling Chen', 'Harvard University', 'Verified email at seas.harvard.edu'], ['https://scholar.google.com/citations?user=rbleSIcAAAAJ&hl=en', 'Parinaz Naghizadeh', 'Assistant Professor of ISE & ECE, Ohio State University', 'Verified email at osu.edu'], ['https://scholar.google.com/citations?user=4T2B-e8AAAAJ&hl=en', 'Ji Liu', 'Stony Brook University', 'Verified email at stonybrook.edu'], ['https://scholar.google.com/citations?user=9Kw4t_kAAAAJ&hl=en', 'Christos Dimitrakakis', 'Professor, University of Oslo', 'Verified email at a3.epfl.ch'], ['https://scholar.google.com/citations?user=DWKoeW0AAAAJ&hl=en', 'Chien-Ju Ho', 'Washington University in St. Louis', 'Verified email at wustl.edu'], ['https://scholar.google.com/citations?user=NGIsUesAAAAJ&hl=en', 'Tamer Başar', 'Swanlund Endowed Chair Emeritus & CAS Professor Emeritus of ECE, University of Illinois', 'Verified email at illinois.edu'], ['https://scholar.google.com/citations?user=K8vJkTcAAAAJ&hl=en', 'Bo Li', 'University of Illinois at Urbana–Champaign', 'Verified email at illinois.edu'], ['https://scholar.google.com/citations?user=k2RheI8AAAAJ&hl=en', 'Yitao Liang', 'Assistant Professor, Peking University', 'Verified email at pku.edu.cn'], ['https://scholar.google.com/citations?user=IFV_RdMAAAAJ&hl=en', 'Jie Zhang', 'Associate Professor, Computer Science and Engineering, NTU, Singapore', 'Verified email at ntu.edu.sg'], ['https://scholar.google.com/citations?user=8r28SnIAAAAJ&hl=en', 'Jing Deng', 'Professor of Computer Science, UNC Greensboro', 'Verified email at uncg.edu'], ['https://scholar.google.com/citations?user=f6terwoAAAAJ&hl=en', 'Tudor Dumitras', 'Assistant Professor, University of Maryland, College Park', 'Verified email at umiacs.umd.edu'], ['https://scholar.google.com/citations?user=Juoqtj8AAAAJ&hl=en', 'Chaowei Xiao', 'Nvidia Research & ASU', 'Verified email at umich.edu'], ['https://scholar.google.com/citations?user=H5fGjPkAAAAJ&hl=en', 'Sahand Ahmad', 'Director of Systematic Trading Strategies', 'Verified email at umich.edu']], 'name': 'Yang Liu', 'url': 'https://scholar.google.com/citations?hl=en&user=jKrIVCIAAAAJ', 'top_num_coauthors': 20.0, 'num_domain': 3.0, 'top_topic_diversity': 19.0, 'num_coauthors_all_wwo_ai': 85, 'organization_top': 0.0}, {'academic': True, 'academic_age': 9.0, 'academic_lifespan': 7.0, 'cit_sum_before_year': {'2016': 4, '2017': 13, '2018': 34, '2019': 91, '2020': 246, '2021': 451}, 'citation_table': ['497', '6'], 'domain_labels': ['artificial_intelligence', 'machine_learning'], 'gender': 'F', 'gs_sid': 'HemTnvEAAAAJ', 'organization': 'New Jersey Institute of Technology', 'organization_code': '3222048884122846369', 'paper_num': 8, 'cites': {'years': ['2016', '2017', '2018', '2019', '2020', '2021', '2022'], 'cites': ['4', '9', '21', '57', '155', '205', '45']}, 'coauthors': None, 'name': 'Yang Liu', 'url': 'https://scholar.google.com/citations?hl=en&user=HemTnvEAAAAJ', 'top_num_coauthors': None, 'num_domain': 2.0, 'top_topic_diversity': None, 'num_coauthors_all_wwo_ai': 16, 'organization_top': 0.0}, {'academic': True, 'academic_age': 6.0, 'academic_lifespan': 5.0, 'cit_sum_before_year': {'2018': 13, '2019': 39, '2020': 99, '2021': 242}, 'citation_table': ['301', '6'], 'domain_labels': ['computational_imaging', 'computational_photography', 'machine_learning'], 'gender': 'F', 'gs_sid': 'QRRaWikAAAAJ', 'organization': 'PhD student, MIT CSAIL', 'organization_code': None, 'paper_num': 10, 'cites': {'years': ['2018', '2019', '2020', '2021', '2022'], 'cites': ['13', '26', '60', '143', '57']}, 'coauthors': [['https://scholar.google.com/citations?user=CHAajY4AAAAJ&hl=en', 'Qionghai  Dai', 'Tsinghua University', 'Verified email at tsinghua.edu.cn'], ['https://scholar.google.com/citations?user=e4lel8QAAAAJ&hl=en', 'Jinli Suo', 'Tsinghua University', 'Verified email at tsinghua.edu.cn'], ['https://scholar.google.com/citations?user=cS9CbWkAAAAJ&hl=en', 'Xin Yuan', 'Westlake Univ., Bell Labs, Duke University, Hong Kong Polytechnic University', 'Verified email at westlake.edu.cn'], ['https://scholar.google.com/citations?user=NJ9c4ygAAAAJ&hl=en', 'Fredo Durand', 'Professor of Computer Science, MIT', 'Verified email at mit.edu']], 'name': 'Yang Liu', 'url': 'https://scholar.google.com/citations?hl=en&user=QRRaWikAAAAJ', 'top_num_coauthors': 4.0, 'num_domain': 3.0, 'top_topic_diversity': 8.0, 'num_coauthors_all_wwo_ai': 26, 'organization_top': 0.0}, {'academic': True, 'academic_age': 14.0, 'academic_lifespan': 14.0, 'cit_sum_before_year': {'2010': 1, '2011': 2, '2012': 7, '2013': 17, '2014': 36, '2015': 48, '2016': 63, '2017': 74, '2018': 101, '2019': 136, '2020': 146, '2021': 168}, 'citation_table': ['171', '7'], 'domain_labels': ['wireless_sensor_networks', 'internet_of_things', 'vanets', 'machine_learning', 'convex_optimization'], 'gender': 'F', 'gs_sid': 'zqagrvcAAAAJ', 'organization': 'Guangdong University of Technology', 'organization_code': '16712606981674617829', 'paper_num': 20, 'cites': {'years': ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], 'cites': ['1', '1', '5', '10', '19', '12', '15', '11', '27', '35', '10', '22', '3']}, 'coauthors': None, 'name': 'Yang Liu', 'url': 'https://scholar.google.com/citations?hl=en&user=zqagrvcAAAAJ', 'top_num_coauthors': None, 'num_domain': 5.0, 'top_topic_diversity': None, 'num_coauthors_all_wwo_ai': 24, 'organization_top': 0.0}, {'academic': True, 'academic_age': 11.0, 'academic_lifespan': 10.0, 'cit_sum_before_year': {'2013': 1, '2014': 8, '2015': 11, '2016': 17, '2017': 25, '2018': 38, '2019': 55, '2020': 82, '2021': 155}, 'citation_table': ['175', '5'], 'domain_labels': ['neuroscience', 'computer_vision', 'machine_learning'], 'gender': 'F', 'gs_sid': 'nVWQwHkAAAAJ', 'organization': 'PhD, Computation and Neural Systems, California Institute of Technology', 'organization_code': '7467084778962869219', 'paper_num': 10, 'cites': {'years': ['2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], 'cites': ['1', '7', '3', '6', '8', '13', '17', '27', '73', '19']}, 'coauthors': [['https://scholar.google.com/citations?user=QKhjs2YAAAAJ&hl=en', 'Markus Meister', 'California Institute of Technology', 'Verified email at caltech.edu'], ['https://scholar.google.com/citations?user=j29kMCwAAAAJ&hl=en', 'Pietro Perona', 'California Institute of Technology', 'Verified email at caltech.edu'], ['https://scholar.google.com/citations?user=Hbr4c10AAAAJ&hl=en', 'Sara Beery', 'PhD Candidate at Caltech, collaborations with Google Research, Microsoft AI for Earth', 'Verified email at caltech.edu'], ['https://scholar.google.com/citations?user=Kz5C0p0AAAAJ&hl=en', 'Jeremy Bernstein', 'Computation and Neural Systems, Caltech', 'Verified email at caltech.edu'], ['https://scholar.google.com/citations?user=tEk4qo8AAAAJ&hl=en', 'Yisong Yue', 'California Institute of Technology; Argo AI', 'Verified email at caltech.edu'], ['https://scholar.google.com/citations?user=-xiLdcUAAAAJ&hl=en', 'Jing Liu', 'Technical Institute of Physics and Chemistry, Chinese Academy of Sciences & Tsinghua University', 'Verified email at mail.ipc.ac.cn']], 'name': 'Yang Liu', 'url': 'https://scholar.google.com/citations?hl=en&user=nVWQwHkAAAAJ', 'top_num_coauthors': 6.0, 'num_domain': 3.0, 'top_topic_diversity': 11.0, 'num_coauthors_all_wwo_ai': 23, 'organization_top': 0.0}, {'academic': True, 'academic_age': 10.0, 'academic_lifespan': 6.0, 'cit_sum_before_year': {'2015': 2, '2016': 5, '2017': 15, '2018': 30, '2019': 52, '2020': 75, '2021': 110}, 'citation_table': ['120', '4'], 'domain_labels': ['machine_learning', 'data_science', 'social_media', 'user_behavior'], 'gender': 'F', 'gs_sid': 'xr9H83IAAAAJ', 'organization': 'Bowling Green State University', 'organization_code': None, 'paper_num': 9, 'cites': {'years': ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], 'cites': ['2', '3', '10', '15', '22', '23', '35', '8']}, 'coauthors': [['https://scholar.google.com/citations?user=9zeJXnEAAAAJ&hl=en', 'Louisa Ha', 'Bowling Green State University', 'Verified email at bgsu.edu'], ['https://scholar.google.com/citations?user=dFp6JBEAAAAJ&hl=en', 'Mohammad Hatim Abuljadail', 'King Abdulaziz University, Associate Professor of Marketing Communication', 'Verified email at kau.edu.sa'], ['https://scholar.google.com/citations?user=7jS8cFkAAAAJ&hl=en', 'Chen Yang', 'Robert Morris University', 'Verified email at rmu.edu'], ['https://scholar.google.com/citations?user=fjFjnFYAAAAJ&hl=en', 'Lianxiang Yang', 'Professor of Mechanical Engineering, Oakland University', 'Verified email at oakland.edu']], 'name': 'Yang Liu', 'url': 'https://scholar.google.com/citations?hl=en&user=xr9H83IAAAAJ', 'top_num_coauthors': 4.0, 'num_domain': 4.0, 'top_topic_diversity': 0.0, 'num_coauthors_all_wwo_ai': 27, 'organization_top': 0.0}, {'academic': False, 'academic_age': 8.0, 'academic_lifespan': 5.0, 'cit_sum_before_year': {'2015': 4, '2016': 20, '2017': 42, '2018': 86, '2019': 136, '2020': 208, '2021': 284}, 'citation_table': ['304', '5'], 'domain_labels': ['computer_vision', 'machine_learning'], 'gender': 'F', 'gs_sid': 'lUuS4kQAAAAJ', 'organization': 'Ph.D, UCLA', 'organization_code': '14108176128635076915', 'paper_num': 5, 'cites': {'years': ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], 'cites': ['4', '16', '22', '44', '50', '72', '76', '15']}, 'coauthors': [['https://scholar.google.com/citations?user=Al8dyb4AAAAJ&hl=en', 'song-chun zhu', 'Professor of Statistics and Computer Science, UCLA', 'Verified email at stat.ucla.edu'], ['https://scholar.google.com/citations?user=1OQBtdcAAAAJ&hl=en', 'Ping Wei', "Professor, Xi'an Jiaotong University", 'Verified email at xjtu.edu.cn'], ['https://scholar.google.com/citations?user=ffKMTFUAAAAJ&hl=en', 'Xiaobai Liu', 'Associate Professor of Computer Science, San Diego State University', 'Verified email at sdsu.edu'], ['https://scholar.google.com/citations?user=fvr-J3sAAAAJ&hl=en', 'Yuanlu Xu', 'Reality Labs Research, Meta Platforms, Inc.', 'Verified email at fb.com']], 'name': 'Yang Liu', 'url': 'https://scholar.google.com/citations?hl=en&user=lUuS4kQAAAAJ', 'top_num_coauthors': 4.0, 'num_domain': 2.0, 'top_topic_diversity': 12.0, 'num_coauthors_all_wwo_ai': 12, 'organization_top': 0.0}, {'academic': False, 'academic_age': 16.0, 'academic_lifespan': 15.0, 'cit_sum_before_year': {'2008': 2, '2009': 3, '2010': 7, '2011': 8, '2012': 9, '2013': 28, '2014': 45, '2015': 77, '2016': 105, '2017': 136, '2018': 163, '2019': 187, '2020': 207, '2021': 236}, 'citation_table': ['241', '7'], 'domain_labels': ['robotics', 'slam', 'computer_vision'], 'gender': 'F', 'gs_sid': 'imLJP60AAAAJ', 'organization': 'Huawei Technologies Canada', 'organization_code': None, 'paper_num': 10, 'cites': {'years': ['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], 'cites': ['2', '1', '4', '1', '1', '19', '17', '32', '28', '31', '27', '24', '20', '29', '5']}, 'coauthors': [['https://scholar.google.com/citations?user=J7UkpAIAAAAJ&hl=en', 'Hong Zhang', 'Chair Professor, SUSTech; Professor Emeritus, University of Alberta', 'Verified email at ualberta.ca']], 'name': 'Yang Liu', 'url': 'https://scholar.google.com/citations?hl=en&user=imLJP60AAAAJ', 'top_num_coauthors': 1.0, 'num_domain': 3.0, 'top_topic_diversity': 3.0, 'num_coauthors_all_wwo_ai': 10, 'organization_top': 0.0}, {'academic': True, 'academic_age': 6.0, 'academic_lifespan': 5.0, 'cit_sum_before_year': {'2018': 10, '2019': 54, '2020': 145, '2021': 245}, 'citation_table': ['282', '6'], 'domain_labels': ['computer_vision', 'image_processing'], 'gender': 'F', 'gs_sid': 'z2eEUuwAAAAJ', 'organization': 'Dalian University of Technology', 'organization_code': '16416005854777279154', 'paper_num': 9, 'cites': {'years': ['2018', '2019', '2020', '2021', '2022'], 'cites': ['10', '44', '91', '100', '35']}, 'coauthors': [['https://scholar.google.com/citations?user=CMsNjGIAAAAJ&hl=en', 'Jinshan Pan', 'Nonejing University of Science and Technology', 'Verified email at seas.harvard.edu'], ['https://scholar.google.com/citations?user=WKO_1VYAAAAJ&hl=en', 'Jimmy S. Ren', 'SenseTime Research', 'Verified email at my.cityu.edu.hk']], 'name': 'Yang Liu', 'url': 'https://scholar.google.com/citations?hl=en&user=z2eEUuwAAAAJ', 'top_num_coauthors': 2.0, 'num_domain': 2.0, 'top_topic_diversity': 5.0, 'num_coauthors_all_wwo_ai': 20, 'organization_top': 0.0}, {'academic': False, 'academic_age': 9.0, 'academic_lifespan': 8.0, 'cit_sum_before_year': {'2016': 1, '2017': 8, '2018': 36, '2019': 94, '2020': 141, '2021': 160}, 'citation_table': ['160', '4'], 'domain_labels': ['artificial_intelligence', 'computer_vision', 'multimedia'], 'gender': 'F', 'gs_sid': 'v-RBgdMAAAAJ', 'organization': 'Computer Vision Researcher at Sportlogiq', 'organization_code': None, 'paper_num': 9, 'cites': {'years': ['2016', '2017', '2018', '2019', '2020', '2021', '2022'], 'cites': ['1', '7', '28', '58', '47', '19']}, 'coauthors': [['https://scholar.google.com/citations?user=KpKUZ0MAAAAJ&hl=en', 'Haiwei Dong', 'Principal Researcher, Huawei Technologies Canada', 'Verified email at huawei.com'], ['https://scholar.google.com/citations?user=VcOjgngAAAAJ&hl=en', 'Abdulmotaleb El Saddik', 'Mohamed bin Zayed University of Artificial Intelligence, University of Ottawa', 'Verified email at uottawa.ca'], ['https://scholar.google.com/citations?user=MetYNkcAAAAJ&hl=en', 'Longyu Zhang', 'University of Ottawa', 'Verified email at uottawa.ca'], ['https://scholar.google.com/citations?user=3S8O0b4AAAAJ&hl=en', 'Mehrsan Javan Roshtkhari', 'Chief Technology Officer, Sportlogiq; Adjunct professor, McGill University', 'Verified email at cim.mcgill.ca'], ['https://scholar.google.com/citations?user=GvSAjYAAAAAJ&hl=en', 'Md Amran Hossen Bhuiyan', 'Associate Professor, Dept. of CSTE, Noakhali Science & Technology University, Bangladesh', 'Verified email at nstu.edu.bd'], ['https://scholar.google.com/citations?user=vNFjHYMAAAAJ&hl=en', 'Parthipan Siva', 'Machine learning researcher, Co-founder, Chirp Inc', 'Verified email at mychirp.com'], ['https://scholar.google.com/citations?user=6LIgQn4AAAAJ&hl=en', 'Luiz Gustavo Hafemann', 'Computer Vision Researcher, Sportlogiq', 'Verified email at sportlogiq.com'], ['https://scholar.google.com/citations?user=zoBnsM4AAAAJ&hl=en', 'Michael Jamieson', 'Sportlogiq', 'Verified email at sportlogiq.com']], 'name': 'Yang Liu', 'url': 'https://scholar.google.com/citations?hl=en&user=v-RBgdMAAAAJ', 'top_num_coauthors': 8.0, 'num_domain': 3.0, 'top_topic_diversity': 11.0, 'num_coauthors_all_wwo_ai': 22, 'organization_top': 0.0}, {'academic': True, 'academic_age': 5.0, 'academic_lifespan': 5.0, 'cit_sum_before_year': {'2018': 4, '2019': 22, '2020': 60, '2021': 147}, 'citation_table': ['172', '3'], 'domain_labels': ['computer_vision'], 'gender': 'F', 'gs_sid': 'DzQAV2gAAAAJ', 'organization': 'Zhejiang University', 'organization_code': '1118375729466322660', 'paper_num': 7, 'cites': {'years': ['2018', '2019', '2020', '2021', '2022'], 'cites': ['4', '18', '38', '87', '24']}, 'coauthors': None, 'name': 'Yang Liu', 'url': 'https://scholar.google.com/citations?hl=en&user=DzQAV2gAAAAJ', 'top_num_coauthors': None, 'num_domain': 1.0, 'top_topic_diversity': None, 'num_coauthors_all_wwo_ai': 20, 'organization_top': 0.0}, {'academic': False, 'academic_age': 18.0, 'academic_lifespan': 18.0, 'cit_sum_before_year': {'2006': 3, '2007': 6, '2008': 10, '2009': 14, '2010': 18, '2011': 35, '2012': 59, '2013': 84, '2014': 104, '2015': 123, '2016': 140, '2017': 150, '2018': 161, '2019': 169, '2020': 188, '2021': 216}, 'citation_table': ['226', '6'], 'domain_labels': ['biomedical_engineering', 'brain_computer_interfaces', 'evolutionary_computation', 'machine_learning', 'internet_of_things'], 'gender': '-', 'gs_sid': '0-Enuf0AAAAJ', 'organization': 'Microsensor Labs, LLC', 'organization_code': None, 'paper_num': 33, 'cites': {'years': ['2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], 'cites': ['3', '3', '4', '4', '4', '17', '24', '25', '20', '19', '17', '10', '11', '8', '19', '28', '8']}, 'coauthors': [['https://scholar.google.com/citations?user=rNkpg0cAAAAJ&hl=en', 'Jiapeng Huang', 'Professor of Anesthesiology & Perioperative Medicine', 'Verified email at louisville.edu'], ['https://scholar.google.com/citations?user=BCDqgloAAAAJ&hl=en', 'ERWEI YIN', 'PhD of Defense Innovation  Insititute', 'Verified email at nudt.edu.cn'], ['https://scholar.google.com/citations?user=zbPV2jgAAAAJ&hl=en', 'Qian Xu', 'University of Louisville', 'Verified email at louisville.edu']], 'name': 'Yang LIU (刘杨)', 'url': 'https://scholar.google.com/citations?hl=en&user=0-Enuf0AAAAJ', 'top_num_coauthors': 3.0, 'num_domain': 5.0, 'top_topic_diversity': 0.0, 'num_coauthors_all_wwo_ai': 40, 'organization_top': 0.0}, {'academic': False, 'academic_age': 10.0, 'academic_lifespan': 9.0, 'cit_sum_before_year': {'2014': 5, '2015': 18, '2016': 27, '2017': 40, '2018': 48, '2019': 89, '2020': 125, '2021': 195}, 'citation_table': ['218', '7'], 'domain_labels': ['optimization', 'transportation_systems', 'machine_learning'], 'gender': '-', 'gs_sid': 'B5NXocgAAAAJ', 'organization': 'Facebook, inc.', 'organization_code': '1978088699341142706', 'paper_num': 11, 'cites': {'years': ['2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], 'cites': ['5', '13', '9', '13', '8', '41', '36', '70', '23']}, 'coauthors': [['https://scholar.google.com/citations?user=Ks1yyXYAAAAJ&hl=en', 'Samitha Samaranayake', 'Cornell University', 'Verified email at alum.mit.edu'], ['https://scholar.google.com/citations?user=H7mK4S8AAAAJ&hl=en', 'prateek bansal', 'National University of Singapore', 'Verified email at nus.edu.sg'], ['https://scholar.google.com/citations?user=HaszNbkAAAAJ&hl=en', 'Ricardo Daziano', 'Cornell University', 'Verified email at cornell.edu'], ['https://scholar.google.com/citations?user=qH12Xy4AAAAJ&hl=en', 'Zhengbing He (贺正冰)', 'Beijing University of Technology', 'Verified email at bjut.edu.cn'], ['https://scholar.google.com/citations?user=Iq15MTUAAAAJ&hl=en', 'Xiaotong Guo', 'Graduate Student, MIT', 'Verified email at mit.edu'], ['https://scholar.google.com/citations?user=Pc9vG2AAAAAJ&hl=en', 'Ning Zhu', 'Tianjin University, College of Management and Economics', 'Verified email at tju.edu.cn'], ['https://scholar.google.com/citations?user=fgbQyncAAAAJ&hl=en', 'Ning Jia', 'Tianjin University', '']], 'name': 'Yang Liu (刘洋)', 'url': 'https://scholar.google.com/citations?hl=en&user=B5NXocgAAAAJ', 'top_num_coauthors': 7.0, 'num_domain': 3.0, 'top_topic_diversity': 0.0, 'num_coauthors_all_wwo_ai': 13, 'organization_top': 1.0}, {'academic': True, 'academic_age': 14.0, 'academic_lifespan': 14.0, 'cit_sum_before_year': {'2011': 22, '2012': 57, '2013': 122, '2014': 204, '2015': 306, '2016': 421, '2017': 497, '2018': 601, '2019': 797, '2020': 2114, '2021': 5081}, 'citation_table': ['6056', '26'], 'domain_labels': ['simulation', 'statistical_mechanics', 'thermodynamics', 'machine_learning', 'federated_learning'], 'gender': '-', 'gs_sid': 'JEieoFsAAAAJ', 'organization': 'Associate Professor at Tsinghua University', 'organization_code': '15442380624744264287', 'paper_num': 58, 'cites': {'years': ['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], 'cites': ['22', '35', '65', '82', '102', '115', '76', '104', '196', '1317', '2967', '913']}, 'coauthors': [['https://scholar.google.com/citations?user=1LxWZLQAAAAJ&hl=en', 'Qiang Yang (杨强）', 'Chief AI Officer@WeBank, Chair Prof.@HKUST, IJCAI President 2017-19, AAAI-21 General Chair', 'Verified email at cse.ust.hk'], ['https://scholar.google.com/citations?user=eXgoTXMAAAAJ&hl=en', 'Han Yu', 'Noneyang Assistant Professor, Noneyang Technological University, Singapore', 'Verified email at ntu.edu.sg'], ['https://scholar.google.com/citations?user=jHnL4RoAAAAJ&hl=en', 'Athanassios Z Panagiotopoulos', 'Susan Dod Brown Professor of Chemical and Biological Engineering, Princeton Univ.', 'Verified email at princeton.edu'], ['https://scholar.google.com/citations?user=kK2oqWMAAAAJ&hl=en', 'Pablo Debenedetti', 'Professor of Chemical and Biological Engineering, Princeton University', 'Verified email at princeton.edu'], ['https://scholar.google.com/citations?user=lFCXMMQAAAAJ&hl=en', 'Yan Kang', 'Lead Researcher at WeBank', 'Verified email at webank.com'], ['https://scholar.google.com/citations?user=_UDtZ_QAAAAJ&hl=en', 'Jeremy Palmer', 'University of Houston', 'Verified email at uh.edu'], ['https://scholar.google.com/citations?user=aeCHfDIAAAAJ&hl=en', 'Yongxin Tong（童咏昕）', 'Professor of Computer Science, Beihang University', 'Verified email at buaa.edu.cn'], ['https://scholar.google.com/citations?user=EiAVNhwAAAAJ&hl=en', 'Chaoping XING', 'Shanghai Jiaotong University', 'Verified email at sjtu.edu.cn'], ['https://scholar.google.com/citations?user=spq1_qEAAAAJ&hl=en', 'Roberto Car', 'Ralph W Dornte Professor in Chemistry, Princeton University ', 'Verified email at princeton.edu'], ['https://scholar.google.com/citations?user=9LPgsrUAAAAJ&hl=en', 'Fausto Martelli', 'IBM Research Europe', 'Verified email at ibm.com'], ['https://scholar.google.com/citations?user=qRnP-p0AAAAJ&hl=en', 'Mingyi Hong', 'Associate Professor, University of Minnesota', 'Verified email at umn.edu'], ['https://scholar.google.com/citations?user=aWx9D50AAAAJ&hl=en', 'Xi Weng', 'Professor of Economics, Guanghua School of Management, Peking University', 'Verified email at gsm.pku.edu.cn'], ['https://scholar.google.com/citations?user=T8sVhLMAAAAJ&hl=en', 'Dusit (Tao) Niyato', 'Noneyang Technological University (NTU)', 'Verified email at ntu.edu.sg'], ['https://scholar.google.com/citations?user=9Q8DH5sAAAAJ&hl=en', 'Dimitrios Papadopoulos', 'Hong Kong University of Science and Technology', 'Verified email at cse.ust.hk']], 'name': 'Yang (Veronica) Liu', 'url': 'https://scholar.google.com/citations?hl=en&user=JEieoFsAAAAJ', 'top_num_coauthors': 14.0, 'num_domain': 5.0, 'top_topic_diversity': 9.0, 'num_coauthors_all_wwo_ai': 114, 'organization_top': 0.0}]

# %%
tmp_d = {0:1, 2:3}
len(tmp_d.keys())
# Out:
# 2

# %%
tmp_long[6]
# Out:
# {'academic': False,
#  'academic_age': 13.0,
#  'academic_lifespan': 13.0,
#  'cit_sum_before_year': {'2014': 9,
#   '2015': 31,
#   '2016': 67,
#   '2017': 121,
#   '2018': 242,
#   '2019': 465,
#   '2020': 810,
#   '2021': 1488},
#  'citation_table': ['1664', '22'],
#  'domain_labels': ['crowdsourcing',
#   'machine_learning',
#   'incentive_and_consensus'],
#  'gender': 'F',
#  'gs_sid': 'jKrIVCIAAAAJ',
#  'organization': 'Computer Science and Engineering, UC Santa Cruz',
#  'organization_code': '6192028974562668508',
#  'paper_num': 74,
#  'cites': {'years': ['2014',
#    '2015',
#    '2016',
#    '2017',
#    '2018',
#    '2019',
#    '2020',
#    '2021',
#    '2022'],
#   'cites': ['9', '22', '36', '54', '121', '223', '345', '678', '153']},
#  'coauthors': [['https://scholar.google.com/citations?user=WiIM-MgAAAAJ&hl=en',
#    'Mingyan Liu',
#    'Professor of Electrical Engineering and Computer Science, University of Michigan',
#    'Verified email at umich.edu'],
# ...

# %%
resp_list, id_list = [], []
for id, item in scholar_search.openreview_profile.items():
    print(f'processing {id}')
    resp = scholar_search.get_scholar(query=item, simple=True, top_n=3, print_true=True)
    resp_list.append(resp)
    id_list.append(id)
# Out:
# processing ~Lam_M_Nguyen1
# [Info] Found a scholar using 78k gs_sid
# [Info] In total 1 scholar is found:
# [
#   {
#     "academic": false,
#     "academic_age": 9.0,
#     "academic_lifespan": 9.0,
#     "cit_sum_before_year": {
#       "2015": 4,
#       "2016": 12,
#       "2017": 25,
#       "2018": 96,
#       "2019": 259,
#       "2020": 585,
#       "2021": 981
#     },
#     "citation_table": [
#       "1064",
#       "14"
#     ],
#     "domain_labels": [
#       "optimization",
#       "machine learning"
#     ],
#     "gender": "-",
#     "gs_sid": "DeFL5Q8AAAAJ",
#     "organization": "Research Staff Member at IBM Research, Thomas J. Watson Research Center; PI of MIT-IBM Watson AI Lab",
#     "organization_code": null,
#     "paper_num": 56,
#     "cites": {
#       "years": [
#         "2015",
#         "2016",
#         "2017",
#         "2018",
#         "2019",
#         "2020",
#         "2021",
#         "2022"
#       ],
#       "cites": [
#         "4",
# ...

# %%
with open('tmp/resp_list_0729v3.json', 'w') as file:
    json.dump(resp_list, file, indent=2)
# with open('tmp/id_list_0729v3.json', 'w') as file:
#     json.dump(id_list, file, indent=2)

# %%
cnt_gt1, cnt_0 = 0, 0
for item in resp_list:
    if len(item) == 0:
        cnt_0 += 1

# %%
cnt1 = 0
cnt2 = 0
cnt3 = 0
hand_list = []
for id, item in scholar_search.openreview_profile.items():
    if 'gscholar' in item['profile']['content']:
        if 'user' in item['profile']['content']['gscholar']:
            cnt1+=1
        else:
            cnt2+=1
            hand_list.append(id)
            print(id, item['profile']['content']['gscholar'])
    else:
        cnt3+=1
        hand_list.append(id)
cnt1, cnt2, cnt3
# Out:
# ~Zied_Eloudi1
# ~Shuai_Li2
# ~Philip_Versteeg1
# ~Philippe_Leray1
# ~Olivier_Spanjaard1
# ~Luigi_Portinale1
# ~Rafael_Rumi1
# ~Richang_Hong1 https://scholar.google.com/scholar?hl=en&as_sdt=0%2C5&q=Richang+Hong&oq=
# ~Mohamed_Daoudi2 https://scholar.google.fr/scholar?hl=fr&q=daoudi+mohamed&btnG=&lr=
# ~Simon_de_GIVRY1
# ~Véronique_Delcroix1 https://scholar.google.com/scholar?q=V%C3%A9ronique+Delcroix
# (444, 11, 189)

# %%
hand_list
# Out:
# ['~Prakash_P_Shenoy1',
#  '~Vibhav_Giridhar_Gogate1',
#  '~Qiang_Ji1',
#  '~Biwei_Huang1',
#  '~Alex_Luedtke1',
#  '~Yang_Liu3',
#  '~Aurelie_Lozano1',
#  '~Brandon_Malone1',
#  '~Rajesh_Ranganath2',
#  '~Peter_Spirtes1',
#  '~Andrej_Risteski2',
#  '~Frederick_Eberhardt1',
#  '~Ilya_Shpitser1',
#  '~Xiangchen_Song1',
#  '~Nevin_L_Zhang1',
#  '~Zhiao_Huang1',
#  '~Lu_Cheng2',
#  '~Yue_Zhang7',
#  '~Badong_Chen1',
#  '~Thomas_Krak1',
#  '~William_Herlands1',
#  '~Linbo_Liu1',
#  '~Yuliya_Shapovalova1',
#  '~Aurélie_Beynier2',
#  '~Bryan_Andrews1',
#  '~Jussi_Rintanen1',
#  '~Benito_van_der_Zander1',
#  '~Zied_Eloudi1',
#  '~David_Strieder1',
#  '~Britta_Velten1',
#  '~Zhou_Dawei1',
#  '~Jingfeng_Zhang1',
#  '~Phillip_Bredahl_Mogensen1',
#  '~Panayiotis_V._Benos1',
#  '~Leon_Van_der_Torre2',
#  '~Christine_Sinoquet1',
#  '~Armen_Aghasaryan1',
#  '~Rong_Zhu4',
#  '~Khaled_S._Refaat1',
#  '~Joseph_Ramsey1',
#  '~Feng_Xie1',
#  '~Shuai_Li2',
#  '~Subhojyoti_Mukherjee1',
#  '~Jin_Sima1',
# ...

# %%
import re
match = re.search(r'[\w-]+\.[\w.-]+', "ucsc.edu")
email_str = match.group(0)

# %%
email_str
# Out:
# 'ucsc.edu'

# %%
cnt = 0
for resp in resp_list:
    if len(resp) != 0:
        cnt += 1

# %%
cnt
# Out:
# 353

# %%
scholar_search.cnt_find_gs_78k, scholar_search.cnt_find_gs_crawl
# Out:
# (270, 174)

# %%
scholar_gs = ScholarGsSearch()

# %%
total_list = scholar_search.openreview_profile.keys()

# %%
scholar_gs.get_scholar(total_list)

# %%
import requests
# _AUTHSEARCH = 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors={0}'
_AUTHSEARCH = 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors={0}'
# _AUTHSEARCH.format(requests.utils.quote('Marty Banks, Berkeley'))

# %%
url_list = []
for key in total_list:
    url_item = []
    name = change_name(key)
    if 'gscholar' in total_list[key]['profile']['content']['gscholar']:
        
    position, school = None, None
    if 'position' in total_list[key]['profile']['content']['history'][0]:
        position = total_list[key]['profile']['content']['history'][0]['position']
    if ('institution' in total_list[key]['profile']['content']['history'][0] and 
        'name' in total_list[key]['profile']['content']['history'][0]['institution']):
        school = total_list[key]['profile']['content']['history'][0]['institution']['name']
    url_item.append('authsearch')
    url_item.append(_AUTHSEARCH.format(requests.utils.quote(name)))
    url_list.append()

# %%
import json
import requests
from bs4 import BeautifulSoup

# %%
with open('tmp/url_list.json', 'w') as file:
    json.dump(url_list, file, indent=2)

# %%
'https://scholar.google.com/citations?hl=en&user={0}'.format('what')
# Out:
# 'https://scholar.google.com/citations?hl=en&user=what'

# %%
res = BeautifulSoup('https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=', 'html.parser')
# Out:
# /home/ljrjerry/miniconda3/envs/env37/lib/python3.7/site-packages/bs4/__init__.py:408: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning

# %%
response = requests.get('https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=Yi Hao ucsd.edu PhD student University of California, San Diego ')
resp_str = response.content.decode('utf-8', errors='ignore')
soup = BeautifulSoup(resp_str, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find_all(class_='gs_ai_t')[0]
# Out:
# <div class="gs_ai_t"><h3 class="gs_ai_name"><a href="/citations?hl=en&amp;user=sTmPxa4AAAAJ"><span class="gs_hlt">Yi Hao</span></a></h3><div class="gs_ai_aff"><span class="gs_hlt">Ph</span>.<span class="gs_hlt">D</span>. <span class="gs_hlt">student</span>, <span class="gs_hlt">University </span>of <span class="gs_hlt">California</span>, <span class="gs_hlt">San Diego</span></div><div class="gs_ai_eml">Verified email at eng.<span class="gs_hlt">ucsd</span>.<span class="gs_hlt">edu</span></div><div class="gs_ai_cby">Cited by 1081</div><div class="gs_ai_int"><a class="gs_ai_one_int" href="/citations?hl=en&amp;view_op=search_authors&amp;mauthors=label:machine_learning">machine learning</a> <a class="gs_ai_one_int" href="/citations?hl=en&amp;view_op=search_authors&amp;mauthors=label:optimization_theory">optimization theory</a> <a class="gs_ai_one_int" href="/citations?hl=en&amp;view_op=search_authors&amp;mauthors=label:information_theory">information theory</a> <a class="gs_ai_one_int" h
# ...

# %%
soup.find_all(class_='gs_ai_t')[0].find_all(class_='gs_ai_aff').get_attribute('textContent')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_14323/1702980131.py in <module>
# ----> 1 soup.find_all(class_='gs_ai_t')[0].find_all(class_='gs_ai_aff').get_attribute('textContent')
#
# IndexError: list index out of range

# %%
soup.find_all(class_='gs_ai_t')[0].find_all(class_='gs_ai_eml')
# Out:
# [<div class="gs_ai_eml">Verified email at eng.<span class="gs_hlt">ucsd</span>.<span class="gs_hlt">edu</span></div>]

# %%
response = requests.get('https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=Yi+Hao')
resp_str = response.content.decode('utf-8', errors='ignore')
soup = BeautifulSoup(resp_str, 'html.parser')

# %%
soup.find_all(class_='gs_ai_t')
# Out:
# [<div class="gs_ai_t"><h3 class="gs_ai_name"><a href="/citations?hl=en&amp;user=Du9R7QwAAAAJ"><span class="gs_hlt">Hao</span>-<span class="gs_hlt">Yi </span>Wu</a></h3><div class="gs_ai_aff">Boise State University</div><div class="gs_ai_eml">Verified email at boisestate.edu</div><div class="gs_ai_cby">Cited by 3388</div><div class="gs_ai_int"><a class="gs_ai_one_int" href="/citations?hl=en&amp;view_op=search_authors&amp;mauthors=label:cosmology">cosmology</a> <a class="gs_ai_one_int" href="/citations?hl=en&amp;view_op=search_authors&amp;mauthors=label:astrophysics">astrophysics</a> </div></div>,
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import ChromiumOptions
from selenium.webdriver.common.by import By
options = ChromiumOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
# options.binary_location = '/opt/google/chrome/chrome'

driver = webdriver.Chrome('../chromedriver', options=options)
driver.execute_cdp_cmd("Page.addScriptToEvaluateOnNewDocument", {
    "source": "Object.defineProperty(navigator, 'webdriver', {get: () => undefined})"
})
# Out:
# /mnt/d/prog/anaconda3/envs/res/lib/python3.7/site-packages/ipykernel_launcher.py:12: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   if sys.path[0] == "":
# {'identifier': '2'}

# %%
driver.get('https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=Yi+Hao')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# /tmp/ipykernel_8288/917001929.py in <module>
# ----> 1 driver.get('https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=Yi+Hao')
#
# /mnt/d/prog/anaconda3/envs/res/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     445         Loads a web page in the current browser session.
#     446         """
# --> 447         self.execute(Command.GET, {'url': url})
#     448
#     449     @property
#
# /mnt/d/prog/anaconda3/envs/res/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     433         response = self.command_executor.execute(driver_command, params)
#     434         if response:
# --> 435             self.error_handler.check_response(response)
#     436             response['value'] = self._unwrap_value(
# ...

# %%
useful_info = driver.find_elements(By.CLASS_NAME, 'gs_ai_t')

# %%
useful_info
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="033157513d9340cc9786e2b59859a4d3", element="a18de065-796d-474b-9ee1-60906c165262")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="033157513d9340cc9786e2b59859a4d3", element="f69e9d22-24af-4391-ae07-b7207dbe3508")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="033157513d9340cc9786e2b59859a4d3", element="a5781d16-666d-4d46-b447-b4ed00710b6c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="033157513d9340cc9786e2b59859a4d3", element="083d8f43-ed44-4b53-b45d-f65b5197df97")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="033157513d9340cc9786e2b59859a4d3", element="06510083-3401-498d-8769-26c0aacd65c0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="033157513d9340cc9786e2b59859a4d3", element="0f1b913e-0acd-4f28-bb31-a53ec24670a9")>,
# ...

# %%
useful_info.find_element(By.CLASS_NAME, 'gs_ai_eml').get_attribute('textContent')
# Out:
# 'Verified email at eng.ucsd.edu'

# %%
url = useful_info[0].find_element(By.CLASS_NAME, 'gs_ai_name').find_element(By.TAG_NAME, 'a')

# %%
url.get_attribute('href')
# Out:
# 'https://scholar.google.com/citations?hl=en&user=Du9R7QwAAAAJ'

# %%
import re
line = 'Verified email at eng.ucsd.edu'
match = re.search(r'[\w-]+\.[\w.-]+', line)
match.group(0)
# Out:
# 'eng.ucsd.edu'

# %%
driver.get('https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=Yi+Hao+ghhdfgbf&btn')

# %%
useful_info[0].find_element(By.CLASS_NAME, 'gs_ai_name').get_attribute('textContent')
# Out:
# 'Hao-Yi Wu'

# %%
sgs = ScholarGsSearch()

# %%
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
options = Options()
# 隐藏 正在受到自动软件的控制 这几个字
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
# options.binary_location = '/usr/bin/google-chrome'

driver = webdriver.Chrome(executable_path='/home/hermione/src/research/chromedriver', options=options)
# Out:
# /mnt/d/prog/anaconda3/envs/res/lib/python3.7/site-packages/ipykernel_launcher.py:12: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   if sys.path[0] == "":

# %%
sgs.search_gsid('RkI8h-wAAAAJ')
# Out:
# {'url': 'https://scholar.google.com/citations?hl=en&user=RkI8h-wAAAAJ',
#  'co_authors': [['https://scholar.google.com/citations?user=x5QTK9YAAAAJ&hl=en',
#    'Di Jin',
#    'Applied Scientist of Amazon Alexa AI',
#    'Verified email at mit.edu'],
#   ['https://scholar.google.com/citations?user=1LuGqFQAAAAJ&hl=en',
#    'Peter Szolovits',
#    'Professor of Computer Science and Engineering, MIT',
#    'Verified email at mit.edu'],
#   ['https://scholar.google.com/citations?user=nzJFv0IAAAAJ&hl=en',
#    'Enrico Santus',
#    'Massachusetts Institute of Technology (MIT)',
#    'Verified email at mit.edu'],
#   ['https://scholar.google.com/citations?user=93a-9kkAAAAJ&hl=en',
#    'Yujie Qian',
#    'Massachusetts Institute of Technology',
#    'Verified email at csail.mit.edu'],
#   ['https://scholar.google.com/citations?user=Pq4Yp_kAAAAJ&hl=en',
#    'Xipeng Qiu（邱锡鹏）',
#    'Professor of Computer Science, Fudan University',
#    'Verified email at fudan.edu.cn'],
# ...

# %%
with open('tmp/resp_list_new.json') as file:
    resp_list = json.load(file)
with open('tmp/id_list_new.json') as file:
    id_list = json.load(file)

# %%
csv_list = []
for resp, id in zip(resp_list, id_list):
    if len(resp) >= 1:
        csv_list.append({
            'openreview_id': id,
            'gs_sid': resp[0]['gs_sid'] if 'gs_sid' in resp[0] else None,
            'citation': resp[0]['citation_table'][0]
        })
    else:
        csv_list.append({
            'openreview_id': id,
            'gs_sid':  None,
            'citation': None
        })

# %%
csv_list
# Out:
# [{'openreview_id': '~Lam_M_Nguyen1',
#   'gs_sid': 'DeFL5Q8AAAAJ',
#   'citation': '1064'},
#  {'openreview_id': '~Bo_Liu2', 'gs_sid': '8MliTo4AAAAJ', 'citation': '1674'},
#  {'openreview_id': '~Tongliang_Liu1',
#   'gs_sid': 'EiLdZ_YAAAAJ',
#   'citation': '6056'},
#  {'openreview_id': '~Shohei_Shimizu1',
#   'gs_sid': 'OpLI4xcAAAAJ',
#   'citation': '2971'},
#  {'openreview_id': '~Prakash_P_Shenoy1',
#   'gs_sid': '3r7dSLAAAAAJ',
#   'citation': '8324'},
#  {'openreview_id': '~Ruichu_Cai1',
#   'gs_sid': 'gG4HJ4UAAAAJ',
#   'citation': '1528'},
#  {'openreview_id': '~Vibhav_Giridhar_Gogate1',
#   'gs_sid': 'pm_dg3cAAAAJ',
#   'citation': '2082'},
#  {'openreview_id': '~Hanwang_Zhang3',
#   'gs_sid': 'YG0DFyYAAAAJ',
#   'citation': '13452'},
#  {'openreview_id': '~Quanquan_Gu1',
#   'gs_sid': 'GU9HgNAAAAAJ',
#   'citation': '11114'},
#  {'openreview_id': '~Jin_Tian1', 'gs_sid': 'T0crkfoAAAAJ', 'citation': '2131'},
#  {'openreview_id': '~Branislav_Kveton1',
# ...

# %%
csv_df = pd.DataFrame.from_dict(csv_list)
csv_df.to_csv('tmp/gs_citations_20220729v3.csv', index=False)
