# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # google scholar search

# %%
import pandas as pd
import numpy as np
import pickle
import json

# %%
from ScholarSearch import ScholarSearch

# %%
scholar_search = ScholarSearch()

# %%
scholar_search.setup()

# %%
resp = scholar_search.get_scholar(query='Ali Boyali', simple=True, top_n=1, print_true=True)
resp
# Out:
# [Info] Found 1 scholars are in 78k data.
# [Debug] Names: 0    Ali BOYALI
# Name: name, dtype: object
# [Info] Find 1 scholars using query without gs_sid in step 4.
# [Info] In total 1 scholar is found:
# [
#   {
#     "url": "https://scholar.google.com/citations?hl=en&user=Dmh5d3wAAAAJ",
#     "gs_sid": "Dmh5d3wAAAAJ",
#     "coauthors": [
#       [
#         "https://scholar.google.com/citations?user=uMLdqe8AAAAJ&hl=en",
#         "Naohisa Hashimoto",
#         "National Institute of Advanced Industrial Science and Technology",
#         "Verified email at aist.go.jp"
#       ],
#       [
#         "https://scholar.google.com/citations?user=Wv71RXYAAAAJ&hl=en",
#         "Vijay John",
#         "RIKEN",
#         "Verified email at riken.jp"
#       ],
#       [
#         "https://scholar.google.com/citations?user=xsE_V84AAAAJ&hl=en",
#         "Levent Guvenc",
#         "Professor of Mechanical and Aerospace Engineering, Ohio State University",
#         "Verified email at osu.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=_b0Z-X0AAAAJ&hl=en",
#         "Manolya Kavakli-Thorne",
#         "Honorary Professor of Computer Science, Macquarie University",
#         "Verified email at mq.edu.au"
#       ],
#       [
#         "https://scholar.google.com/citations?user=XAwrzbYAAAAJ&hl=en",
#         "Alexey Kashevnik",
#         "SPC RAS (\u0421\u041f\u0431 \u0424\u0418\u0426 \u0420\u0410\u041d); ITMO University (\u0423\u043d\u0438\u0432\u0435\u0440\u0441\u0438\u0442\u0435\u0442 \u0418\u0422\u041c\u041e)",
#         "Verified email at iias.spb.su"
#       ],
#       [
#         "https://scholar.google.com/citations?user=yWLL23EAAAAJ&hl=en",
#         "Kohji Tomita",
#         "National Institute of Advanced Industrial Science and Technology (AIST)",
#         "Verified email at aist.go.jp"
#       ],
#       [
#         "https://scholar.google.com/citations?user=lVbzSpEAAAAJ&hl=en",
#         "Dr. Murat Demirci",
#         "FEV Turkey",
#         "Verified email at fev.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=RmYzDu4AAAAJ&hl=en",
#         "Jason Twamley",
#         "Quantum Machines Unit, Okinawa University of Science and Technology",
#         "Verified email at oist.jp"
#       ],
#       [
#         "https://scholar.google.com/citations?user=Q23gJB8AAAAJ&hl=en",
#         "Shin Kato",
#         "National Institute of Advanced Industrial Science and Technology (AIST)",
#         "Verified email at aist.go.jp"
#       ],
#       [
#         "https://scholar.google.com/citations?user=c_WcJWEAAAAJ&hl=en",
#         "Zheng Liu",
#         "University of British Columbia (Okanagan)",
#         "Verified email at ubc.ca"
#       ],
#       [
#         "https://scholar.google.com/citations?user=Wh81q8YAAAAJ&hl=en",
#         "Hossein T Tehrani",
#         "University of Nevada, Las Vegas",
#         "Verified email at unlv.nevada.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=KBYr23EAAAAJ&hl=en",
#         "S S Rathour",
#         "PD",
#         "Verified email at toyota-ti.ac.jp"
#       ],
#       [
#         "https://scholar.google.com/citations?user=cwl2lDIAAAAJ&hl=en",
#         "Annamalai Lakshmanan",
#         "MSc EEIT Student @ ETH Z\u00fcrich",
#         "Verified email at student.ethz.ch"
#       ],
#       [
#         "https://scholar.google.com/citations?user=fvq0BZsAAAAJ&hl=en",
#         "Hessam Jahani",
#         "PhD Researcher, Macquarie university",
#         "Verified email at hdr.mq.edu.au"
#       ],
#       [
#         "https://scholar.google.com/citations?user=lW0WVXEAAAAJ&hl=en",
#         "Simon Thompson",
#         "Tier IV, Inc",
#         "Verified email at tier4.jp"
#       ],
#       [
#         "https://scholar.google.com/citations?user=rZbIjowAAAAJ&hl=en",
#         "Sadayuki Tsugawa",
#         "Meijo University retired",
#         "Verified email at meijo-u.ac.jp"
#       ],
#       [
#         "https://scholar.google.com/citations?user=bD-68sXlVEgC&hl=en",
#         "David Robert Wong",
#         "Designated Assistant Professor, Nagoya University",
#         "Verified email at lifecyclist.co.nz"
#       ],
#       [
#         "https://scholar.google.com/citations?user=NeBqqSwAAAAJ&hl=en",
#         "Ariya Terani",
#         "Sensors & Automated Driving Expert",
#         ""
#       ],
#       [
#         "https://scholar.google.com/citations?user=2iYlCzwAAAAJ&hl=en",
#         "Kiminori Sato",
#         "Department of Environmental Sciences, Tokyo Gakugei University",
#         "Verified email at u-gakugei.ac.jp"
#       ]
#     ],
#     "citation_table": [
#       "519",
#       "11"
#     ],
#     "cites": {
#       "years": [
#         "2006",
#         "2007",
#         "2008",
#         "2009",
#         "2010",
#         "2011",
#         "2012",
#         "2013",
#         "2014",
#         "2015",
#         "2016",
#         "2017",
#         "2018",
#         "2019",
#         "2020",
#         "2021",
#         "2022"
#       ],
#       "cites": [
#         "3",
#         "3",
#         "10",
#         "8",
#         "10",
#         "8",
#         "16",
#         "6",
#         "15",
#         "38",
#         "38",
#         "43",
#         "71",
#         "77",
#         "69",
#         "63",
#         "38"
#       ]
#     },
#     "name": "Ali BOYALI",
#     "organization": "Toyota Technological Institute",
#     "homepage_url": null,
#     "email_info": "toyota-ti.ac.jp",
#     "domain_labels": [
#       "autonomous vehicles",
#       "planning and control",
#       "signal processing",
#       "machine learning"
#     ],
#     "extra_co_authors": []
#   }
# ]
# [{'url': 'https://scholar.google.com/citations?hl=en&user=Dmh5d3wAAAAJ',
#   'gs_sid': 'Dmh5d3wAAAAJ',
#   'coauthors': [['https://scholar.google.com/citations?user=uMLdqe8AAAAJ&hl=en',
#     'Naohisa Hashimoto',
#     'National Institute of Advanced Industrial Science and Technology',
#     'Verified email at aist.go.jp'],
#    ['https://scholar.google.com/citations?user=Wv71RXYAAAAJ&hl=en',
#     'Vijay John',
#     'RIKEN',
#     'Verified email at riken.jp'],
#    ['https://scholar.google.com/citations?user=xsE_V84AAAAJ&hl=en',
#     'Levent Guvenc',
#     'Professor of Mechanical and Aerospace Engineering, Ohio State University',
#     'Verified email at osu.edu'],
#    ['https://scholar.google.com/citations?user=_b0Z-X0AAAAJ&hl=en',
#     'Manolya Kavakli-Thorne',
#     'Honorary Professor of Computer Science, Macquarie University',
#     'Verified email at mq.edu.au'],
#    ['https://scholar.google.com/citations?user=XAwrzbYAAAAJ&hl=en',
#     'Alexey Kashevnik',
#     'SPC RAS (СПб ФИЦ РАН); ITMO University (Университет ИТМО)',
#     'Verified email at iias.spb.su'],
#    ['https://scholar.google.com/citations?user=yWLL23EAAAAJ&hl=en',
#     'Kohji Tomita',
#     'National Institute of Advanced Industrial Science and Technology (AIST)',
#     'Verified email at aist.go.jp'],
#    ['https://scholar.google.com/citations?user=lVbzSpEAAAAJ&hl=en',
#     'Dr. Murat Demirci',
#     'FEV Turkey',
#     'Verified email at fev.com'],
#    ['https://scholar.google.com/citations?user=RmYzDu4AAAAJ&hl=en',
#     'Jason Twamley',
#     'Quantum Machines Unit, Okinawa University of Science and Technology',
#     'Verified email at oist.jp'],
#    ['https://scholar.google.com/citations?user=Q23gJB8AAAAJ&hl=en',
#     'Shin Kato',
#     'National Institute of Advanced Industrial Science and Technology (AIST)',
#     'Verified email at aist.go.jp'],
#    ['https://scholar.google.com/citations?user=c_WcJWEAAAAJ&hl=en',
#     'Zheng Liu',
#     'University of British Columbia (Okanagan)',
#     'Verified email at ubc.ca'],
#    ['https://scholar.google.com/citations?user=Wh81q8YAAAAJ&hl=en',
#     'Hossein T Tehrani',
#     'University of Nevada, Las Vegas',
#     'Verified email at unlv.nevada.edu'],
#    ['https://scholar.google.com/citations?user=KBYr23EAAAAJ&hl=en',
#     'S S Rathour',
#     'PD',
#     'Verified email at toyota-ti.ac.jp'],
#    ['https://scholar.google.com/citations?user=cwl2lDIAAAAJ&hl=en',
#     'Annamalai Lakshmanan',
#     'MSc EEIT Student @ ETH Zürich',
#     'Verified email at student.ethz.ch'],
#    ['https://scholar.google.com/citations?user=fvq0BZsAAAAJ&hl=en',
#     'Hessam Jahani',
#     'PhD Researcher, Macquarie university',
#     'Verified email at hdr.mq.edu.au'],
#    ['https://scholar.google.com/citations?user=lW0WVXEAAAAJ&hl=en',
#     'Simon Thompson',
#     'Tier IV, Inc',
#     'Verified email at tier4.jp'],
#    ['https://scholar.google.com/citations?user=rZbIjowAAAAJ&hl=en',
#     'Sadayuki Tsugawa',
#     'Meijo University retired',
#     'Verified email at meijo-u.ac.jp'],
#    ['https://scholar.google.com/citations?user=bD-68sXlVEgC&hl=en',
#     'David Robert Wong',
#     'Designated Assistant Professor, Nagoya University',
#     'Verified email at lifecyclist.co.nz'],
#    ['https://scholar.google.com/citations?user=NeBqqSwAAAAJ&hl=en',
#     'Ariya Terani',
#     'Sensors & Automated Driving Expert',
#     ''],
#    ['https://scholar.google.com/citations?user=2iYlCzwAAAAJ&hl=en',
#     'Kiminori Sato',
#     'Department of Environmental Sciences, Tokyo Gakugei University',
#     'Verified email at u-gakugei.ac.jp']],
#   'citation_table': ['519', '11'],
#   'cites': {'years': ['2006',
#     '2007',
#     '2008',
#     '2009',
#     '2010',
#     '2011',
#     '2012',
#     '2013',
#     '2014',
#     '2015',
#     '2016',
#     '2017',
#     '2018',
#     '2019',
#     '2020',
#     '2021',
#     '2022'],
#    'cites': ['3',
#     '3',
#     '10',
#     '8',
#     '10',
#     '8',
#     '16',
#     '6',
#     '15',
#     '38',
#     '38',
#     '43',
#     '71',
#     '77',
#     '69',
#     '63',
#     '38']},
#   'name': 'Ali BOYALI',
#   'organization': 'Toyota Technological Institute',
#   'homepage_url': None,
#   'email_info': 'toyota-ti.ac.jp',
#   'domain_labels': ['autonomous vehicles',
#    'planning and control',
#    'signal processing',
#    'machine learning'],
#   'extra_co_authors': []}]

# %% [markdown]
# # Run csv test

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from TwitterSearch import TwitterSearch

# %%
ts = TwitterSearch('../chromedriver')

# %%
# first 460 are hand-labeled
df = pd.read_csv('tmp/gs_scholars_matched_with_twitter_accounts_500 - gs_scholars_1k.csv', index_col=0)

# %%
name_list = df.head(460)['name'].values.tolist()

# %%
ts.search_scholar('name', 'Shayan Shams')
# Out:
# [Info] Found 1 scholars are in 78k data.
# [Debug] Names: 0    Shayan Shams
# Name: name, dtype: object
# [Info] Find 1 scholars using query without gs_sid in step 4.
# [Info] In total 1 scholar is found:
# [
#   {
#     "url": "https://scholar.google.com/citations?hl=en&user=KPB33b8AAAAJ",
#     "gs_sid": "KPB33b8AAAAJ",
#     "coauthors": [
#       [
#         "https://scholar.google.com/citations?user=AEJSH4UAAAAJ&hl=en",
#         "Seung-Jong Park",
#         "Professor of Computer Science, Louisiana State University",
#         "Verified email at cct.lsu.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=LLrlZC8AAAAJ&hl=en",
#         "Kisung Lee",
#         "Louisiana State University (LSU)",
#         "Verified email at lsu.edu"
#       ]
#     ],
#     "citation_table": [
#       "338",
#       "8"
#     ],
#     "cites": {
#       "years": [
#         "2014",
#         "2015",
#         "2016",
#         "2017",
#         "2018",
#         "2019",
#         "2020",
#         "2021",
#         "2022"
#       ],
#       "cites": [
#         "6",
#         "4",
#         "7",
#         "21",
#         "41",
#         "65",
#         "102",
#         "87"
#       ]
#     },
#     "name": "Shayan Shams",
#     "organization": "Assistant Professor at University of Texas Health Science Center at Houston",
#     "homepage_url": "https://sbmi.uth.edu/faculty-and-staff/shayan-shams.htm",
#     "email_info": "uth.tmc.edu",
#     "domain_labels": [
#       "artificial intelligence",
#       "deep learning",
#       "computer vision",
#       "health care",
#       "computational biology"
#     ],
#     "extra_co_authors": []
#   }
# ]
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# /tmp/ipykernel_2149/723095346.py in <module>
# ----> 1 ts.search_scholar('name', 'Shayan Shams')
#
# ~/src/research/ai-scholar-toolbox/TwitterSearch.py in search_scholar(self, str_type, term)
#      48                 # try directly get twitter account through homepage
#      49                 if 'homepage_url' in scholar_search_result[0] and scholar_search_result[0]['homepage_url'] is not None:
# ---> 50                     twitter_ids = self._search_twitter_from_homepage(scholar_search_result[0]['homepage_url'], name=term, name_from_gs=scholar_search_result[0]["name"])
#      51                 if twitter_ids is not None:
#      52                     branch_type = 'homepage'
#
# ~/src/research/ai-scholar-toolbox/TwitterSearch.py in _search_twitter_from_homepage(self, homepage_url, name, name_from_gs)
#     144     def _search_twitter_from_homepage(self, homepage_url: str, name: str=None, name_from_gs: str=None):
#     145         # get content of scholar homepage using chromedriver
# --> 146         self.driver.get(homepage_url)
#     147         time.sleep(3)
#     148
#
# /mnt/d/prog/anaconda3/envs/res/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     445         Loads a web page in the current browser session.
#     446         """
# --> 447         self.execute(Command.GET, {'url': url})
#     448
#     449     @property
#
# /mnt/d/prog/anaconda3/envs/res/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     433         response = self.command_executor.execute(driver_command, params)
#     434         if response:
# --> 435             self.error_handler.check_response(response)
#     436             response['value'] = self._unwrap_value(
#     437                 response.get('value', None))
#
# /mnt/d/prog/anaconda3/envs/res/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: unknown error: net::ERR_CONNECTION_RESET
#   (Session info: headless chrome=103.0.5060.134)
# Stacktrace:
# #0 0x5610c87bacd3 <unknown>
# #1 0x5610c85c2968 <unknown>
# #2 0x5610c85bc745 <unknown>
# #3 0x5610c85af096 <unknown>
# #4 0x5610c85b0032 <unknown>
# #5 0x5610c85af362 <unknown>
# #6 0x5610c85ae795 <unknown>
# #7 0x5610c85ad45f <unknown>
# #8 0x5610c85ad8c2 <unknown>
# #9 0x5610c85c43c2 <unknown>
# #10 0x5610c862b60f <unknown>
# #11 0x5610c8617bb2 <unknown>
# #12 0x5610c862aea8 <unknown>
# #13 0x5610c8617aa3 <unknown>
# #14 0x5610c85ed3fa <unknown>
# #15 0x5610c85ee555 <unknown>
# #16 0x5610c88022bd <unknown>
# #17 0x5610c8806418 <unknown>
# #18 0x5610c87ec36e <unknown>
# #19 0x5610c8807078 <unknown>
# #20 0x5610c87e0bb0 <unknown>
# #21 0x5610c8823d58 <unknown>
# #22 0x5610c8823ed8 <unknown>
# #23 0x5610c883dcfd <unknown>
# #24 0x7f333f3f9609 <unknown>

# %%
result_name_list = ts.search_scholar_batch(name_list)
# Out:
# [Info] Found 1 scholars are in 78k data.
# [Debug] Names: 0    Sebastian Gerke
# Name: name, dtype: object
# [Info] Find 2 scholars using query without gs_sid in step 4.
# [Info] In total 1 scholar is found:
# [
#   {
#     "academic": false,
#     "academic_age": 18.0,
#     "academic_lifespan": 16.0,
#     "cit_sum_before_year": {
#       "2005": 1,
#       "2006": 2,
#       "2007": 17,
#       "2008": 33,
#       "2009": 45,
#       "2010": 62,
#       "2011": 81,
#       "2012": 110,
#       "2013": 129,
#       "2014": 155,
#       "2015": 166,
#       "2016": 183,
#       "2017": 207,
#       "2018": 231,
#       "2019": 249,
#       "2020": 266,
#       "2021": 288
#     },
#     "citation_table": [
#       "297",
#       "8"
#     ],
#     "domain_labels": [
#       "computer vision",
#       "machine learning",
#       "content based multimedia retrieval"
#     ],
#     "gender": "M",
#     "gs_sid": "DeP0anAAAAAJ",
#     "organization": "Ree Technology",
#     "organization_code": null,
#     "paper_num": 21,
#     "cites": {
#       "years": [
#         "2005",
#         "2006",
#         "2007",
#         "2008",
#         "2009",
#         "2010",
#         "2011",
#         "2012",
#         "2013",
#         "2014",
#         "2015",
#         "2016",
#         "2017",
#         "2018",
#         "2019",
#         "2020",
#         "2021",
#         "2022"
#       ],
#       "cites": [
#         "1",
#         "1",
#         "15",
#         "16",
#         "12",
#         "17",
#         "19",
#         "29",
#         "19",
#         "26",
#         "11",
#         "17",
#         "24",
#         "24",
#         "18",
#         "17",
#         "22",
#         "6"
#       ]
#     },
#     "coauthors": null,
#     "name": "Sebastian Gerke",
#     "url": "https://scholar.google.com/citations?hl=en&user=DeP0anAAAAAJ",
#     "top_num_coauthors": NaN,
#     "num_domain": 3.0,
#     "top_topic_diversity": NaN,
#     "num_coauthors_all_wwo_ai": 25,
#     "organization_top": 0.0
#   }
# ]
# [{'href': 'https://twitter.com/sg_gehrke/status/908605955851595776', 'title': 'Sebastian Gehrke on Twitter: "We are hiring smart, talented ...', 'description': 'Sep 15, 2017 — Sebastian Gehrke on Twitter: "We are hiring smart, talented, ambitious, and passionate team members who will contribute to our company\'s\xa0...'}, {'href': 'https://tracxn.com/d/companies/terraloupe.com', 'title': 'Terraloupe | Tracxn', 'description': 'Founded by Christian Schaub, Sebastian Gerke in the year 2015 · Manuela Rasthofer, ... Developer of aerial imaging technology. twitter-link linkedin-link.'}, {'href': 'https://www.liebertpub.com/doi/10.1089/cyber.2020.0341', 'title': '#Coronavirus: Monitoring the Belgian Twitter Discourse on the ...', 'description': 'by S Kurten · 2021 · Cited by 20 — #Coronavirus: Monitoring the Belgian Twitter Discourse on the Severe Acute Respiratory Syndrome Coronavirus 2 Pandemic. Sebastian Kurten\xa0...'}, {'href': 'https://www.linkedin.com/posts/juliaknolle_excited-to-share-that-i-joined-clue-by-biowink-activity-6930040769160314880-m25U', 'title': 'Julia Knolle on LinkedIn: Excited to share that I joined Clue by ...', 'description': 'Reach out if you are interested in working together. 80 1 Comment · Like Comment. Share. LinkedIn; Facebook; Twitter. To view or add a comment, sign in\xa0...'}, {'href': 'https://dblp.org/pid/g/JohannesGehrke', 'title': 'Johannes Gehrke - dblp', 'description': 'List of computer science publications by Johannes Gehrke. ... Twitter · Reddit · BibSonomy · LinkedIn · Facebook. persistent URL: ... Johannes Gehrke:'}, {'href': 'https://srms.indianriverschools.org/', 'title': 'Sebastian River Middle School: Home', 'description': '9400 CR 512Sebastian, FL 32958P: 772-564-5111 ... safety education courses and swimming lessons for free or at a reduced rate. ... View more on Twitter\xa0...'}]
# [INFO] branch_type: name
# [INFO] twitter_ids: {'sg_gehrke': 1}
# [Info] Found 20 scholars are in 78k data.
# [Debug] Names: 0                Yang Liu
# 1                Yang Liu
# 2                Yang Liu
# 3                Yang Liu
# 4                Yang Liu
# 5                Yang Liu
# 6                Yang Liu
# 7                Yang Liu
# 8                Yang Liu
# 9                Yang Liu
# 10               Yang Liu
# 11               Yang Liu
# 12               Yang Liu
# 13               Yang Liu
# 14               Yang Liu
# 15               Yang Liu
# 16               Yang Liu
# 17          Yang LIU (刘杨)
# 18          Yang Liu (刘洋)
# 19    Yang (Veronica) Liu
# Name: name, dtype: object
# [Info] Find 9 scholars using query without gs_sid in step 4.
# [Info] In total 1 scholar is found:
# [
#   {
#     "academic": true,
#     "academic_age": 19.0,
#     "academic_lifespan": 19.0,
#     "cit_sum_before_year": {
#       "2006": 19,
#       "2007": 64,
#       "2008": 124,
#       "2009": 225,
#       "2010": 364,
#       "2011": 524,
#       "2012": 654,
#       "2013": 809,
#       "2014": 980,
#       "2015": 1145,
#       "2016": 1423,
#       "2017": 1870,
#       "2018": 2649,
#       "2019": 3616,
#       "2020": 4744,
#       "2021": 5938
#     },
#     "citation_table": [
#       "6267",
#       "36"
#     ],
#     "domain_labels": [
#       "artificial intelligence",
#       "natural language processing"
#     ],
#     "gender": "F",
#     "gs_sid": "lVhoKNcAAAAJ",
#     "organization": "Professor of Computer Science, Tsinghua University",
#     "organization_code": "15442380624744264287",
#     "paper_num": 196,
#     "cites": {
#       "years": [
#         "2006",
#         "2007",
#         "2008",
#         "2009",
#         "2010",
#         "2011",
#         "2012",
#         "2013",
#         "2014",
#         "2015",
#         "2016",
#         "2017",
#         "2018",
#         "2019",
#         "2020",
#         "2021",
#         "2022"
#       ],
#       "cites": [
#         "19",
#         "45",
#         "60",
#         "101",
#         "139",
#         "160",
#         "130",
#         "155",
#         "171",
#         "165",
#         "278",
#         "447",
#         "779",
#         "967",
#         "1128",
#         "1194",
#         "276"
#       ]
#     },
#     "coauthors": [
#       [
#         "https://scholar.google.com/citations?user=zIgT0HMAAAAJ&hl=en",
#         "Maosong Sun",
#         "Professor of Computer Science and Technology, Tsinghua University",
#         "Verified email at tsinghua.edu.cn"
#       ],
#       [
#         "https://scholar.google.com/citations?user=2HhiGzcAAAAJ&hl=en",
#         "Qun Liu",
#         "Noah's Ark Lab, Huawei",
#         "Verified email at huawei.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=IvE2zRgAAAAJ&hl=en",
#         "Zhaopeng Tu",
#         "Principal Researcher, Tencent AI Lab",
#         "Verified email at tencent.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=rZ0mlMYAAAAJ&hl=en",
#         "Yong Cheng",
#         "Google Research",
#         "Verified email at google.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=w6qCk3sAAAAJ&hl=en",
#         "Jinsong Su",
#         "Xiamen University",
#         "Verified email at xmu.edu.cn"
#       ],
#       [
#         "https://scholar.google.com/citations?user=N1dib3cAAAAJ&hl=en",
#         "Meng Zhang",
#         "Huawei Noah's Ark Lab",
#         "Verified email at huawei.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=iDFjEO0AAAAJ&hl=en",
#         "Zhixing Tan",
#         "Tsinghua University",
#         "Verified email at tsinghua.edu.cn"
#       ],
#       [
#         "https://scholar.google.com/citations?user=G3OMbFSm858C&hl=en",
#         "Haitao Mi",
#         "Principal Researcher, Tencent US",
#         "Verified email at tencent.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=QPLO3myO5PkC&hl=en",
#         "Deyi Xiong",
#         "Professor, College of Intelligence and Computing, Tianjin University, China",
#         "Verified email at tju.edu.cn"
#       ],
#       [
#         "https://scholar.google.com/citations?user=vLT3OXgAAAAJ&hl=en",
#         "Yajuan Lyu (Yajuan L\u00fc)",
#         "Baidu Inc.",
#         "Verified email at baidu.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=a-1wSFYAAAAJ&hl=en",
#         "Zhongjun HE",
#         "Researcher of Natural Language Processing, Baidu",
#         "Verified email at baidu.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=CncXH-YAAAAJ&hl=en",
#         "Min Zhang",
#         "Professor of Computer Science, Soochow University",
#         "Verified email at suda.edu.cn"
#       ],
#       [
#         "https://scholar.google.com/citations?user=nTl5mSwAAAAJ&hl=en",
#         "Hang Li",
#         "AI Lab, Bytedance Technology",
#         "Verified email at bytedance.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=5vm5yAMAAAAJ&hl=en",
#         "Shuo Wang",
#         "Tsinghua University",
#         "Verified email at mails.tsinghua.edu.cn"
#       ],
#       [
#         "https://scholar.google.com/citations?user=e23-LKYAAAAJ&hl=en",
#         "Shiqi Shen",
#         "Wechat, Tencent",
#         "Verified email at tencent.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=lWRYa3wAAAAJ&hl=en",
#         "Xinyan Xiao",
#         "Baidu",
#         "Verified email at baidu.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=OJ-xVYwAAAAJ&hl=en",
#         "jiali zeng",
#         "Tencent",
#         "Verified email at tencent.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=x5lXo2YAAAAJ&hl=en",
#         "Zhengdong Lu",
#         "DeeplyCurious.ai",
#         "Verified email at deeplycurious.ai"
#       ],
#       [
#         "https://scholar.google.com/citations?user=UYIw2qAAAAAJ&hl=en",
#         "Yang Feng",
#         "Professor of Institute of Computing Technology, Chinese Academy of Sciences",
#         "Verified email at ict.ac.cn"
#       ],
#       [
#         "https://scholar.google.com/citations?user=GQWTo4MAAAAJ&hl=en",
#         "Li Deng",
#         "Chief AI Officer, Citadel (former)",
#         "Verified email at ieee.org"
#       ]
#     ],
#     "name": "Yang Liu",
#     "url": "https://scholar.google.com/citations?hl=en&user=lVhoKNcAAAAJ",
#     "top_num_coauthors": 20.0,
#     "num_domain": 2.0,
#     "top_topic_diversity": 23.0,
#     "num_coauthors_all_wwo_ai": 217,
#     "organization_top": 0.0
#   }
# ]
# [{'href': 'https://twitter.com/air_tsinghua', 'title': '清华大学智能产业研究院(@air_tsinghua) / Twitter', 'description': '清华大学智能产业研究院(@air_tsinghua) / Twitter\xa0...'}, {'href': 'https://twitter.com/Tsinghua_Uni?ref_src=twsrc%5Egoogle%7Ctwcamp%5Eserp%7Ctwgr%5Eauthor', 'title': 'Tsinghua University (@Tsinghua_Uni) / Twitter', 'description': 'Tsinghua University is a research university located in Beijing, China, established in 1911. Education\xa0...'}, {'href': 'https://twitter.com/elgreco_winter/with_replies?lang=de', 'title': 'Tweets mit Antworten von Heng Ji (@elgreco_winter) / Twitter', 'description': 'Yang Liu from Tsinghua University. We aim to make AACL as good and international as NAACL. Stay tuned for submission dates and see you in Taipei next year.'}, {'href': 'https://mobile.twitter.com/jietang/with_replies', 'title': 'Tweets with replies by jietang (@jietang) / Twitter', 'description': 'Congrats Yuxiao! @ericdongyx #KDD2022 @Tsinghua_Uni @kdd_news twitter.com/nvchawla/statu…'}, {'href': 'https://twitter.com/ericyi0124?lang=en', 'title': 'Li Yi (@ericyi0124) / Twitter', 'description': 'Li Yi (@ericyi0124) / Twitter\xa0...'}, {'href': 'https://twitter.com/zibuyu9/with_replies', 'title': 'Tweets with replies by Zhiyuan Liu (@zibuyu9) / Twitter', 'description': "the BitFit paper finally got officially accepted to an NLP venue (ACL, via ARR). If you haven't heard of it yet, check out the thread below: twitter.com/\xa0..."}, {'href': 'https://dblp.org/pid/51/3710-5', 'title': 'Yang Liu 0005 - DBLP', 'description': 'Yang Liu 0005 ... affiliation: Tsinghua University, Department of Computer Science and Technology, ... Twitter · Reddit · BibSonomy · LinkedIn · Facebook.'}, {'href': 'https://cs.utdallas.edu/faculty/yang_liu/CV_Yang_Liu.pdf', 'title': 'Yang Liu - UT Dallas Computer Science', 'description': 'by Y Liu · 2014 — MS, 2000, Tsinghua University, Beijing, China, Electrical Engineering ... Twitter. International Joint Conference on Artificial Intelligence (IJCAI),\xa0...'}]
# [INFO] branch_type: name
# [INFO] twitter_ids: {'air_tsinghua': 1, 'Tsinghua_Uni': 1, 'elgreco_winter': 1, 'jietang': 1, 'ericyi0124': 1, 'zibuyu9': 1}
# [Info] Found 2 scholars are in 78k data.
# [Debug] Names: 0    Son N. Tran
# 1       Son Tran
# Name: name, dtype: object
# [Info] Find 1 scholars using query without gs_sid in step 4.
# [Info] In total 1 scholar is found:
# [
#   {
#     "url": "https://scholar.google.com/citations?hl=en&user=h82eCK8AAAAJ",
#     "gs_sid": "h82eCK8AAAAJ",
#     "coauthors": [
#       [
#         "https://scholar.google.com/citations?user=BCpY0gsAAAAJ&hl=en",
#         "Artur d'Avila Garcez",
#         "Professor of Computer Science. City, University of London",
#         "Verified email at city.ac.uk"
#       ],
#       [
#         "https://scholar.google.com/citations?user=04xrJ3oAAAAJ&hl=en",
#         "Qing Zhang",
#         "CSIRO",
#         "Verified email at csiro.au"
#       ],
#       [
#         "https://scholar.google.com/citations?user=DUgCliAAAAAJ&hl=en",
#         "Tillman Weyde",
#         "Reader in Computer Science, City University London",
#         "Verified email at city.ac.uk"
#       ],
#       [
#         "https://scholar.google.com/citations?user=kFY-kEUAAAAJ&hl=en",
#         "Xuan-Son Vu",
#         "Postdoctoral Fellow, Department of Computing Science, Ume\u00e5 University, Sweden",
#         "Verified email at cs.umu.se"
#       ],
#       [
#         "https://scholar.google.com/citations?user=EidMOuEAAAAJ&hl=en",
#         "Thanh Vu",
#         "Oracle Corporation",
#         "Verified email at oracle.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=HUFV96EAAAAJ&hl=en",
#         "Ngo Tung Son",
#         "FPT University",
#         "Verified email at fe.edu.vn"
#       ],
#       [
#         "https://scholar.google.com/citations?user=emUQ350AAAAJ&hl=en",
#         "Srikanth Cherla",
#         "Unity Technologies",
#         "Verified email at unity3d.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=XEJyFFgAAAAJ&hl=en",
#         "Hazrat Ali",
#         "Hamad Bin Khalifa University Qatar",
#         "Verified email at hbku.edu.qa"
#       ],
#       [
#         "https://scholar.google.com/citations?user=Wg49oI4AAAAJ&hl=en",
#         "Emmanouil Benetos",
#         "Queen Mary University of London / The Alan Turing Institute",
#         "Verified email at qmul.ac.uk"
#       ],
#       [
#         "https://scholar.google.com/citations?user=pdeyqasAAAAJ&hl=en",
#         "Spranger Michael",
#         "Sony AI / Sony Computer Science Laboratories Inc.",
#         "Verified email at sony.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=wBMRRk0AAAAJ&hl=en",
#         "Marco Gori",
#         "Professor of Computer Science, University of Siena",
#         "Verified email at dii.unisi.it"
#       ],
#       [
#         "https://scholar.google.com/citations?user=Fm5jLHUAAAAJ&hl=en",
#         "Lu\u00eds Lamb",
#         "Professor of Foundations of Computer Science and AI at UFRGS University",
#         "Verified email at mit.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=rfCV4fwAAAAJ&hl=en",
#         "Luciano Serafini",
#         "Head of Data and Knowledge Management Research Unit, Fondazione Bruno Kessler, Trento, Italy",
#         "Verified email at fbk.eu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=PCTA8yAAAAAJ&hl=en",
#         "Song Dawei",
#         "Open University",
#         "Verified email at tju.edu.cn"
#       ],
#       [
#         "https://scholar.google.com/citations?user=-vxkP70AAAAJ&hl=en",
#         "A/Prof. Jie Yin",
#         "University of Sydney",
#         "Verified email at sydney.edu.au"
#       ],
#       [
#         "https://scholar.google.com/citations?user=gz_DvgQAAAAJ&hl=en",
#         "Khalid Iqbal Khattak (Associate Profes...",
#         "COMSATS University Islamabad, Attock Campus",
#         "Verified email at cuiatk.edu.pk"
#       ],
#       [
#         "https://scholar.google.com/citations?user=dY2NajQAAAAJ&hl=en",
#         "Daniel Wolff",
#         "Utopia Music",
#         "Verified email at city.ac.uk"
#       ],
#       [
#         "https://scholar.google.com/citations?user=DZ9jplQAAAAJ&hl=en",
#         "David Ireland",
#         "CSIRO",
#         "Verified email at csiro.au"
#       ],
#       [
#         "https://scholar.google.com/citations?user=dotRwNwAAAAJ&hl=en",
#         "Hamed Hassanzadeh",
#         "Australian e-Health Research Centre, CSIRO",
#         "Verified email at csiro.au"
#       ],
#       [
#         "https://scholar.google.com/citations?user=K5eVC8MAAAAJ&hl=en",
#         "Anthony Nguyen",
#         "Research Team Leader, Commonwealth Scientific and Industrial Research Organisation (CSIRO)",
#         "Verified email at csiro.au"
#       ]
#     ],
#     "citation_table": [
#       "812",
#       "13"
#     ],
#     "cites": {
#       "years": [
#         "2014",
#         "2015",
#         "2016",
#         "2017",
#         "2018",
#         "2019",
#         "2020",
#         "2021",
#         "2022"
#       ],
#       "cites": [
#         "5",
#         "10",
#         "17",
#         "44",
#         "41",
#         "95",
#         "177",
#         "231",
#         "181"
#       ]
#     },
#     "name": "Son N. Tran",
#     "organization": "University of Tasmania",
#     "homepage_url": null,
#     "email_info": "utas.edu.au",
#     "domain_labels": [
#       "artificial intelligence",
#       "machine learning",
#       "neuro-symbolic/neural-symbolic"
#     ],
#     "extra_co_authors": []
#   }
# ]
# [{'href': 'https://www.utas.edu.au/profiles/staff/ict/son-tran', 'title': 'Son Tran - Profiles - University of Tasmania', 'description': 'Dr. Son Tran obtained his Ph.D in Computer Science at City, University of London, ... feed of University of Tasmania Twitter feed of University of Tasmania\xa0...'}, {'href': 'https://twitter.com/alana_mann?lang=en', 'title': 'alana_mann - Twitter', 'description': 'Give @lawrence_bull a Walkley for his work! twitter.com/ben_hr/status/… Show this thread.'}, {'href': 'https://orcid.org/0000-0002-5912-293X', 'title': 'Son Tran (0000-0002-5912-293X) - ORCID', 'description': 'Source: University of Tasmania. Record last modified Jul 26, 2022, 5:26:01 AM UTC. 14,822,051 ORCID iDs and counting. See more statistics. Orcid Twitter\xa0...'}, {'href': 'https://scholar.google.com/citations?user=EidMOuEAAAAJ&hl=en', 'title': '\u202aThanh Vu\u202c - \u202aGoogle Scholar\u202c', 'description': 'Email được xác minh tại oracle.com ... experiment in integrating sentiment features for tech stock prediction in twitter ... T Vu, A Willis, SN Tran, D Song.'}, {'href': 'https://www.adscientificindex.com/scientist.php?id=53669', 'title': 'Son N Tran - AD Scientific Index 2022', 'description': 'Son N Tran University of Tasmania ... Facebook · Twitter · Linkedin · Whatsapp ... Use redlist@adscientificindex.com to report an inappropriate profile,\xa0...'}, {'href': 'https://scholar.google.co.uk/citations?user=EidMOuEAAAAJ&hl=en', 'title': '\u202aThanh Vu\u202c - \u202aGoogle Scholar\u202c', 'description': 'Verified email at oracle.com ... in integrating sentiment features for tech stock prediction in twitter ... XS Vu, T Vu, MV Tran, T Le-Cong, HTM Nguyen.'}, {'href': 'https://people.cs.umu.se/sonvx/files/ETNLP_ranlp2019.pdf', 'title': 'ETNLP: a visual-aided systematic approach to select pre ...', 'description': 'by XS Vu · Cited by 29 — {sonvx; lili.jiang}@cs.umu.se; thanh.vu@csiro.au; sn.tran@utas.edu.au. INTRODUCTION ... Accurate Neural Network Model for Irony Detection in Twitter", In:.'}]
# [INFO] branch_type: name
# [INFO] twitter_ids: {'alana_mann': 1}
# [Info] Found 1 scholars are in 78k data.
# [Debug] Names: 0    Massimiliano Ciaramita
# Name: name, dtype: object
# [Info] Find 1 scholars using query without gs_sid in step 4.
# [Info] In total 1 scholar is found:
# [
#   {
#     "url": "https://scholar.google.com/citations?hl=en&user=PwsKWfUAAAAJ",
#     "gs_sid": "PwsKWfUAAAAJ",
#     "coauthors": [
#       [
#         "https://scholar.google.com/citations?user=DLx8WAYAAAAJ&hl=en",
#         "Vassilis Plachouras",
#         "Facebook, London, UK",
#         "Verified email at acm.org"
#       ],
#       [
#         "https://scholar.google.com/citations?user=-iVGcoAAAAAJ&hl=en",
#         "Aldo Gangemi",
#         "University of Bologna and ISTC, National Research Council, Italy",
#         "Verified email at unibo.it"
#       ],
#       [
#         "https://scholar.google.com/citations?user=a3133-8AAAAJ&hl=en",
#         "Mihai Surdeanu",
#         "Associate Professor, Computer Science, University of Arizona",
#         "Verified email at email.arizona.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=p86Ewsi7jXwJ&hl=en",
#         "Giuseppe Attardi",
#         "professor of Informatics, Universit\u00e0 di Pisa",
#         "Verified email at di.unipi.it"
#       ],
#       [
#         "https://scholar.google.com/citations?user=bX1lYWUAAAAJ&hl=en",
#         "Jordi Atserias",
#         "Amazon",
#         "Verified email at amazon.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=3EILU3MAAAAJ&hl=en",
#         "Paolo Ferragina",
#         "Professor of Algorithms, Dept. Computer Science, University of Pisa",
#         "Verified email at unipi.it"
#       ],
#       [
#         "https://scholar.google.com/citations?user=Z_kok3sAAAAJ&hl=en",
#         "Mark Johnson",
#         "Professor of Language Sciences, School of Computing, Macquarie University",
#         "Verified email at MQ.edu.au"
#       ],
#       [
#         "https://scholar.google.com/citations?user=jUCiLN4AAAAJ&hl=en",
#         "Yasemin Altun",
#         "Google Research",
#         "Verified email at google.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=AxGhhfsAAAAJ&hl=en",
#         "Enrique Alfonseca",
#         "Research Manager, Google Inc. (US)",
#         "Verified email at google.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=bmXpOd8AAAAJ&hl=en",
#         "Donald Metzler",
#         "Google",
#         "Verified email at google.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=mKeIvpYAAAAJ&hl=en",
#         "Ama\u00e7 Herda\u011fdelen",
#         "Facebook",
#         "Verified email at herdagdelen.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=QuymF8gAAAAJ&hl=en",
#         "Daniel Mahler",
#         "",
#         "Verified email at rmn.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=v9xULZwAAAAJ&hl=en",
#         "Ricardo Baeza-Yates",
#         "Northeastern Univ. - Univ. Pompeu Fabra - Univ. de Chile; USA, Spain & Chile",
#         "Verified email at upf.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=23xz9QgAAAAJ&hl=en",
#         "Katja Filippova",
#         "Google",
#         "Verified email at google.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=UetM7FgAAAAJ&hl=en",
#         "Rada Mihalcea",
#         "Professor of Computer Science, University of Michigan",
#         "Verified email at umich.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=kEiTxHsAAAAJ&hl=en",
#         "Roelof van Zwol",
#         "Head of Ads Quality Engineering at Pinterest",
#         ""
#       ]
#     ],
#     "citation_table": [
#       "5291",
#       "38"
#     ],
#     "cites": {
#       "years": [
#         "2004",
#         "2005",
#         "2006",
#         "2007",
#         "2008",
#         "2009",
#         "2010",
#         "2011",
#         "2012",
#         "2013",
#         "2014",
#         "2015",
#         "2016",
#         "2017",
#         "2018",
#         "2019",
#         "2020",
#         "2021",
#         "2022"
#       ],
#       "cites": [
#         "24",
#         "38",
#         "67",
#         "115",
#         "175",
#         "295",
#         "347",
#         "315",
#         "320",
#         "401",
#         "366",
#         "398",
#         "418",
#         "350",
#         "330",
#         "368",
#         "310",
#         "348",
#         "230"
#       ]
#     },
#     "name": "Massimiliano Ciaramita",
#     "organization": "Google",
#     "homepage_url": null,
#     "email_info": "google.com",
#     "domain_labels": [
#       "natural language processing",
#       "web search"
#     ],
#     "extra_co_authors": []
#   }
# ]
# [{'href': 'https://twitter.com/sobigdata/status/906060240860405761', 'title': 'SoBigData on Twitter: "Massimiliano Ciaramita from Google is ...', 'description': 'Sep 8, 2017 — SoBigData on Twitter: "Massimiliano Ciaramita from Google is talking about Active Question Answering at #DataScience for Society\xa0...'}, {'href': 'https://research.google.com/pubs/archive/43113.pdf', 'title': 'Adapting taggers to Twitter with not-so-distant supervision', 'description': 'by B Plank · Cited by 50 — Google Inc.2 ... Learning taggers for Twitter data from small amounts ... Stefan Rüd, Massimiliano Ciaramita, Jens Müller, and Hinrich Schütze. 2011.'}, {'href': 'https://neilhoulsby.github.io/publications/aqa18.md', 'title': 'Active Question Reformulation with Reinforcement Learning', 'description': 'Zurich, Switzerland; Twitter · Google Scholar ... Christian Buck, Jannis Bulian, Massimiliano Ciaramita, Wojciech Gajewski, Andrea Gesmundo, Neil Houlsby,\xa0...'}, {'href': 'http://ai.googleblog.com/2013/07/natural-language-understanding-focused.html', 'title': 'Natural Language Understanding-focused awards announced', 'description': 'Jul 2, 2013 — Posted by Massimiliano Ciaramita, Research Scientist and David Harper, Head University Relations ... Share on Twitter Share on Facebook.'}, {'href': 'https://www.researchgate.net/publication/220873736_Piggyback_Using_Search_Engines_for_Robust_Cross-Domain_Named_Entity_Recognition', 'title': 'Piggyback: Using Search Engines for Robust Cross-Domain ...', 'description': 'Jul 4, 2022 — Massimiliano Ciaramita at Google Inc. Massimiliano Ciaramita · Google Inc. ... speech, social communities like Twitter, and SMS.'}, {'href': 'https://scholar.google.com/citations?user=mKeIvpYAAAAJ&hl=en', 'title': '\u202aAmaç Herdağdelen\u202c - \u202aGoogle Scholar\u202c', 'description': 'A Herdağdelen, M Ciaramita, D Mahler, M Holmqvist, K Hall, S Riezler, . ... Social media and language processing: How Facebook and Twitter provide the best\xa0...'}]
# [INFO] branch_type: name
# [INFO] twitter_ids: {'sobigdata': 1}
# [Info] Found 1 scholars are in 78k data.
# [Debug] Names: 0    Marco Baity-Jesi
# Name: name, dtype: object
# [Info] Find 1 scholars using query without gs_sid in step 4.
# [Info] In total 1 scholar is found:
# [
#   {
#     "url": "https://scholar.google.com/citations?hl=en&user=4S1Ajs8AAAAJ",
#     "gs_sid": "4S1Ajs8AAAAJ",
#     "coauthors": [
#       [
#         "https://scholar.google.com/citations?user=dWKDuxcAAAAJ&hl=en",
#         "Victor Martin-Mayor",
#         "Professor of theoretical physics (Universidad Complutense de Madrid)",
#         "Verified email at ucm.es"
#       ],
#       [
#         "https://scholar.google.com/citations?user=Fx6_jlYAAAAJ&hl=en",
#         "Luis Antonio Fernandez",
#         "Professor of Theoretical Physics. Universidad Complutense de Madrid",
#         "Verified email at ucm.es"
#       ],
#       [
#         "https://scholar.google.com/citations?user=TeuEgRkAAAAJ&hl=en",
#         "Giorgio Parisi",
#         "Professor of Theoretical Physics, Rome I University \"La Sapienza\"",
#         "Verified email at roma1.infn.it"
#       ],
#       [
#         "https://scholar.google.com/citations?user=ZE5_-DIAAAAJ&hl=en",
#         "Enzo Marinari",
#         "Professor of Theoretical Physics, Sapienza Universit\u00e0 di Roma",
#         "Verified email at uniroma1.it"
#       ],
#       [
#         "https://scholar.google.com/citations?user=JQi6_d8AAAAJ&hl=en",
#         "Antonio Gordillo-Guerrero",
#         "Electronic Department. University of Extremadura. Spain.",
#         "Verified email at unex.es"
#       ],
#       [
#         "https://scholar.google.com/citations?user=s4rvGzMAAAAJ&hl=en",
#         "Andrea Maiorano",
#         "DBCF, Universit\u00e0 di Siena, Italy; BIFI, Saragozza, Spain; INFN Roma1, Italy",
#         "Verified email at maiorano.email"
#       ],
#       [
#         "https://scholar.google.com/citations?user=J9BtOssAAAAJ&hl=en",
#         "Denis Navarro",
#         "zaragoza",
#         "Verified email at unizar.es"
#       ],
#       [
#         "https://scholar.google.com/citations?user=1-lK6LEAAAAJ&hl=en",
#         "Alfonso Tarancon Lafita",
#         "Professor of Physics",
#         "Verified email at unizar.es"
#       ],
#       [
#         "https://scholar.google.com/citations?user=zkyUHFkAAAAJ&hl=en",
#         "J.M Gil-Narvion",
#         "BSH hausger\u00e4te gmbh",
#         "Verified email at bshg.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=HIwJ8QIAAAAJ&hl=en",
#         "David Yllanes",
#         "Chan Zuckerberg Biohub",
#         "Verified email at czbiohub.org"
#       ],
#       [
#         "https://scholar.google.com/citations?user=_Zz89tQAAAAJ&hl=en",
#         "Sebastiano Fabio Schifano",
#         "University of Ferrara",
#         "Verified email at fe.infn.it"
#       ],
#       [
#         "https://scholar.google.com/citations?user=k8nSlL4AAAAJ&hl=en",
#         "Federico Ricci-Tersenghi",
#         "Professor of Theoretical Physics, \"La Sapienza\" University, Roma",
#         "Verified email at roma1.infn.it"
#       ],
#       [
#         "https://scholar.google.com/citations?user=dcZc7A8AAAAJ&hl=en",
#         "Juan J. Ruiz-Lorenzo",
#         "Professor of Theoretical Physics, Department of Physics. Universidad de Extremadura",
#         "Verified email at unex.es"
#       ],
#       [
#         "https://scholar.google.com/citations?user=RyCweLUAAAAJ&hl=en",
#         "Beatriz Seoane",
#         "Departamento de f\u00edsica te\u00f3rica, Universidad Complutense de Madrid",
#         "Verified email at ucm.es"
#       ],
#       [
#         "https://scholar.google.com/citations?user=BadZJUsAAAAJ&hl=en",
#         "Giulio Biroli",
#         "Professor of Theoretical Physics, ENS Paris",
#         "Verified email at cea.fr"
#       ],
#       [
#         "https://scholar.google.com/citations?user=DdEYqIoAAAAJ&hl=en",
#         "Enrico Calore",
#         "INFN Ferrara",
#         "Verified email at fe.infn.it"
#       ],
#       [
#         "https://scholar.google.com/citations?user=2H-yxNkAAAAJ&hl=en",
#         "Filippo Mantovani",
#         "Post-doc at Barcelona Supercomputing Center",
#         "Verified email at bsc.es"
#       ],
#       [
#         "https://scholar.google.com/citations?user=1TttZYYAAAAJ&hl=en",
#         "Matthieu Wyart",
#         "EPFL, Institute of Physics",
#         "Verified email at epfl.ch"
#       ],
#       [
#         "https://scholar.google.com/citations?user=HKy60cwAAAAJ&hl=en",
#         "Javier Moreno-Gordo",
#         "Institute for Biocomputation and Physics of Complex Systems (BIFI), Universidad de Zaragoza",
#         "Verified email at bifi.es"
#       ],
#       [
#         "https://scholar.google.com/citations?user=vsLT1BIAAAAJ&hl=en",
#         "Chiara Cammarota",
#         "La Sapienza, University of Rome",
#         "Verified email at uniroma1.it"
#       ]
#     ],
#     "citation_table": [
#       "884",
#       "16"
#     ],
#     "cites": {
#       "years": [
#         "2012",
#         "2013",
#         "2014",
#         "2015",
#         "2016",
#         "2017",
#         "2018",
#         "2019",
#         "2020",
#         "2021",
#         "2022"
#       ],
#       "cites": [
#         "4",
#         "9",
#         "31",
#         "37",
#         "54",
#         "43",
#         "69",
#         "135",
#         "147",
#         "186",
#         "167"
#       ]
#     },
#     "name": "Marco Baity-Jesi",
#     "organization": "Eawag",
#     "homepage_url": "https://mbaityje.github.io/",
#     "email_info": "eawag.ch",
#     "domain_labels": [
#       "disordered systems",
#       "machine learning",
#       "deep learning",
#       "glasses",
#       "activated dynamics"
#     ],
#     "extra_co_authors": []
#   }
# ]
# []
# [{'href': 'https://twitter.com/search?q=%23CIEB&src=hash&f=image', 'title': '#CIEB - Twitter Search / Twitter', 'description': '... we want to predict the effect of chemicals on fish using machine learning methods”, says Marco Baity-Jesi, Head of the. @Eawag. Data Science Group.'}, {'href': 'https://twitter.com/utox_eawag?lang=en', 'title': 'Utox_Eawag - Twitter', 'description': 'Utox_Eawag (@Utox_Eawag) / Twitter\xa0...'}, {'href': 'https://twitter.com/cieb_unibas?lang=en', 'title': 'CIEB Universität Basel (@cieb_unibas) / Twitter', 'description': 'CIEB Universität Basel (@cieb_unibas) / Twitter\xa0...'}, {'href': 'https://mobile.twitter.com/peterisles', 'title': 'Peter Isles (@PeterIsles) / Twitter', 'description': 'Peter Isles (@PeterIsles) / Twitter\xa0...'}, {'href': 'https://twitter.com/PeterIsles/with_replies', 'title': 'Tweets with replies by Peter Isles (@PeterIsles) / Twitter', 'description': 'New paper let by Sreenath Kyathanahally, Marco Baity-Jesi, and Francesco Pomati, developing a deep-learning classifier for automated plankton imaging data.'}, {'href': 'https://mobile.twitter.com/cieb_unibas/with_replies', 'title': 'Tweets with replies by CIEB Universität Basel ... - Twitter', 'description': 'Basel, Switzerland cieb.unibas.ch Joined April 2020 ... innoscape.ch ... learning methods”, says Marco Baity-Jesi, Head of the. @Eawag. Data Science Group.'}, {'href': 'https://twitter.com/cieb_unibas?lang=ar-x-fm', 'title': 'تويتر \\ CIEB Universität Basel (cieb_unibas@) - Twitter', 'description': 'Basel, Switzerland cieb.unibas.ch انضم في أبريل ٢٠٢٠ ... innoscape.ch ... learning methods”, says Marco Baity-Jesi, Head of the. @Eawag. Data Science Group.'}, {'href': 'https://meetingorganizer.copernicus.org/EGU22/EGU22-3661.html', 'title': 'Neural ODEs in Hydrology - CO Meeting Organizer EGU22', 'description': 'by M Höge · 2022 — Marvin Höge , Andreas Scheidegger , Marco Baity-Jesi, Carlo Albert , and Fabrizio Fenicia. Marvin Höge et al. ... Reddit. Twitter. Facebook. LinkedIn\xa0...'}, {'href': 'https://ch.linkedin.com/posts/cieb-unibas_machinelearning-ai-economics-activity-6967369823357919232-Co_p', 'title': 'CIEB Universität Basel auf LinkedIn', 'description': '... says Marco Baity-Jesi, Head of the Eawag Data Science Group. ... Facebook; Twitter. Loggen Sie sich ein, um Kommentare zu sehen oder hinzuzufügen.'}]
# [INFO] branch_type: name
# [INFO] twitter_ids: {'cieb_unibas': 3, 'search': 1, 'utox_eawag': 1, 'peterisles': 1, 'PeterIsles': 1}
# [Info] Found 1 scholars are in 78k data.
# [Debug] Names: 0    Takuya Funatomi
# Name: name, dtype: object
# [Info] Find 1 scholars using query without gs_sid in step 4.
# [Info] In total 1 scholar is found:
# [
#   {
#     "url": "https://scholar.google.com/citations?hl=en&user=OjA6YhgAAAAJ",
#     "gs_sid": "OjA6YhgAAAAJ",
#     "coauthors": [
#       [
#         "https://scholar.google.com/citations?user=vWuuPa8AAAAJ&hl=en",
#         "Yasuhiro Mukaigawa",
#         "NAIST",
#         "Verified email at is.naist.jp"
#       ],
#       [
#         "https://scholar.google.com/citations?user=TRmARjkAAAAJ&hl=en",
#         "Hiroyuki Kubo",
#         "Chiba University",
#         "Verified email at chiba-u.jp"
#       ],
#       [
#         "https://scholar.google.com/citations?user=WTzqVTEAAAAJ&hl=en",
#         "Kenichiro Tanaka",
#         "Ritsumeikan University",
#         "Verified email at fc.ritsumei.ac.jp"
#       ],
#       [
#         "https://scholar.google.com/citations?user=MI-yYJYAAAAJ&hl=en",
#         "Masaaki Iiyama",
#         "Kyoto Univerisity",
#         "Verified email at iiyama-lab.org"
#       ],
#       [
#         "https://scholar.google.com/citations?user=DHIGVL8AAAAJ&hl=en",
#         "Atsushi Hashimoto",
#         "OMRON SINIC X Corp.",
#         "Verified email at sinicx.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=lBJ2M80AAAAJ&hl=en",
#         "Shigehito Yamada",
#         "Congenital Anomaly Research Center, Kyoto University Graduate School of Medicine",
#         "Verified email at cac.med.kyoto-u.ac.jp"
#       ],
#       [
#         "https://scholar.google.com/citations?user=i4XnOJ8AAAAJ&hl=en",
#         "Masahiro Toyoura (\u8c4a\u6d66 \u6b63\u5e83)",
#         "University of Yamanashi",
#         "Verified email at yamanashi.ac.jp"
#       ],
#       [
#         "https://scholar.google.com/citations?user=vwOQ-UIAAAAJ&hl=en",
#         "Yang Wu (\u4f0d \u6d0b)",
#         "Tencent",
#         "Verified email at tencent.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=zaucIBAAAAAJ&hl=en",
#         "Ahmed Ayman",
#         "Assistant Professor of Computer Science",
#         "Verified email at azhar.edu.eg"
#       ]
#     ],
#     "citation_table": [
#       "753",
#       "13"
#     ],
#     "cites": {
#       "years": [
#         "2007",
#         "2008",
#         "2009",
#         "2010",
#         "2011",
#         "2012",
#         "2013",
#         "2014",
#         "2015",
#         "2016",
#         "2017",
#         "2018",
#         "2019",
#         "2020",
#         "2021",
#         "2022"
#       ],
#       "cites": [
#         "8",
#         "7",
#         "14",
#         "22",
#         "23",
#         "40",
#         "36",
#         "49",
#         "31",
#         "47",
#         "49",
#         "53",
#         "86",
#         "88",
#         "99",
#         "94"
#       ]
#     },
#     "name": "Takuya Funatomi",
#     "organization": "Nara Institute of Science and Technology",
#     "homepage_url": "http://omilab.naist.jp/~funatomi/",
#     "email_info": "is.naist.jp",
#     "domain_labels": [
#       "computer vision",
#       "pattern recognition",
#       "computer graphics"
#     ],
#     "extra_co_authors": []
#   }
# ]
# []
# [{'href': 'http://www.naist.jp/en/research_achievements/2020/01/006634.html', 'title': 'A technology for embedding data in printed objects', 'description': 'Jan 17, 2020 — twitter; Facebook; YouTube ... Associate Professor Takuya Funatomi, Assistant Professor Hiroyuki Kubo, ... 2018 NAIST, All Rights Reserved.'}, {'href': 'https://dblp.org/pid/68/2427-2', 'title': 'Takahito Aoto 0002 - DBLP', 'description': 'Twitter · Reddit · BibSonomy · LinkedIn · Facebook ... Takahiro Kushida, Kenichiro Tanaka, Takahito Aoto, Takuya Funatomi , Yasuhiro Mukaigawa:'}, {'href': 'https://orcid.org/0000-0002-7263-1931', 'title': 'Tsuyoshi Takatani (0000-0002-7263-1931) - ORCID', 'description': 'May 27, 2022 — Nara Institute of Science and Technology (NAIST): Ikoma, Nara, JP ... Orcid Twitter · Rss · Github. public domain The text of this website\xa0...'}, {'href': 'https://www.adscientificindex.com/?sort=asc&sortby=subject&university=Nara+Institute+of+Science+%26+Technology', 'title': 'Nara Institute of Science & Technology Scientist and ...', 'description': 'List without CERN, Statistical Data etc. Sort by last 5 years H Index. share Share arrow_drop_down. Facebook · Twitter · Linkedin\xa0...'}, {'href': 'https://scholar.google.com/citations?user=YNMwoeUAAAAJ&hl=en', 'title': '\u202aTakeshi Okadome\u202c - \u202aGoogle Scholar\u202c', 'description': 'Social mood extraction from Twitter posts with document topic model. M Ohmura, K Kakusho, T Okadome. 2014 International Conference on Information Science\xa0...'}, {'href': 'http://www.sigmm.org/archive/MM/mm12/www.acmmm12.org/wp-content/uploads/ACMMM12_Program_1018.pdf', 'title': 'Eternal / Moment - ACM SIGMM', 'description': 'can share their experiences with others on Twitter /. Facebook. ... Hideyuki Ando (Multimedia Art Program Chair / Osaka University, JP).'}, {'href': 'https://scholar.google.co.kr/citations?user=YNMwoeUAAAAJ&hl=zh-TW', 'title': '\u202aTakeshi Okadome\u202c - \u202aGoogle 學術搜尋\u202c', 'description': 'Social mood extraction from Twitter posts with document topic model. M Ohmura, K Kakusho, T Okadome. 2014 International Conference on Information Science\xa0...'}]
# [{'href': 'https://www.naist.jp/en/research_achievements/2021/08/008216.html', 'title': 'Turning the tables into touchscreens｜NARA Institute of ...', 'description': 'NARA INSTITUTE of SCIENCE and TECHNOLOGY. twitter; Facebook; YouTube. JAPANESE. Access / Campus Map · Job Opportunities · Contact NAIST\xa0...'}, {'href': 'https://www.zoominfo.com/people-search/location-japan--nara?pageNum=5', 'title': 'Emails and Direct Phone Numbers of professionals in Nara', 'description': 'Japan,. Nara. Takuya Funatomi · Nara Institute of Science and Technology ... LinkedIn logo · Twitter logo · Instagram logo · Facebook logo · Youtube logo.'}, {'href': 'https://dl.acm.org/profile/81331492245', 'title': 'Takuya Funatomi - Home - ACM Digital Library', 'description': "Takuya Funatomi. Search within Takuya Funatomi's work ... Author's Latest Publications. research-article ... Contact · Facebook · Twitter · Linkedin."}, {'href': 'https://www.researchgate.net/institution/Nara-Institute-of-Science-and-Technology/members', 'title': 'Nara Institute of Science and Technology | Ikoma, Japan | NAIST', 'description': 'Find 898 researchers working at Nara Institute of Science and Technology | Ikoma, ... Social Networks · Twitter · Social Computing ... Takuya Funatomi.'}, {'href': 'https://orcid.org/0000-0002-5503-5716', 'title': 'Daiki Kijima (0000-0002-5503-5716) - ORCID', 'description': 'Aug 5, 2022 — Nara Institute of Science and Technology: Ikoma, JP ... Orcid Twitter · Rss · Github. public domain The text of this website is published\xa0...'}, {'href': 'https://dblp.org/pid/56/1428-1', 'title': 'Yang Wu 0001 - dblp', 'description': 'affiliation: Nara Institute of Science and Technology, Institute for Research Initiatives, Japan ... Twitter · Reddit · BibSonomy · LinkedIn · Facebook.'}]
# [{'href': 'https://twitter.com/jst_kisokenkyu/status/1507251583041830912?lang=en', 'title': 'JST CREST・さきがけ・ACT-I/X on Twitter: ""Eliminating ...', 'description': 'Mar 25, 2022 — "Eliminating Temporal Illumination Variations in Whisk-broom Hyperspectral Imaging" by Takuya Funatomi, Takehiro Ogawa, Kenichiro Tanaka,\xa0...'}, {'href': 'https://dblp.org/pid/26/3763', 'title': 'Takuya Funatomi - DBLP', 'description': 'List of computer science publications by Takuya Funatomi. ... Takuya Funatomi. ORCID. 0000-0001-5588-5932 ... Twitter · Reddit · BibSonomy · LinkedIn.'}, {'href': 'https://dl.acm.org/profile/81331492245', 'title': 'Takuya Funatomi - Home - ACM Digital Library', 'description': "Takuya Funatomi. Search within Takuya Funatomi's work. SearchSearch. HomeTakuya Funatomi. Takuya Funatomi ... Contact · Facebook · Twitter · Linkedin."}, {'href': 'https://figshare.com/articles/media/defog_submit_mp4/13352306', 'title': 'defog_submit.mp4 - Figshare', 'description': 'Feb 16, 2021 — ... Hiromu Kitajima, Kenichiro Tanaka, Hiroyuki Kubo, Takuya Funatomi, Yasuhiro Mukaigawa ... facebook page twitter page vimeo page.'}, {'href': 'https://oa.mg/author/A376472489', 'title': 'Yoko Yamakata papers and PDFs - OA.mg', 'description': 'Atsushi Hashimoto, Naoyuki Mori, Takuya Funatomi, Yoko Yamakata, ... Yoko Yamakata, Takuya Funatomi, Koh Kakusho, Michihiko Minoh ... twitter.com/OAmgHQ.'}, {'href': 'http://www.naist.jp/en/research_achievements/2020/01/006634.html', 'title': 'A technology for embedding data in printed objects', 'description': 'Jan 17, 2020 — twitter; Facebook; YouTube ... Professor Yasuhiro Mukaigawa, Associate Professor Takuya Funatomi, Assistant Professor Hiroyuki Kubo,\xa0...'}, {'href': 'https://chemrxiv.org/engage/chemrxiv/article-details/60c73d0ef96a0079df285cf7', 'title': 'Facile Fabrication of Ultralow-Density Transparent Boehmite ...', 'description': 'by G Hayase · 2018 — Gen Hayase, Takuya Funatomi, Kota Kumagai. ACS Applied Nano Materials , Volume 1, Issue 1 ... twitter facebook linkedin print show more\xa0...'}, {'href': 'https://elcvia.cvc.uab.cat/article/view/v7-n4-funatomi-liyama-kakusho-et-al/213', 'title': 'Distortion Correction for 3D Scan of Trunk Swaying', 'description': 'by T Funatomi · 2008 · Cited by 2 — ... of Trunk SwayingHuman Body SegmentsTakuya Funatomi∗Masaaki Iiyama+Koh Kakusho∗Michihiko ... 52T. Funatomi et al. ... OJS; AddThis; Twitter; Facebook.'}]
# [INFO] branch_type: name
# [INFO] twitter_ids: {'jst_kisokenkyu': 1}
# [Info] Found 1 scholars are in 78k data.
# [Debug] Names: 0    Saurabh Sawlani
# Name: name, dtype: object
# [Info] Find 1 scholars using query without gs_sid in step 4.
# [Info] In total 1 scholar is found:
# [
#   {
#     "url": "https://scholar.google.com/citations?hl=en&user=u21gfyUAAAAJ",
#     "gs_sid": "u21gfyUAAAAJ",
#     "coauthors": [
#       [
#         "https://scholar.google.com/citations?user=loh7ivYAAAAJ&hl=en",
#         "Richard Peng",
#         "University of Waterloo",
#         "Verified email at uwaterloo.ca"
#       ],
#       [
#         "https://scholar.google.com/citations?user=RfyLl28AAAAJ&hl=en",
#         "David Durfee",
#         "LinkedIn",
#         "Verified email at linkedin.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=8DxE0DoAAAAJ&hl=en",
#         "Yu Gao",
#         "Georgia Institute of Technology",
#         "Verified email at gatech.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=OzXbU7kAAAAJ&hl=en",
#         "Jayalal Sarma",
#         "Indian Institute of Technology Madras, Chennai, India",
#         "Verified email at cse.iitm.ac.in"
#       ],
#       [
#         "https://scholar.google.com/citations?user=-oRTB8TtsDYC&hl=en",
#         "Saravanan Thirumuruganathan",
#         "Qatar Computing Research Institute, HBKU",
#         "Verified email at hbku.edu.qa"
#       ],
#       [
#         "https://scholar.google.com/citations?user=slMpmnMAAAAJ&hl=en",
#         "Sanya Chaba",
#         "Graduate Student, Georgia Institute of Technology",
#         "Verified email at gatech.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=RqkqRnUAAAAJ&hl=en",
#         "Xu Chu",
#         "Assistant Professor, Georgia Institute of Technology",
#         "Verified email at cc.gatech.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=D2bH_T8AAAAJ&hl=en",
#         "Renzhi Wu",
#         "Georgia Institute of Technology",
#         "Verified email at gatech.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=jq8VoFkAAAAJ&hl=en",
#         "Xiaorui Sun",
#         "University of Illinois at Chicago",
#         "Verified email at uic.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=TJSHa2IAAAAJ&hl=en",
#         "Laxman Dhulipala",
#         "University of Maryland, College Park",
#         "Verified email at umd.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=_fxnybwAAAAJ&hl=en",
#         "Janardhan Kulkarni",
#         "Microsoft  Research, Redmond",
#         "Verified email at cs.washington.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=gn2qlUoAAAAJ&hl=en",
#         "Di Wang",
#         "Google Research",
#         "Verified email at eecs.berkeley.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=brUg_BkAAAAJ&hl=en",
#         "Digvijay Boob",
#         "Southern Methodist University",
#         "Verified email at smu.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=sb1-HK8AAAAJ&hl=en",
#         "Sushant Sachdeva",
#         "Assistant Professor, UToronto, Vector Institute Affiliate",
#         "Verified email at cs.toronto.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=DlkDg3EAAAAJ&hl=en",
#         "Kevin A. Lai",
#         "PhD, Georgia Tech",
#         "Verified email at gatech.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=4T2Ji_gAAAAJ&hl=en",
#         "Matthew Fahrbach",
#         "Google Research",
#         "Verified email at google.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=14NcbFcAAAAJ&hl=en",
#         "Shen Chen Xu",
#         "Carnegie Mellon University",
#         "Verified email at cs.cmu.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=umm-i20AAAAJ&hl=en",
#         "Gary L. Miller",
#         "Carnegie Mellon University",
#         "Verified email at cs.cmu.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=uTv7Dl4AAAAJ&hl=en",
#         "Balagopal Komarath",
#         "Assistant Professor, CSE, IIT Gandhinagar",
#         "Verified email at iitgn.ac.in"
#       ],
#       [
#         "https://scholar.google.com/citations?user=VZnSCWMAAAAJ&hl=en",
#         "Gorav Jindal",
#         "Max Planck Institute for Informatics \u2003",
#         "Verified email at mpi-inf.mpg.de"
#       ]
#     ],
#     "citation_table": [
#       "231",
#       "10"
#     ],
#     "cites": {
#       "years": [
#         "2015",
#         "2016",
#         "2017",
#         "2018",
#         "2019",
#         "2020",
# ...
#         "Dr. Fawad Ali",
#         "Lecturer of Mathematics, Institute of Numerical Sciences, Kohat University of Science and Technology",
#         "Verified email at math.qau.edu.pk"
#       ],
#       [
#         "https://scholar.google.com/citations?user=uUlbkioAAAAJ&hl=en",
#         "Naila Siddique",
#         "Pakistan Institute of Nuclear Science and Technology",
#         "Verified email at pinstech.org.pk"
#       ],
#       [
#         "https://scholar.google.com/citations?user=X9R5znMAAAAJ&hl=en",
#         "Quentin Crowley",
#         "Associate Professor, Trinity College Dublin",
#         "Verified email at tcd.ie"
#       ],
#       [
#         "https://scholar.google.com/citations?user=vrknf78AAAAJ&hl=en",
#         "Aftab Alam",
#         "Centre for Earthquake Studies, National Centre for Physics",
#         "Verified email at ncp.edu.pk"
#       ],
#       [
#         "https://scholar.google.com/citations?user=sSaFNC8AAAAJ&hl=en",
#         "Shane Walsh",
#         "PhD Student, University College Dublin",
#         "Verified email at ucdconnect.ie"
#       ],
#       [
#         "https://scholar.google.com/citations?user=SaAV_I8AAAAJ&hl=en",
#         "Muhammad Ali Shah",
#         "Director, Centre for Earthquake Studies (CES), Islamabad",
#         "Verified email at ncp.edu.pk"
#       ],
#       [
#         "https://scholar.google.com/citations?user=9kbPxX0AAAAJ&hl=en",
#         "Bijan Davvaz",
#         "Professor of Mathematics, Yazd University, Yazd, Iran",
#         "Verified email at yazd.ac.ir"
#       ],
#       [
#         "https://scholar.google.com/citations?user=BSDXhwgAAAAJ&hl=en",
#         "Nasir M. Rajpoot",
#         "Director, Tissue Image Analytics (TIA) Centre, University of Warwick",
#         "Verified email at warwick.ac.uk"
#       ],
#       [
#         "https://scholar.google.com/citations?user=HBT8xvUAAAAJ&hl=en",
#         "Peter Lynch",
#         "Emeritus Professor, School of Mathematics & Statistics",
#         "Verified email at ucd.ie"
#       ],
#       [
#         "https://scholar.google.com/citations?user=PRXAyLcAAAAJ&hl=en",
#         "Erdal Karapinar",
#         "Cankaya University, Department of Mathematics, Ankara,Turkey & visiting professor at CMU",
#         "Verified email at mail.cmuh.org.tw"
#       ],
#       [
#         "https://scholar.google.com/citations?user=40U5KvYAAAAJ&hl=en",
#         "Awais Muhammad",
#         "Pr. Scientist, National Centre for Physics",
#         "Verified email at ncp.edu.pk"
#       ]
#     ],
#     "citation_table": [
#       "366",
#       "10"
#     ],
#     "cites": {
#       "years": [
#         "2010",
#         "2011",
#         "2012",
#         "2013",
#         "2014",
#         "2015",
#         "2016",
#         "2017",
#         "2018",
#         "2019",
#         "2020",
#         "2021",
#         "2022"
#       ],
#       "cites": [
#         "3",
#         "4",
#         "2",
#         "7",
#         "6",
#         "3",
#         "3",
#         "4",
#         "13",
#         "20",
#         "86",
#         "114",
#         "99"
#       ]
#     },
#     "name": "Dr Umar Hayat",
#     "organization": "PhD, University of Warwick, UK",
#     "homepage_url": null,
#     "email_info": "qau.edu.pk",
#     "domain_labels": [
#       "algebraic/arithmetic geometry",
#       "machine learning",
#       "information security",
#       "graph theory"
#     ],
#     "extra_co_authors": []
#   }
# ]
# []
# []
# []
# [INFO] branch_type: None
# [INFO] twitter_ids: None
# [Info] Found 1 scholars are in 78k data.
# [Debug] Names: 0    Alejandro Ojeda
# Name: name, dtype: object
# [Info] Find 5 scholars using query without gs_sid in step 4.
# [Info] In total 1 scholar is found:
# [
#   {
#     "academic": false,
#     "academic_age": 15.0,
#     "academic_lifespan": 14.0,
#     "cit_sum_before_year": {
#       "2010": 3,
#       "2011": 22,
#       "2012": 35,
#       "2013": 49,
#       "2014": 85,
#       "2015": 133,
#       "2016": 193,
#       "2017": 289,
#       "2018": 428,
#       "2019": 608,
#       "2020": 785,
#       "2021": 1038
#     },
#     "citation_table": [
#       "1130",
#       "10"
#     ],
#     "domain_labels": [
#       "electromagnetic source imaging",
#       "signal processing",
#       "brain computer interfaces",
#       "machine learning",
#       "sustained attention"
#     ],
#     "gender": "M",
#     "gs_sid": "sxXZxmMAAAAJ",
#     "organization": "Brain Vision, Brain Products",
#     "organization_code": null,
#     "paper_num": 15,
#     "cites": {
#       "years": [
#         "2010",
#         "2011",
#         "2012",
#         "2013",
#         "2014",
#         "2015",
#         "2016",
#         "2017",
#         "2018",
#         "2019",
#         "2020",
#         "2021",
#         "2022"
#       ],
#       "cites": [
#         "3",
#         "19",
#         "13",
#         "14",
#         "36",
#         "48",
#         "60",
#         "96",
#         "139",
#         "180",
#         "177",
#         "253",
#         "82"
#       ]
#     },
#     "coauthors": [
#       [
#         "https://scholar.google.com/citations?user=wQPk6NIAAAAJ&hl=en",
#         "Scott Makeig",
#         "Director, Swartz Center for Computational Neuroscience, Institute for Neural Computation, UCSD",
#         "Verified email at ucsd.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=KZQz_7AAAAAJ&hl=en",
#         "Gert Cauwenberghs",
#         "Professor of Bioengineering and Co-Director, Institute for Neural Computation, UC San Diego",
#         "Verified email at ucsd.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=3hAFHB4AAAAJ&hl=en",
#         "Christian Kothe",
#         "Intheon",
#         "Verified email at intheon.io"
#       ],
#       [
#         "https://scholar.google.com/citations?user=0M2PVJIAAAAJ&hl=en",
#         "Pedro A. Valdes-Sosa",
#         "University of Electronic Science and Technology of China/ Cuban Neuroscience Center",
#         "Verified email at cneuro.edu.cu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=UbLgLucAAAAJ&hl=en",
#         "Pedro Antonio Valdes-Hernandez",
#         "University of Florida",
#         "Verified email at dental.ufl.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=ZyEhJAMAAAAJ&hl=en",
#         "Ken Kreutz-Delgado",
#         "UCSD",
#         "Verified email at eng.ucsd.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=43aedoUAAAAJ&hl=en",
#         "Carlos Muravchik",
#         "Profesor Electrical Engineering - (LEICI) Universidad Nacional de La Plata",
#         "Verified email at ing.unlp.edu.ar"
#       ],
#       [
#         "https://scholar.google.com/citations?user=1RRtTngAAAAJ&hl=en",
#         "Eduardo Mart\u00ednez-Montes",
#         "Neuroinformatics Department, Cuban Neuroscience Center",
#         "Verified email at cneuro.edu.cu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=ZUFLEBIAAAAJ&hl=en",
#         "Jyoti Mishra",
#         "University of California San Diego",
#         "Verified email at ucsd.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=9VGJVCQAAAAJ&hl=en",
#         "Makoto Miyakoshi",
#         "Swartz Center for Computational Neuroscience, INC, UCSD",
#         "Verified email at ucsd.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=ij8pBrQAAAAJ&hl=en",
#         "Yasser Alem\u00e1n G\u00f3mez",
#         "Department of Psychiatry and Department of Radiology. Centre Hospitalier Universitaire Vaudois (CHUV",
#         "Verified email at chuv.ch"
#       ],
#       [
#         "https://scholar.google.com/citations?user=KK-gSk8AAAAJ&hl=en",
#         "Grace Leslie",
#         "Assistant Professor, Georgia Institute of Technology",
#         "Verified email at gatech.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=UTRoDfwAAAAJ&hl=en",
#         "John Rehner Iversen",
#         "University of California San Diego",
#         "Verified email at ucsd.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=CG71Tj0AAAAJ&hl=en",
#         "Marius Klug",
#         "Research Associate / PhD Student, Berlin Institute of Technology",
#         "Verified email at tu-berlin.de"
#       ],
#       [
#         "https://scholar.google.com/citations?user=AzMzY5AAAAAJ&hl=en",
#         "Klaus Gramann",
#         "Technische Universit\u00e4t Berlin",
#         "Verified email at tu-berlin.de"
#       ],
#       [
#         "https://scholar.google.com/citations?user=H58NDVIAAAAJ&hl=en",
#         "Nima Bigdely-Shamlo",
#         "",
#         ""
#       ],
#       [
#         "https://scholar.google.com/citations?user=dL7lCKUAAAAJ&hl=en",
#         "Tomas Ward",
#         "Insight SFI Research Centre for Data Analytics, Dublin City University",
#         "Verified email at dcu.ie"
#       ],
#       [
#         "https://scholar.google.com/citations?user=-aFepXoAAAAJ&hl=en",
#         "Yasser Iturria Medina",
#         "Montreal Neurological Institute",
#         "Verified email at mcgill.ca"
#       ]
#     ],
#     "name": "Alejandro Ojeda",
#     "url": "https://scholar.google.com/citations?hl=en&user=sxXZxmMAAAAJ",
#     "top_num_coauthors": 18.0,
#     "num_domain": 5.0,
#     "top_topic_diversity": 4.0,
#     "num_coauthors_all_wwo_ai": 40,
#     "organization_top": 0.0
#   }
# ]
# []
# []
# [INFO] branch_type: None
# [INFO] twitter_ids: None
# [Info] Found 1 scholars are in 78k data.
# [Debug] Names: 0    Zhaohan Daniel Guo
# Name: name, dtype: object
# [Info] Find 1 scholars using query without gs_sid in step 4.
# [Info] In total 1 scholar is found:
# [
#   {
#     "url": "https://scholar.google.com/citations?hl=en&user=fxr_9oQAAAAJ",
#     "gs_sid": "fxr_9oQAAAAJ",
#     "coauthors": [
#       [
#         "https://scholar.google.com/citations?user=HaN8b2YAAAAJ&hl=en",
#         "Emma Brunskill",
#         "Associate Professor of Computer Science, Stanford University",
#         "Verified email at cs.stanford.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=e8Gzgo4AAAAJ&hl=en",
#         "Philip Thomas",
#         "University of Massachusetts Amherst",
#         "Verified email at cs.umass.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=0CQMPB0AAAAJ&hl=en",
#         "Shayan Doroudi",
#         "Assistant Professor at the University of California, Irvine",
#         "Verified email at uci.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=umAny5UAAAAJ&hl=en",
#         "Yao Liu",
#         "Amazon",
#         "Verified email at stanford.edu"
#       ]
#     ],
#     "citation_table": [
#       "3056",
#       "13"
#     ],
#     "cites": {
#       "years": [
#         "2016",
#         "2017",
#         "2018",
#         "2019",
#         "2020",
#         "2021",
#         "2022"
#       ],
#       "cites": [
#         "13",
#         "15",
#         "45",
#         "67",
#         "249",
#         "1183",
#         "1467"
#       ]
#     },
#     "name": "Zhaohan Daniel Guo",
#     "organization": "DeepMind",
#     "homepage_url": "http://www.cs.cmu.edu/~zguo/",
#     "email_info": "google.com",
#     "domain_labels": [
#       "reinforcement learning"
#     ],
#     "extra_co_authors": []
#   }
# ]
# []
# []
# []
# []
# [INFO] branch_type: None
# [INFO] twitter_ids: None
# [Info] Found 1 scholars are in 78k data.
# [Debug] Names: 0    Shayan Shams
# Name: name, dtype: object
# [Info] Find 1 scholars using query without gs_sid in step 4.
# [Info] In total 1 scholar is found:
# [
#   {
#     "url": "https://scholar.google.com/citations?hl=en&user=KPB33b8AAAAJ",
#     "gs_sid": "KPB33b8AAAAJ",
#     "coauthors": [
#       [
#         "https://scholar.google.com/citations?user=AEJSH4UAAAAJ&hl=en",
#         "Seung-Jong Park",
#         "Professor of Computer Science, Louisiana State University",
#         "Verified email at cct.lsu.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=LLrlZC8AAAAJ&hl=en",
#         "Kisung Lee",
#         "Louisiana State University (LSU)",
#         "Verified email at lsu.edu"
#       ]
#     ],
#     "citation_table": [
#       "338",
#       "8"
#     ],
#     "cites": {
#       "years": [
#         "2014",
#         "2015",
#         "2016",
#         "2017",
#         "2018",
#         "2019",
#         "2020",
#         "2021",
#         "2022"
#       ],
#       "cites": [
#         "6",
#         "4",
#         "7",
#         "21",
#         "41",
#         "65",
#         "102",
#         "87"
#       ]
#     },
#     "name": "Shayan Shams",
#     "organization": "Assistant Professor at University of Texas Health Science Center at Houston",
#     "homepage_url": "https://sbmi.uth.edu/faculty-and-staff/shayan-shams.htm",
#     "email_info": "uth.tmc.edu",
#     "domain_labels": [
#       "artificial intelligence",
#       "deep learning",
#       "computer vision",
#       "health care",
#       "computational biology"
#     ],
#     "extra_co_authors": []
#   }
# ]
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# /tmp/ipykernel_2149/3455754221.py in <module>
# ----> 1 result_name_list = ts.search_scholar_batch(name_list)
#
# ~/src/research/ai-scholar-toolbox/TwitterSearch.py in search_scholar_batch(self, name_list)
#     213         result_list = []
#     214         for name in name_list:
# --> 215             result_list.append(self.search_scholar('name', name))
#     216         return result_list
#     217
#
# ~/src/research/ai-scholar-toolbox/TwitterSearch.py in search_scholar(self, str_type, term)
#      48                 # try directly get twitter account through homepage
#      49                 if 'homepage_url' in scholar_search_result[0] and scholar_search_result[0]['homepage_url'] is not None:
# ---> 50                     twitter_ids = self._search_twitter_from_homepage(scholar_search_result[0]['homepage_url'], name=term, name_from_gs=scholar_search_result[0]["name"])
#      51                 if twitter_ids is not None:
#      52                     branch_type = 'homepage'
#
# ~/src/research/ai-scholar-toolbox/TwitterSearch.py in _search_twitter_from_homepage(self, homepage_url, name, name_from_gs)
#     144     def _search_twitter_from_homepage(self, homepage_url: str, name: str=None, name_from_gs: str=None):
#     145         # get content of scholar homepage using chromedriver
# --> 146         self.driver.get(homepage_url)
#     147         time.sleep(3)
#     148
#
# /mnt/d/prog/anaconda3/envs/res/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     445         Loads a web page in the current browser session.
#     446         """
# --> 447         self.execute(Command.GET, {'url': url})
#     448
#     449     @property
#
# /mnt/d/prog/anaconda3/envs/res/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     433         response = self.command_executor.execute(driver_command, params)
#     434         if response:
# --> 435             self.error_handler.check_response(response)
#     436             response['value'] = self._unwrap_value(
#     437                 response.get('value', None))
#
# /mnt/d/prog/anaconda3/envs/res/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: unknown error: net::ERR_CONNECTION_RESET
#   (Session info: headless chrome=103.0.5060.134)
# Stacktrace:
# #0 0x5610c87bacd3 <unknown>
# #1 0x5610c85c2968 <unknown>
# #2 0x5610c85bc745 <unknown>
# #3 0x5610c85af096 <unknown>
# #4 0x5610c85b0032 <unknown>
# #5 0x5610c85af362 <unknown>
# #6 0x5610c85ae795 <unknown>
# #7 0x5610c85ad45f <unknown>
# #8 0x5610c85ad8c2 <unknown>
# #9 0x5610c85c43c2 <unknown>
# #10 0x5610c862b60f <unknown>
# #11 0x5610c8617bb2 <unknown>
# #12 0x5610c862aea8 <unknown>
# #13 0x5610c8617aa3 <unknown>
# #14 0x5610c85ed3fa <unknown>
# #15 0x5610c85ee555 <unknown>
# #16 0x5610c88022bd <unknown>
# #17 0x5610c8806418 <unknown>
# #18 0x5610c87ec36e <unknown>
# #19 0x5610c8807078 <unknown>
# #20 0x5610c87e0bb0 <unknown>
# #21 0x5610c8823d58 <unknown>
# #22 0x5610c8823ed8 <unknown>
# #23 0x5610c883dcfd <unknown>
# #24 0x7f333f3f9609 <unknown>

# %% [markdown]
# # twitter search

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from TwitterSearch import TwitterSearch

# %%
ts = TwitterSearch('../chromedriver')

# %%
ts.search_scholar('name', 'Ziv Epstein')
# Out:
# [Info] Found 1 scholars are in 78k data.
# [Debug] Names: 0    Ziv Epstein
# Name: name, dtype: object
# [Info] Find 1 scholars using query without gs_sid in step 4.
# [Info] In total 1 scholar is found:
# [
#   {
#     "url": "https://scholar.google.com/citations?hl=en&user=yG7l19UAAAAJ",
#     "gs_sid": "yG7l19UAAAAJ",
#     "coauthors": [
#       [
#         "https://scholar.google.com/citations?user=C0ANojIAAAAJ&hl=en",
#         "David G. Rand",
#         "Erwin H. Schell Professor, Massachusetts Institute of Technology",
#         "Verified email at mit.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=AIbJenwAAAAJ&hl=en",
#         "Gordon Pennycook",
#         "Associate Professor, University of Regina",
#         "Verified email at uregina.ca"
#       ],
#       [
#         "https://scholar.google.com/citations?user=Axm9X-QAAAAJ&hl=en",
#         "Antonio Alonso Arechar",
#         "Economist",
#         "Verified email at arechar.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=Zri-8PwAAAAJ&hl=en",
#         "Matthew Groh",
#         "MIT",
#         "Verified email at mit.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=yKCX2IUAAAAJ&hl=en",
#         "Iyad Rahwan",
#         "Center for Humans & Machines, Max Planck Institute for Human Development",
#         "Verified email at mpib-berlin.mpg.de"
#       ],
#       [
#         "https://scholar.google.com/citations?user=oNQRPLYAAAAJ&hl=en",
#         "Dean Eckles",
#         "MIT",
#         "Verified email at mit.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=DAivUTUAAAAJ&hl=en",
#         "Mohsen Mosleh",
#         "MIT - Sloan School of Management & Exeter Business School",
#         "Verified email at mit.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=ZkBTPkUAAAAJ&hl=en",
#         "Manuel Cebrian",
#         "Universidad Carlos III de Madrid",
#         "Verified email at uc3m.es"
#       ],
#       [
#         "https://scholar.google.com/citations?user=KJNUEgkAAAAJ&hl=en",
#         "Abhimanyu Dubey",
#         "Facebook AI Research",
#         "Verified email at fb.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=nxJvvD0AAAAJ&hl=en",
#         "Bjarke Felbo",
#         "Massachusetts Institute of Technology",
#         "Verified email at felbo.dk"
#       ],
#       [
#         "https://scholar.google.com/citations?user=wFN9eKUAAAAJ&hl=en",
#         "Blakeley Hoffman Payne",
#         "University of Colorado at Boulder",
#         "Verified email at colorado.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=LCjSZ3eS8pIC&hl=en",
#         "Judy Hanwen Shen",
#         "Stanford University",
#         "Verified email at stanford.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=rvHmi4YAAAAJ&hl=en",
#         "William Padula",
#         "University of Southern California",
#         "Verified email at usc.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=zwLePrsAAAAJ&hl=en",
#         "Alex Peysakhovich",
#         "Research Scientist, FAIR",
#         "Verified email at fb.com"
#       ],
#       [
#         "https://scholar.google.com/citations?user=Yt2H6lwAAAAJ&hl=en",
#         "Sydney Levine",
#         "Postdoctoral Associate, Harvard & MIT",
#         "Verified email at mit.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=9mSx8yIAAAAJ&hl=en",
#         "Oc\u00e9ane Boulais",
#         "Researcher, MIT Media Lab",
#         "Verified email at media.mit.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=g0x9raEAAAAJ&hl=en",
#         "Skylar Gordon",
#         "Computation and Cognition, MIT",
#         "Verified email at mit.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=sjaZfDIAAAAJ&hl=en",
#         "Esteban Moro",
#         "Associate Professor, Department Mathematics, Universidad Carlos III de Madrid",
#         "Verified email at math.uc3m.es"
#       ],
#       [
#         "https://scholar.google.com/citations?user=P4nfoKYAAAAJ&hl=en",
#         "Alex `Sandy' Pentland",
#         "Professor MIT",
#         "Verified email at mit.edu"
#       ],
#       [
#         "https://scholar.google.com/citations?user=Dq0Fom8AAAAJ&hl=en",
#         "Dmitriy Smirnov",
#         "Research Scientist, Netflix",
#         "Verified email at netflix.com"
#       ]
#     ],
#     "citation_table": [
#       "904",
#       "11"
#     ],
#     "cites": {
#       "years": [
#         "2014",
#         "2015",
#         "2016",
#         "2017",
#         "2018",
#         "2019",
#         "2020",
#         "2021",
#         "2022"
#       ],
#       "cites": [
#         "3",
#         "11",
#         "26",
#         "26",
#         "68",
#         "51",
#         "97",
#         "257",
#         "335"
#       ]
#     },
#     "name": "Ziv Epstein",
#     "organization": "MIT",
#     "homepage_url": "http://zive.info/",
#     "email_info": "mit.edu",
#     "domain_labels": [
#       "computational social science",
#       "social media",
#       "artificial intelligence",
#       "systems design"
#     ],
#     "extra_co_authors": []
#   }
# ]
# []
# [{'href': 'https://twitter.com/medialab/status/1306366009150976001', 'title': 'MIT Media Lab on Twitter: "In a new paper, Ziv Epstein ...', 'description': 'Sep 16, 2020 — MIT Media Lab on Twitter: "In a new paper, Ziv Epstein, Sydney Levine, David Rand, and Iyad Rahwan consider the question, "Who gets credit\xa0...'}, {'href': 'https://twitter.com/umsi/status/1379531874981310472', 'title': 'School of Information on Twitter: "At this week\'s DS/CSS ...', 'description': 'At this week\'s DS/CSS seminar, PhD student Ziv Epstein of MIT\'s. @medialab. will discuss the proliferation of disinformation with a talk titled: "Shifting\xa0...'}, {'href': 'https://twitter.com/mitsloanexperts/status/1312044727529877504', 'title': 'MIT Sloan Experts on Twitter: "People have many false beliefs ...', 'description': 'Oct 2, 2020 — Mistaken notions of AI agency could be helped by hands-on learning, argues MIT scholar Ziv Epstein. 3:00 PM · Oct 2, 2020 ·Sprout Social.'}, {'href': 'https://twitter.com/medialab/status/1013530209629458433', 'title': 'MIT Media Lab on Twitter: "Visualizing Scissors Congruence, a ...', 'description': 'MIT Media Lab on Twitter: "Visualizing Scissors Congruence, a project from Scalable Cooperation Student Ziv Epstein, is in The National Science Foundation\'s\xa0...'}, {'href': 'https://mobile.twitter.com/zdnet/status/1307092660319117312', 'title': 'ZDNET on Twitter: "People\'s notions about AI are terrible, an ...', 'description': 'Sep 18, 2020 — ZDNET on Twitter: "People\'s notions about AI are terrible, an MIT study ... be helped by hands-on learning, argues MIT scholar Ziv Epstein.'}, {'href': 'http://zive.info/', 'title': 'Zivvy Epstein', 'description': "Zivvy Epstein. I am a PhD student in the MIT Media Lab, where I'm co-advised by David Rand and Sandy Pentland. ... twitter · email · cv · scholar 386."}, {'href': 'https://news.mit.edu/2021/social-media-false-news-reminders-0317', 'title': 'A remedy for the spread of false news? - MIT News', 'description': 'Mar 17, 2021 — ... Ziv Epstein, a PhD candidate at the MIT Media Lab; Mohsen Mosleh, a lecturer at ... as well as a field experiment conducted on Twitter.'}]
# [INFO] branch_type: name + organization
# [INFO] twitter_ids: {'medialab': 2, 'umsi': 1, 'mitsloanexperts': 1, 'zdnet': 1}
# 'medialab'

# %%
# soup, tmp_list = ts._search_twitter_from_homepage('https://jermainewang.github.io/', name='Minjie Wang')
tmp = ts._search_twitter_from_homepage('http://zive.info/', name='Zivvy Epstein')
# Out:
# []

# %%
tmp
# Out:
# <html><head><title>** zive.info **</title><meta content="" name="description"/><meta content="" name="keywords"/></head><frameset border="0" rows="100%,*"><frame frameborder="0" src="http://web.media.mit.edu/~zive/"/></frameset></html>

# %%
from utils import get_str_similarity
get_str_similarity('samsontmr', 'samsontan')
# Out:
# 0.7777777777777778

# %%
import re
print(soup.find_all(href=re.compile('twitter.com/'))[1])
# Out:
# <a href="https://twitter.com/GraphDeep/">twitter account</a>

# %%
print(soup.find_all(href=re.compile('twitter.com/'))[0]['href'])
# Out:
# https://twitter.com/minjie_nyu

# %%
from selenium.webdriver.common.by import By

# %%
from bs4 import BeautifulSoup
page = ts.driver.page_source
soup = BeautifulSoup(page, "html.parser")

# %%
result_block = soup.find_all('div', attrs={'class': 'g'})
for result in result_block:
    # Find link, title, description
    # print(result)
    link = result.find('a', href=True)
    title = result.find('h3')
    description_box = result.find('div', {'style': '-webkit-line-clamp:2'})
    if link and title and description_box:
        # description = description_box.find('span')
        # if link and title and description:
            # result_list.append(SearchResult(link['href'], title.text, description.text))
            # print(link['href'], title.text, description.text)
        # print(description_box.text)
        print(link['href'])
        print('\n')
# Out:
# https://twitter.com/zhijingjin?lang=en
#
#
# https://twitter.com/ZhijingJin/status/1422153131585150979
#
#
# https://twitter.com/ZhijingJin/status/1543329155923599360
#
#
# https://twitter.com/ZhijingJin/status/1471233274311811073
#
#
# https://twitter.com/ZhijingJin/status/1552356661829914634
#
#
# https://twitter.com/ZhijingJin/status/1555126680557166595
#
#
# https://mobile.twitter.com/ZhijingJin/status/1529038162034577408
#
#
# https://twitter.com/ZhijingJin/status/1413750729991499777
#
#
# https://twitter.com/zhijingjin/status/1524075310475620355
#
#
# https://twitter.com/ZhijingJin/status/1559966514500866048

# %%
result_block = soup.find_all('div', attrs={'class': 'g'})
for result in result_block:
    # Find link, title, description
    # print(result)
    link = result.find('a', href=True)
    title = result.find('h3')
    description_box = result.find('div', {'style': '-webkit-line-clamp:2'})
    if description_box:
        description = description_box.find('span')
        if link and title and description:
            # result_list.append(SearchResult(link['href'], title.text, description.text))
            # print(link['href'], title.text, description.text)
            print(description.text)
# Out:
# Zhijing Jin (@ZhijingJin) / Twitter ...
# Jul 27, 2022 —
# Mar 18, 2022 —
# Nov 12, 2021 —
# May 22, 2022 —
# PhD at Max Planck Institute & ETH, affiliated at UMich (2020-2024 expected) Email: jinzhi@ethz.ch ‍  Google Scholar / CV / twitter-icon @ZhijingJin

# %%
result = driver.find_elements(By.TAG_NAME, 'div')

# %%
result
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="c97af1a6-5a45-4a6d-a1bb-55041338444d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="ec3539df-feea-457d-b991-d12c507793ca")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="a78f47e9-88ec-4875-88b3-542695f6ee11")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="435fbd42-d250-4c9b-8bb3-8c69d46efa33")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="1df2e1f4-2a0e-4a17-ae31-0b8198eeb746")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="a7665a49-f5df-4f7d-8d37-18e4ae76dbb4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="8de64eb1-5088-47ad-a6a7-14861556ed95")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="9c155fa8-82f8-45c8-bbe0-f0e6942f70ca")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="0d548325-cbf8-402d-878c-6fb25bbf6d39")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="e3b301d1-76cb-480e-b817-8c2dbe746e0a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="a4101a7b-da9d-4e56-9674-302b04543b46")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="77143355-32e9-423d-a260-ec5bdd2eea17")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="edba9911-84b9-4987-8df4-d5a6887bd29f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="8717f0cb-c3f5-42b6-972d-bf71cc44edfd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="8fb93c21-05ad-4dc2-839b-bb83b9430936")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="7363e17e-4cee-4bb5-baed-85b99d5255aa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="966ba25e-51ce-45fc-aed3-39f0aa59b84d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="c4da54f8-6094-4598-a850-3dcbd74dc341")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="61e302a6-6fe1-492c-8293-c1c17553b9f4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="9781a926-1365-4e84-b532-ce39b7dbfe11")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="b9159ea1-494f-4dc3-a3c7-fb63fec8b5e1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="8434754b-81d9-48e9-9f92-be2c97672098")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="24ed2a45-14ce-4b6f-b2ab-3935e313f1c7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="e519d08d-64a6-4088-ab41-bab166c63100")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="c6c68ee1-6949-482a-bc71-3baf9b5efcb0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="ea44c53a-5fcb-4a1c-b833-d028f2a0f587")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="fb5205be-2cee-4699-a698-c02baadd5a36")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="8d4de810-3a56-48f8-8c53-ef9ea44f0db0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="f354c37e-b384-42d4-9f58-4ed580ac260e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="70e152e8-d743-4ca6-8f73-e52b034c8f8e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="9973bfda-7e27-4755-8ff4-b5b7150af044")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="11fdfdd7-83d1-435c-9865-a91bd27faa3b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="8987f1a0-5b04-4df0-9021-590de9565671")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="43657173-ef7c-4562-b562-e531246d34f8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="cf8a5119-4b89-4ff9-ab20-74d3ae65d499")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="08fcd4bf-06b1-40c2-8496-48896aa17551")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="0989225b-58b2-4452-a17b-067daecaeb8c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="099574d5-f7b6-4b5a-aabf-4185f6989fbc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="a8220e29-afe8-49ba-b711-c910fa67dd25")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="c338313f-3421-46fd-95f6-6f3ebd4e56fb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="d0eab7b9-7f8a-46b3-8acc-585ebfa32f8c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="ed6aa9fa-5d56-47d6-807a-63891c370978")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="b62c28e8-27e0-4b7a-91b3-cca189e4202a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="43edf193-ed09-4226-9f7e-a0ba3433f2af")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="526badd8-45eb-47bf-9eea-453fa893cc8c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="a80869b3-ca09-4e97-b9f6-b81e7446b542")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="330b21c3-64c8-4935-88bc-21b9586d37f3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="4f55faa3-669a-457d-8854-b927210265ac")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="59cde9ce-d888-487d-bf05-09c4cb9d5a7f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="a30f17c0-3fe8-4b70-bef9-fd9712e7ed47")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="f756a4e0-bc3b-44d9-8dd2-2e2197f62dff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="426f62df-2bd0-4115-b087-096e17c30db7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="ba5924bc-66a6-40a0-92a4-8ca9564bdc33")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="297b3c7e-c69c-4e1c-9ddd-f361f1463e00")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="811c27e5-c1da-4432-ba99-8ada5740dbff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="92a58ecc-da30-4ee6-83a7-4e75df1359b3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="43a41848-2e43-4f00-b8bc-2274df2e43af")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="f8a5a4d4-4796-4d14-bc36-723bb18ee106")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="256607d6-00ee-45a2-af9c-be239dfa43c8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="b4fcdb21-5934-4cd5-90e6-93ad94bf4c17")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="a3e70bf0-0bb8-49d6-bed0-be19c0b6b4fa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="2c6fe3e4-ea90-4885-b0f8-f3dc4360447e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="803c82d6-0607-4013-8516-ceb3b5f4b15e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="252d5401-bb11-4d34-83f6-9b6a7de6cb63")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="ef32727d-d0b2-4112-9567-5ab59b1725e8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="1a00a749-0e72-46ca-90f0-516072e1c39e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="71294b56-a4bd-48f8-8b17-9f161036a75d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="c342d635-f8fa-4a06-931d-0303c2f4ab8f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="6b6711bc-5465-4b5a-b98d-7122f892b262")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="c98dd4bf-fdca-462f-bcb8-90a9aa5b9620")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="29250798-34d3-420f-9eaf-0319272cc060")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="dec1fa1a-4c03-452e-9e48-831cc49dd7d5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="96436bc9-280f-4a70-a3a2-a1b6b9bea425")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="2a42c2d2-8480-4462-8f3b-1f51d20dbc50")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="32563f3d-d486-4490-858b-a1a55ac8fb05")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="a270be40-0b10-4fe9-be73-044cce14b266")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="2a4ab7db-fbe9-4e0f-8380-c894910376ea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="b425a057-9ad0-4163-9973-9e190a9ba155")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="2ee161a8-5fcf-48d0-a075-a4ff7573b22b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="94921080-e85a-4cdf-bd68-a9c33dc7dabe")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="022bdccb-36ee-4332-84f4-3bbe22311d24")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="6abbd8bf-d7d8-4b4f-9b60-b9944ff33bdc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="7aec6afd-5eda-49c3-8ed5-9812cd68aa38")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="c6ea670e-1e52-4792-9f92-cacc80fabf0c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="a145cd51-d4f4-42c9-b86f-a4da43858b8d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="ec0a0a8b-dc63-49c9-b759-771df8dba086")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="168e1c10-a502-4815-b95c-3d5cab668841")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="9aa3651a-831f-405e-9392-0fc50025b829")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="9e9c1595-b638-4a99-813e-7879424bc58f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="7d3b29d4-5a87-47ca-9db1-b950476fceab")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="c238e9b8-1ca4-462c-b3c0-1a0d93715106")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="4361801d-9a83-41e8-92be-d8a15f3ba660")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="bf0dbaf5-32ec-44e8-a8e5-531ecfb632fb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="a505bf68-ca20-4d1b-9fcc-f99bbd697afa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="3ab1193c-bb76-4a2a-9e6b-6c9d4b9d0b82")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="a82380ae-19a0-4f07-982d-ef8f99ee1113")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="4e881180-b1b0-4748-adbf-b8e75bd2fb54")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="7a2aa703-397c-42a1-8a9a-cd2cf9f8ebcd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7cba4730afc9b81ccf40abdd686b5ae3", element="84d73234-69c6-470a-8866-0600f05c39d1")>]

# %%
for res_item in result:
    # print(res_item.get_attribute('class'))
    print(res_item.get_attribute('textContent'))
    # print(res_item.find_elements(By.CLASS_NAME, 'g'))
# Out:
# .Ne6nSd{display:flex;align-items:center;padding:6px}a.MV3Tnb{display:inline-block;padding:5px;margin:0 5px;color:#202124}a.MV3Tnb:first-of-type{margin-left:15px}.LX3sZb{display:inline-block;flex-grow:1}AboutStoreGmailImagesSign in.LS8OJ{display:flex;flex-direction:column;align-items:center}.k1zIA{height:100%;margin-top:auto}.rSk4se{max-height:92px;position:relative}.lnXdpd{max-height:100%;max-width:100%;object-fit:contain;object-position:center bottom;width:auto}.om7nvf{padding:20px}.spch-dlg{background:transparent;border:none}.spch{background:#fff;height:100%;left:0;opacity:0;overflow:hidden;position:fixed;text-align:left;top:0;visibility:hidden;width:100%;z-index:10000;transition:visibility 0s linear 0.218s,background-color 0.218s;}.s2fp.spch{opacity:1;transition-delay:0s;visibility:visible;}.close-button{background:none;border:none;color:#70757a;cursor:pointer;font-size:26px;right:0;line-height:15px;opacity:.6;margin:-1px -1px 0 0;padding:0 0 2px 0;height:48px;width:48px;position:absolute;top:0;z-index:10}.close-button:hover{opacity:.8}.close-button:active{opacity:1}.spchc{display:block;height:42px;pointer-events:none;margin:auto;position:relative;top:0;margin-top:312px;max-width:572px;min-width:534px;padding:0 223px}.inner-container{height:100%;opacity:.1;pointer-events:none;width:100%;transition:opacity .318s ease-in}.s2ml .inner-container,.s2ra .inner-container,.s2er .inner-container{opacity:1;transition:opacity 0s}.google-logo{background:url(data:image/png;base64,...) no-repeat center;background-size:94px 32px;height:32px;width:94px;top:8px;opacity:0;float:right;left:255px;pointer-events:none;position:relative;transition:opacity .5s ease-in,left .5s ease-in}×.button{background-color:#fff;border:1px solid #eee;border-radius:100%;bottom:0;box-shadow:0 2px 5px rgba(0,0,0,.1);cursor:pointer;display:inline-block;opacity:0;pointer-events:none;position:absolute;right:0;transition:background-color 0.218s,border 0.218s,box-shadow 0.218s;transition-delay:0;position:absolute;opacity:0;left:0;top:0}.s2fp .button{opacity:1;pointer-events:auto;transform:scale(1);}.s2ra .button{background-color:#f44;border:0;box-shadow:none}.r8s4j{background-color:#dbdbdb;border-radius:100%;display:inline-block;opacity:1;pointer-events:none;position:absolute;transform:scale(.01);transition:opacity 0.218s;height:301px;left:-69px;top:-69px;width:301px;}.button-container{pointer-events:none;position:relative;transition:transform 0.218s,opacity 0.218s ease-in;transform:scale(.1);height:165px;width:165px;right:-70px;top:-70px;float:right;}.s2fp .button-container{transform:scale(1)}.s2ra .button:active{background-color:#cd0000}.button:active{background-color:#eee}.microphone{height:87px;pointer-events:none;position:absolute;width:42px;top:47px;transform:scale(1);left:43px;}.receiver{background-color:#999;border-radius:30px;height:46px;left:25px;pointer-events:none;position:absolute;width:24px}.wrapper{bottom:0;height:53px;left:11px;overflow:hidden;pointer-events:none;position:absolute;width:52px}.stem{background-color:#999;bottom:14px;height:14px;left:22px;pointer-events:none;position:absolute;width:9px;z-index:1}.shell{border:7px solid #999;border-radius:28px;bottom:27px;height:57px;pointer-events:none;position:absolute;width:38px;z-index:0;left:0px}.s2ml .receiver,.s2ml .stem{background-color:#f44}.s2ml .shell{border-color:#f44}.s2ra .receiver,.s2ra .stem{background-color:#fff}.s2ra .shell{border-color:#fff}.text-container{pointer-events:none;position:absolute;}.spcht{font-weight:normal;line-height:1.2;opacity:0;pointer-events:none;position:absolute;text-align:left;-webkit-font-smoothing:antialiased;transition:opacity .1s ease-in,margin-left .5s ease-in,top 0s linear 0.218s;left:-44px;top:-.2em;margin-left:44px;font-size:32px;width:460px;}.s2fp .spcht{margin-left:0;opacity:1;transition:opacity .5s ease-out,margin-left .5s ease-out}.spchta{color:#15c;cursor:pointer;font-size:18px;font-weight:500;pointer-events:auto;text-decoration:underline}.spch-2l.spcht, ...
# .Ne6nSd{display:flex;align-items:center;padding:6px}a.MV3Tnb{display:inline-block;padding:5px;margin:0 5px;color:#202124}a.MV3Tnb:first-of-type{margin-left:15px}.LX3sZb{display:inline-block;flex-grow:1}AboutStoreGmailImagesSign in
# GmailImagesSign in
# GmailImagesSign in
# GmailImagesSign in
# GmailImages
# GmailImages
# Gmail
# Images
# Sign in
#
#
#
#
# .LS8OJ{display:flex;flex-direction:column;align-items:center}.k1zIA{height:100%;margin-top:auto}.rSk4se{max-height:92px;position:relative}.lnXdpd{max-height:100%;max-width:100%;object-fit:contain;object-position:center bottom;width:auto}
# .rSk4se{max-height:92px;position:relative}.lnXdpd{max-height:100%;max-width:100%;object-fit:contain;object-position:center bottom;width:auto}
# .om7nvf{padding:20px}.spch-dlg{background:transparent;border:none}.spch{background:#fff;height:100%;left:0;opacity:0;overflow:hidden;position:fixed;text-align:left;top:0;visibility:hidden;width:100%;z-index:10000;transition:visibility 0s linear 0.218s,background-color 0.218s;}.s2fp.spch{opacity:1;transition-delay:0s;visibility:visible;}.close-button{background:none;border:none;color:#70757a;cursor:pointer;font-size:26px;right:0;line-height:15px;opacity:.6;margin:-1px -1px 0 0;padding:0 0 2px 0;height:48px;width:48px;position:absolute;top:0;z-index:10}.close-button:hover{opacity:.8}.close-button:active{opacity:1}.spchc{display:block;height:42px;pointer-events:none;margin:auto;position:relative;top:0;margin-top:312px;max-width:572px;min-width:534px;padding:0 223px}.inner-container{height:100%;opacity:.1;pointer-events:none;width:100%;transition:opacity .318s ease-in}.s2ml .inner-container,.s2ra .inner-container,.s2er .inner-container{opacity:1;transition:opacity 0s}.google-logo{background:url(data:image/png;base64,...) no-repeat center;background-size:94px 32px;height:32px;width:94px;top:8px;opacity:0;float:right;left:255px;pointer-events:none;position:relative;transition:opacity .5s ease-in,left .5s ease-in}×.button{background-color:#fff;border:1px solid #eee;border-radius:100%;bottom:0;box-shadow:0 2px 5px rgba(0,0,0,.1);cursor:pointer;display:inline-block;opacity:0;pointer-events:none;position:absolute;right:0;transition:background-color 0.218s,border 0.218s,box-shadow 0.218s;transition-delay:0;position:absolute;opacity:0;left:0;top:0}.s2fp .button{opacity:1;pointer-events:auto;transform:scale(1);}.s2ra .button{background-color:#f44;border:0;box-shadow:none}.r8s4j{background-color:#dbdbdb;border-radius:100%;display:inline-block;opacity:1;pointer-events:none;position:absolute;transform:scale(.01);transition:opacity 0.218s;height:301px;left:-69px;top:-69px;width:301px;}.button-container{pointer-events:none;position:relative;transition:transform 0.218s,opacity 0.218s ease-in;transform:scale(.1);height:165px;width:165px;right:-70px;top:-70px;float:right;}.s2fp .button-container{transform:scale(1)}.s2ra .button:active{background-color:#cd0000}.button:active{background-color:#eee}.microphone{height:87px;pointer-events:none;position:absolute;width:42px;top:47px;transform:scale(1);left:43px;}.receiver{background-color:#999;border-radius:30px;height:46px;left:25px;pointer-events:none;position:absolute;width:24px}.wrapper{bottom:0;height:53px;left:11px;overflow:hidden;pointer-events:none;position:absolute;width:52px}.stem{background-color:#999;bottom:14px;height:14px;left:22px;pointer-events:none;position:absolute;width:9px;z-index:1}.shell{border:7px solid #999;border-radius:28px;bottom:27px;height:57px;pointer-events:none;position:absolute;width:38px;z-index:0;left:0px}.s2ml .receiver,.s2ml .stem{background-color:#f44}.s2ml .shell{border-color:#f44}.s2ra .receiver,.s2ra .stem{background-color:#fff}.s2ra .shell{border-color:#fff}.text-container{pointer-events:none;position:absolute;}.spcht{font-weight:normal;line-height:1.2;opacity:0;pointer-events:none;position:absolute;text-align:left;-webkit-font-smoothing:antialiased;transition:opacity .1s ease-in,margin-left .5s ease-in,top 0s linear 0.218s;left:-44px;top:-.2em;margin-left:44px;font-size:32px;width:460px;}.s2fp .spcht{margin-left:0;opacity:1;transition:opacity .5s ease-out,margin-left .5s ease-out}.spchta{color:#15c;cursor:pointer;font-size:18px;font-weight:500;pointer-events:auto;text-decoration:underline}.spch-2l.spcht,.spch-3l.spcht,.spch-4l.spcht{transition:top 0.218s ease-out}.spch-2l.spcht{top:-.6em}.spch-3l.spcht{top:-1.3em}.spch-4l.spcht{top:-1.7em}.s2fp .spch-5l.spcht{top:-2.5em;}.permission-bar{margin-top:-100px;opacity:0;pointer-events:none;position:absolute;width:500px;transition:opacity 0.218s ease-in,margin-top .4s ease-in}.s2wfp .permission-bar{margin-top:-300px;opacity:1;transition:opacity .5s ease-out 0.218s,margin-top 0.218s ease-out 0.218s}.permission-bar-gradi ...
# .spch-dlg{background:transparent;border:none}.spch{background:#fff;height:100%;left:0;opacity:0;overflow:hidden;position:fixed;text-align:left;top:0;visibility:hidden;width:100%;z-index:10000;transition:visibility 0s linear 0.218s,background-color 0.218s;}.s2fp.spch{opacity:1;transition-delay:0s;visibility:visible;}.close-button{background:none;border:none;color:#70757a;cursor:pointer;font-size:26px;right:0;line-height:15px;opacity:.6;margin:-1px -1px 0 0;padding:0 0 2px 0;height:48px;width:48px;position:absolute;top:0;z-index:10}.close-button:hover{opacity:.8}.close-button:active{opacity:1}.spchc{display:block;height:42px;pointer-events:none;margin:auto;position:relative;top:0;margin-top:312px;max-width:572px;min-width:534px;padding:0 223px}.inner-container{height:100%;opacity:.1;pointer-events:none;width:100%;transition:opacity .318s ease-in}.s2ml .inner-container,.s2ra .inner-container,.s2er .inner-container{opacity:1;transition:opacity 0s}.google-logo{background:url(data:image/png;base64,...) no-repeat center;background-size:94px 32px;height:32px;width:94px;top:8px;opacity:0;float:right;left:255px;pointer-events:none;position:relative;transition:opacity .5s ease-in,left .5s ease-in}×.button{background-color:#fff;border:1px solid #eee;border-radius:100%;bottom:0;box-shadow:0 2px 5px rgba(0,0,0,.1);cursor:pointer;display:inline-block;opacity:0;pointer-events:none;position:absolute;right:0;transition:background-color 0.218s,border 0.218s,box-shadow 0.218s;transition-delay:0;position:absolute;opacity:0;left:0;top:0}.s2fp .button{opacity:1;pointer-events:auto;transform:scale(1);}.s2ra .button{background-color:#f44;border:0;box-shadow:none}.r8s4j{background-color:#dbdbdb;border-radius:100%;display:inline-block;opacity:1;pointer-events:none;position:absolute;transform:scale(.01);transition:opacity 0.218s;height:301px;left:-69px;top:-69px;width:301px;}.button-container{pointer-events:none;position:relative;transition:transform 0.218s,opacity 0.218s ease-in;transform:scale(.1);height:165px;width:165px;right:-70px;top:-70px;float:right;}.s2fp .button-container{transform:scale(1)}.s2ra .button:active{background-color:#cd0000}.button:active{background-color:#eee}.microphone{height:87px;pointer-events:none;position:absolute;width:42px;top:47px;transform:scale(1);left:43px;}.receiver{background-color:#999;border-radius:30px;height:46px;left:25px;pointer-events:none;position:absolute;width:24px}.wrapper{bottom:0;height:53px;left:11px;overflow:hidden;pointer-events:none;position:absolute;width:52px}.stem{background-color:#999;bottom:14px;height:14px;left:22px;pointer-events:none;position:absolute;width:9px;z-index:1}.shell{border:7px solid #999;border-radius:28px;bottom:27px;height:57px;pointer-events:none;position:absolute;width:38px;z-index:0;left:0px}.s2ml .receiver,.s2ml .stem{background-color:#f44}.s2ml .shell{border-color:#f44}.s2ra .receiver,.s2ra .stem{background-color:#fff}.s2ra .shell{border-color:#fff}.text-container{pointer-events:none;position:absolute;}.spcht{font-weight:normal;line-height:1.2;opacity:0;pointer-events:none;position:absolute;text-align:left;-webkit-font-smoothing:antialiased;transition:opacity .1s ease-in,margin-left .5s ease-in,top 0s linear 0.218s;left:-44px;top:-.2em;margin-left:44px;font-size:32px;width:460px;}.s2fp .spcht{margin-left:0;opacity:1;transition:opacity .5s ease-out,margin-left .5s ease-out}.spchta{color:#15c;cursor:pointer;font-size:18px;font-weight:500;pointer-events:auto;text-decoration:underline}.spch-2l.spcht,.spch-3l.spcht,.spch-4l.spcht{transition:top 0.218s ease-out}.spch-2l.spcht{top:-.6em}.spch-3l.spcht{top:-1.3em}.spch-4l.spcht{top:-1.7em}.s2fp .spch-5l.spcht{top:-2.5em;}.permission-bar{margin-top:-100px;opacity:0;pointer-events:none;position:absolute;width:500px;transition:opacity 0.218s ease-in,margin-top .4s ease-in}.s2wfp .permission-bar{margin-top:-300px;opacity:1;transition:opacity .5s ease-out 0.218s,margin-top 0.218s ease-out 0.218s}.permission-bar-gradient{box-shadow:0 1px  ...
# .button{background-color:#fff;border:1px solid #eee;border-radius:100%;bottom:0;box-shadow:0 2px 5px rgba(0,0,0,.1);cursor:pointer;display:inline-block;opacity:0;pointer-events:none;position:absolute;right:0;transition:background-color 0.218s,border 0.218s,box-shadow 0.218s;transition-delay:0;position:absolute;opacity:0;left:0;top:0}.s2fp .button{opacity:1;pointer-events:auto;transform:scale(1);}.s2ra .button{background-color:#f44;border:0;box-shadow:none}.r8s4j{background-color:#dbdbdb;border-radius:100%;display:inline-block;opacity:1;pointer-events:none;position:absolute;transform:scale(.01);transition:opacity 0.218s;height:301px;left:-69px;top:-69px;width:301px;}.button-container{pointer-events:none;position:relative;transition:transform 0.218s,opacity 0.218s ease-in;transform:scale(.1);height:165px;width:165px;right:-70px;top:-70px;float:right;}.s2fp .button-container{transform:scale(1)}.s2ra .button:active{background-color:#cd0000}.button:active{background-color:#eee}.microphone{height:87px;pointer-events:none;position:absolute;width:42px;top:47px;transform:scale(1);left:43px;}.receiver{background-color:#999;border-radius:30px;height:46px;left:25px;pointer-events:none;position:absolute;width:24px}.wrapper{bottom:0;height:53px;left:11px;overflow:hidden;pointer-events:none;position:absolute;width:52px}.stem{background-color:#999;bottom:14px;height:14px;left:22px;pointer-events:none;position:absolute;width:9px;z-index:1}.shell{border:7px solid #999;border-radius:28px;bottom:27px;height:57px;pointer-events:none;position:absolute;width:38px;z-index:0;left:0px}.s2ml .receiver,.s2ml .stem{background-color:#f44}.s2ml .shell{border-color:#f44}.s2ra .receiver,.s2ra .stem{background-color:#fff}.s2ra .shell{border-color:#fff}.text-container{pointer-events:none;position:absolute;}.spcht{font-weight:normal;line-height:1.2;opacity:0;pointer-events:none;position:absolute;text-align:left;-webkit-font-smoothing:antialiased;transition:opacity .1s ease-in,margin-left .5s ease-in,top 0s linear 0.218s;left:-44px;top:-.2em;margin-left:44px;font-size:32px;width:460px;}.s2fp .spcht{margin-left:0;opacity:1;transition:opacity .5s ease-out,margin-left .5s ease-out}.spchta{color:#15c;cursor:pointer;font-size:18px;font-weight:500;pointer-events:auto;text-decoration:underline}.spch-2l.spcht,.spch-3l.spcht,.spch-4l.spcht{transition:top 0.218s ease-out}.spch-2l.spcht{top:-.6em}.spch-3l.spcht{top:-1.3em}.spch-4l.spcht{top:-1.7em}.s2fp .spch-5l.spcht{top:-2.5em;}.permission-bar{margin-top:-100px;opacity:0;pointer-events:none;position:absolute;width:500px;transition:opacity 0.218s ease-in,margin-top .4s ease-in}.s2wfp .permission-bar{margin-top:-300px;opacity:1;transition:opacity .5s ease-out 0.218s,margin-top 0.218s ease-out 0.218s}.permission-bar-gradient{box-shadow:0 1px 0px #4285f4;height:80px;left:0;margin:0;opacity:0;pointer-events:none;position:fixed;right:0;top:-80px;transition:opacity 0.218s,box-shadow 0.218s}.s2wfp .permission-bar-gradient{box-shadow:0 1px 80px #4285f4;opacity:1;pointer-events:none;animation:allow-alert .75s 0 infinite;animation-direction:alternate;animation-timing-function:ease-out;transition:opacity 0.218s,box-shadow 0.218s}@-webkit-keyframes allow-alert {from{opacity:1}to{opacity:.35}}
# .button{background-color:#fff;border:1px solid #eee;border-radius:100%;bottom:0;box-shadow:0 2px 5px rgba(0,0,0,.1);cursor:pointer;display:inline-block;opacity:0;pointer-events:none;position:absolute;right:0;transition:background-color 0.218s,border 0.218s,box-shadow 0.218s;transition-delay:0;position:absolute;opacity:0;left:0;top:0}.s2fp .button{opacity:1;pointer-events:auto;transform:scale(1);}.s2ra .button{background-color:#f44;border:0;box-shadow:none}.r8s4j{background-color:#dbdbdb;border-radius:100%;display:inline-block;opacity:1;pointer-events:none;position:absolute;transform:scale(.01);transition:opacity 0.218s;height:301px;left:-69px;top:-69px;width:301px;}.button-container{pointer-events:none;position:relative;transition:transform 0.218s,opacity 0.218s ease-in;transform:scale(.1);height:165px;width:165px;right:-70px;top:-70px;float:right;}.s2fp .button-container{transform:scale(1)}.s2ra .button:active{background-color:#cd0000}.button:active{background-color:#eee}.microphone{height:87px;pointer-events:none;position:absolute;width:42px;top:47px;transform:scale(1);left:43px;}.receiver{background-color:#999;border-radius:30px;height:46px;left:25px;pointer-events:none;position:absolute;width:24px}.wrapper{bottom:0;height:53px;left:11px;overflow:hidden;pointer-events:none;position:absolute;width:52px}.stem{background-color:#999;bottom:14px;height:14px;left:22px;pointer-events:none;position:absolute;width:9px;z-index:1}.shell{border:7px solid #999;border-radius:28px;bottom:27px;height:57px;pointer-events:none;position:absolute;width:38px;z-index:0;left:0px}.s2ml .receiver,.s2ml .stem{background-color:#f44}.s2ml .shell{border-color:#f44}.s2ra .receiver,.s2ra .stem{background-color:#fff}.s2ra .shell{border-color:#fff}.text-container{pointer-events:none;position:absolute;}.spcht{font-weight:normal;line-height:1.2;opacity:0;pointer-events:none;position:absolute;text-align:left;-webkit-font-smoothing:antialiased;transition:opacity .1s ease-in,margin-left .5s ease-in,top 0s linear 0.218s;left:-44px;top:-.2em;margin-left:44px;font-size:32px;width:460px;}.s2fp .spcht{margin-left:0;opacity:1;transition:opacity .5s ease-out,margin-left .5s ease-out}.spchta{color:#15c;cursor:pointer;font-size:18px;font-weight:500;pointer-events:auto;text-decoration:underline}.spch-2l.spcht,.spch-3l.spcht,.spch-4l.spcht{transition:top 0.218s ease-out}.spch-2l.spcht{top:-.6em}.spch-3l.spcht{top:-1.3em}.spch-4l.spcht{top:-1.7em}.s2fp .spch-5l.spcht{top:-2.5em;}
# .button{background-color:#fff;border:1px solid #eee;border-radius:100%;bottom:0;box-shadow:0 2px 5px rgba(0,0,0,.1);cursor:pointer;display:inline-block;opacity:0;pointer-events:none;position:absolute;right:0;transition:background-color 0.218s,border 0.218s,box-shadow 0.218s;transition-delay:0;position:absolute;opacity:0;left:0;top:0}.s2fp .button{opacity:1;pointer-events:auto;transform:scale(1);}.s2ra .button{background-color:#f44;border:0;box-shadow:none}.r8s4j{background-color:#dbdbdb;border-radius:100%;display:inline-block;opacity:1;pointer-events:none;position:absolute;transform:scale(.01);transition:opacity 0.218s;height:301px;left:-69px;top:-69px;width:301px;}.button-container{pointer-events:none;position:relative;transition:transform 0.218s,opacity 0.218s ease-in;transform:scale(.1);height:165px;width:165px;right:-70px;top:-70px;float:right;}.s2fp .button-container{transform:scale(1)}.s2ra .button:active{background-color:#cd0000}.button:active{background-color:#eee}.microphone{height:87px;pointer-events:none;position:absolute;width:42px;top:47px;transform:scale(1);left:43px;}.receiver{background-color:#999;border-radius:30px;height:46px;left:25px;pointer-events:none;position:absolute;width:24px}.wrapper{bottom:0;height:53px;left:11px;overflow:hidden;pointer-events:none;position:absolute;width:52px}.stem{background-color:#999;bottom:14px;height:14px;left:22px;pointer-events:none;position:absolute;width:9px;z-index:1}.shell{border:7px solid #999;border-radius:28px;bottom:27px;height:57px;pointer-events:none;position:absolute;width:38px;z-index:0;left:0px}.s2ml .receiver,.s2ml .stem{background-color:#f44}.s2ml .shell{border-color:#f44}.s2ra .receiver,.s2ra .stem{background-color:#fff}.s2ra .shell{border-color:#fff}
# .microphone{height:87px;pointer-events:none;position:absolute;width:42px;top:47px;transform:scale(1);left:43px;}.receiver{background-color:#999;border-radius:30px;height:46px;left:25px;pointer-events:none;position:absolute;width:24px}.wrapper{bottom:0;height:53px;left:11px;overflow:hidden;pointer-events:none;position:absolute;width:52px}.stem{background-color:#999;bottom:14px;height:14px;left:22px;pointer-events:none;position:absolute;width:9px;z-index:1}.shell{border:7px solid #999;border-radius:28px;bottom:27px;height:57px;pointer-events:none;position:absolute;width:38px;z-index:0;left:0px}.s2ml .receiver,.s2ml .stem{background-color:#f44}.s2ml .shell{border-color:#f44}.s2ra .receiver,.s2ra .stem{background-color:#fff}.s2ra .shell{border-color:#fff}
#
# .text-container{pointer-events:none;position:absolute;}.spcht{font-weight:normal;line-height:1.2;opacity:0;pointer-events:none;position:absolute;text-align:left;-webkit-font-smoothing:antialiased;transition:opacity .1s ease-in,margin-left .5s ease-in,top 0s linear 0.218s;left:-44px;top:-.2em;margin-left:44px;font-size:32px;width:460px;}.s2fp .spcht{margin-left:0;opacity:1;transition:opacity .5s ease-out,margin-left .5s ease-out}.spchta{color:#15c;cursor:pointer;font-size:18px;font-weight:500;pointer-events:auto;text-decoration:underline}.spch-2l.spcht,.spch-3l.spcht,.spch-4l.spcht{transition:top 0.218s ease-out}.spch-2l.spcht{top:-.6em}.spch-3l.spcht{top:-1.3em}.spch-4l.spcht{top:-1.7em}.s2fp .spch-5l.spcht{top:-2.5em;}
#
# .permission-bar{margin-top:-100px;opacity:0;pointer-events:none;position:absolute;width:500px;transition:opacity 0.218s ease-in,margin-top .4s ease-in}.s2wfp .permission-bar{margin-top:-300px;opacity:1;transition:opacity .5s ease-out 0.218s,margin-top 0.218s ease-out 0.218s}.permission-bar-gradient{box-shadow:0 1px 0px #4285f4;height:80px;left:0;margin:0;opacity:0;pointer-events:none;position:fixed;right:0;top:-80px;transition:opacity 0.218s,box-shadow 0.218s}.s2wfp .permission-bar-gradient{box-shadow:0 1px 80px #4285f4;opacity:1;pointer-events:none;animation:allow-alert .75s 0 infinite;animation-direction:alternate;animation-timing-function:ease-out;transition:opacity 0.218s,box-shadow 0.218s}@-webkit-keyframes allow-alert {from{opacity:1}to{opacity:.35}}
#
#  .A8SBwf{margin:0 auto;width:calc(632px + 8px);padding-top:6px;width:auto;max-width:584px;position:relative;}.RNNXgb{display:flex;z-index:3;height:44px;background:#fff;border:1px solid #dfe1e5;box-shadow:none;border-radius:24px;margin:0 auto;width:calc(632px + 6px);width:auto;max-width:584px;}.minidiv .RNNXgb{height:32px;border-radius:16px;background:#fff;margin:10px 0 0;}.emcav .RNNXgb{border-bottom-left-radius:0;border-bottom-right-radius:0;box-shadow:0 1px 6px rgba(32,33,36,.28);border-color:rgba(223,225,229,0);}.minidiv .emcav .RNNXgb{border-bottom-left-radius:0;border-bottom-right-radius:0;}.emcav.emcat .RNNXgb{border-bottom-left-radius:24px;border-bottom-right-radius:24px}.minidiv .emcav.emcat .RNNXgb{border-bottom-left-radius:16px;border-bottom-right-radius:16px}.RNNXgb:hover,.sbfc .RNNXgb{background-color:#fff;box-shadow:0 1px 6px rgba(32,33,36,.28);border-color:rgba(223,225,229,0)}.SDkEP{flex:1;display:flex;padding:5px 8px 0 14px;}.minidiv .SDkEP{padding-top:0}.FPdoLc{padding-top:18px}.iblpc{display:flex;align-items:center;padding-right:13px;margin-top:-5px}.minidiv .iblpc{margin-top:0}.CKb9sd{background:none;display:flex;flex:0 0 auto}.CcAdNb{margin:auto}.QCzoEc{margin-top:3px;color:#9aa0a6}.gLFyf{background-color:transparent;border:none;margin:0;padding:0;color:rgba(0,0,0,.87);word-wrap:break-word;outline:none;display:flex;flex:100%;-webkit-tap-highlight-color:transparent;margin-top:-37px;height:34px;font-size:16px;}.minidiv .gLFyf{margin-top:-35px;}.a4bIc{display:flex;flex:1;flex-wrap:wrap}.YacQv{color:transparent;flex:100%;white-space:pre;height:34px;font-size:16px;}.YacQv span{background:url("/images/experiments/wavy-underline.png") repeat-x scroll 0 100% transparent;padding:0 0 10px 0;}.dRYYxd{display:flex;flex:0 0 auto;margin-top:-5px;align-items:stretch;flex-direction:row}.minidiv .dRYYxd{margin-top:0} .BKRPef{background:transparent;align-items:center;flex:1 0 auto;flex-direction:row;display:flex;cursor:pointer}.vOY7J{background:transparent;border:0;align-items:center;flex:1 0 auto;cursor:pointer;display:none;height:100%;line-height:44px;outline:none;padding:0 12px}.M2vV3{display:flex}.ExCKkf{height:100%;color:#70757a;vertical-align:middle;outline:none}.minidiv .vOY7J{line-height:32px}.minidiv .ExCKkf{width:20px} .BKRPef{padding-right:4px}.ACRAdd{border-left:1px solid #dadce0;height:65%}.ACRAdd{display:none}.ACRAdd.M2vV3{display:block}          .XDyW0e{flex:1 0 auto;display:flex;cursor:pointer;align-items:center;border:0;background:transparent;outline:none;padding:0 8px;width:24px;line-height:44px}.goxjub{height:24px;width:24px;vertical-align:middle}.minidiv .XDyW0e{line-height:32px}.minidiv .goxjub{width:20px;height:20px}.UUbT9{position:absolute;text-align:left;z-index:3;cursor:default;-webkit-user-select:none;width:100%;margin-top:-1px;}.aajZCb{display:flex;flex-direction:column;list-style-type:none;margin:0;padding:0;overflow:hidden;background:#fff;border-radius:0 0 24px 24px;box-shadow:0 4px 6px rgba(32,33,36,.28);border:0;padding-bottom:4px;}.minidiv .aajZCb{border-bottom-left-radius:16px;border-bottom-right-radius:16px}.mkHrUc{display:flex;}.h3L8Ub .rLrQHf{padding-bottom:16px}.h3L8Ub .rLrQHf{margin-right:30px}.h3L8Ub .rLrQHf{width:44%}.erkvQe{padding-bottom:8px;flex:auto;}.RjPuVb{height:1px;margin:0 26px 0 0;}.S3nFnd{display:flex}.S3nFnd .RjPuVb,.S3nFnd .aajZCb{flex:0 0 auto}.lh87ke:link,.lh87ke:visited{color:#1a0dab;cursor:pointer;font:11px arial,sans-serif;padding:0 5px;margin-top:-10px;text-decoration:none;flex:auto;align-self:flex-end;margin:0 16px 5px 0}.lh87ke:hover{text-decoration:underline}.xtSCL{border-top:1px solid #e8eaed;margin:0 20px 0 14px;padding-bottom:4px}.sb7{background:url() no-repeat ;min-height:0px;min-width:0px;height:0px;width:0px}.sb27{background:url(/images/searchbox/desktop_searchbox_sprites318_hr.webp) no-repeat 0 -21px;background-size:20px;min-height:20px;min-width:20px;height:20px;width:20px}.sb43{background:url(/images/searchbox/desktop_searchbox_sprites318_hr.webp) no-repea ...
# .A8SBwf{margin:0 auto;width:calc(632px + 8px);padding-top:6px;width:auto;max-width:584px;position:relative;}.RNNXgb{display:flex;z-index:3;height:44px;background:#fff;border:1px solid #dfe1e5;box-shadow:none;border-radius:24px;margin:0 auto;width:calc(632px + 6px);width:auto;max-width:584px;}.minidiv .RNNXgb{height:32px;border-radius:16px;background:#fff;margin:10px 0 0;}.emcav .RNNXgb{border-bottom-left-radius:0;border-bottom-right-radius:0;box-shadow:0 1px 6px rgba(32,33,36,.28);border-color:rgba(223,225,229,0);}.minidiv .emcav .RNNXgb{border-bottom-left-radius:0;border-bottom-right-radius:0;}.emcav.emcat .RNNXgb{border-bottom-left-radius:24px;border-bottom-right-radius:24px}.minidiv .emcav.emcat .RNNXgb{border-bottom-left-radius:16px;border-bottom-right-radius:16px}.RNNXgb:hover,.sbfc .RNNXgb{background-color:#fff;box-shadow:0 1px 6px rgba(32,33,36,.28);border-color:rgba(223,225,229,0)}.SDkEP{flex:1;display:flex;padding:5px 8px 0 14px;}.minidiv .SDkEP{padding-top:0}.FPdoLc{padding-top:18px}.iblpc{display:flex;align-items:center;padding-right:13px;margin-top:-5px}.minidiv .iblpc{margin-top:0}.CKb9sd{background:none;display:flex;flex:0 0 auto}.CcAdNb{margin:auto}.QCzoEc{margin-top:3px;color:#9aa0a6}.gLFyf{background-color:transparent;border:none;margin:0;padding:0;color:rgba(0,0,0,.87);word-wrap:break-word;outline:none;display:flex;flex:100%;-webkit-tap-highlight-color:transparent;margin-top:-37px;height:34px;font-size:16px;}.minidiv .gLFyf{margin-top:-35px;}.a4bIc{display:flex;flex:1;flex-wrap:wrap}.YacQv{color:transparent;flex:100%;white-space:pre;height:34px;font-size:16px;}.YacQv span{background:url("/images/experiments/wavy-underline.png") repeat-x scroll 0 100% transparent;padding:0 0 10px 0;}.dRYYxd{display:flex;flex:0 0 auto;margin-top:-5px;align-items:stretch;flex-direction:row}.minidiv .dRYYxd{margin-top:0} .BKRPef{background:transparent;align-items:center;flex:1 0 auto;flex-direction:row;display:flex;cursor:pointer}.vOY7J{background:transparent;border:0;align-items:center;flex:1 0 auto;cursor:pointer;display:none;height:100%;line-height:44px;outline:none;padding:0 12px}.M2vV3{display:flex}.ExCKkf{height:100%;color:#70757a;vertical-align:middle;outline:none}.minidiv .vOY7J{line-height:32px}.minidiv .ExCKkf{width:20px} .BKRPef{padding-right:4px}.ACRAdd{border-left:1px solid #dadce0;height:65%}.ACRAdd{display:none}.ACRAdd.M2vV3{display:block}          .XDyW0e{flex:1 0 auto;display:flex;cursor:pointer;align-items:center;border:0;background:transparent;outline:none;padding:0 8px;width:24px;line-height:44px}.goxjub{height:24px;width:24px;vertical-align:middle}.minidiv .XDyW0e{line-height:32px}.minidiv .goxjub{width:20px;height:20px}.UUbT9{position:absolute;text-align:left;z-index:3;cursor:default;-webkit-user-select:none;width:100%;margin-top:-1px;}.aajZCb{display:flex;flex-direction:column;list-style-type:none;margin:0;padding:0;overflow:hidden;background:#fff;border-radius:0 0 24px 24px;box-shadow:0 4px 6px rgba(32,33,36,.28);border:0;padding-bottom:4px;}.minidiv .aajZCb{border-bottom-left-radius:16px;border-bottom-right-radius:16px}.mkHrUc{display:flex;}.h3L8Ub .rLrQHf{padding-bottom:16px}.h3L8Ub .rLrQHf{margin-right:30px}.h3L8Ub .rLrQHf{width:44%}.erkvQe{padding-bottom:8px;flex:auto;}.RjPuVb{height:1px;margin:0 26px 0 0;}.S3nFnd{display:flex}.S3nFnd .RjPuVb,.S3nFnd .aajZCb{flex:0 0 auto}.lh87ke:link,.lh87ke:visited{color:#1a0dab;cursor:pointer;font:11px arial,sans-serif;padding:0 5px;margin-top:-10px;text-decoration:none;flex:auto;align-self:flex-end;margin:0 16px 5px 0}.lh87ke:hover{text-decoration:underline}.xtSCL{border-top:1px solid #e8eaed;margin:0 20px 0 14px;padding-bottom:4px}.sb7{background:url() no-repeat ;min-height:0px;min-width:0px;height:0px;width:0px}.sb27{background:url(/images/searchbox/desktop_searchbox_sprites318_hr.webp) no-repeat 0 -21px;background-size:20px;min-height:20px;min-width:20px;height:20px;width:20px}.sb43{background:url(/images/searchbox/desktop_searchbox_sprites318_hr.webp) no-repeat ...
# .CcAdNb{margin:auto}.QCzoEc{margin-top:3px;color:#9aa0a6}.gLFyf{background-color:transparent;border:none;margin:0;padding:0;color:rgba(0,0,0,.87);word-wrap:break-word;outline:none;display:flex;flex:100%;-webkit-tap-highlight-color:transparent;margin-top:-37px;height:34px;font-size:16px;}.minidiv .gLFyf{margin-top:-35px;}.a4bIc{display:flex;flex:1;flex-wrap:wrap}.YacQv{color:transparent;flex:100%;white-space:pre;height:34px;font-size:16px;}.YacQv span{background:url("/images/experiments/wavy-underline.png") repeat-x scroll 0 100% transparent;padding:0 0 10px 0;}.dRYYxd{display:flex;flex:0 0 auto;margin-top:-5px;align-items:stretch;flex-direction:row}.minidiv .dRYYxd{margin-top:0} .BKRPef{background:transparent;align-items:center;flex:1 0 auto;flex-direction:row;display:flex;cursor:pointer}.vOY7J{background:transparent;border:0;align-items:center;flex:1 0 auto;cursor:pointer;display:none;height:100%;line-height:44px;outline:none;padding:0 12px}.M2vV3{display:flex}.ExCKkf{height:100%;color:#70757a;vertical-align:middle;outline:none}.minidiv .vOY7J{line-height:32px}.minidiv .ExCKkf{width:20px} .BKRPef{padding-right:4px}.ACRAdd{border-left:1px solid #dadce0;height:65%}.ACRAdd{display:none}.ACRAdd.M2vV3{display:block}          .XDyW0e{flex:1 0 auto;display:flex;cursor:pointer;align-items:center;border:0;background:transparent;outline:none;padding:0 8px;width:24px;line-height:44px}.goxjub{height:24px;width:24px;vertical-align:middle}.minidiv .XDyW0e{line-height:32px}.minidiv .goxjub{width:20px;height:20px}
# .CcAdNb{margin:auto}.QCzoEc{margin-top:3px;color:#9aa0a6}.gLFyf{background-color:transparent;border:none;margin:0;padding:0;color:rgba(0,0,0,.87);word-wrap:break-word;outline:none;display:flex;flex:100%;-webkit-tap-highlight-color:transparent;margin-top:-37px;height:34px;font-size:16px;}.minidiv .gLFyf{margin-top:-35px;}.a4bIc{display:flex;flex:1;flex-wrap:wrap}.YacQv{color:transparent;flex:100%;white-space:pre;height:34px;font-size:16px;}.YacQv span{background:url("/images/experiments/wavy-underline.png") repeat-x scroll 0 100% transparent;padding:0 0 10px 0;}.dRYYxd{display:flex;flex:0 0 auto;margin-top:-5px;align-items:stretch;flex-direction:row}.minidiv .dRYYxd{margin-top:0} .BKRPef{background:transparent;align-items:center;flex:1 0 auto;flex-direction:row;display:flex;cursor:pointer}.vOY7J{background:transparent;border:0;align-items:center;flex:1 0 auto;cursor:pointer;display:none;height:100%;line-height:44px;outline:none;padding:0 12px}.M2vV3{display:flex}.ExCKkf{height:100%;color:#70757a;vertical-align:middle;outline:none}.minidiv .vOY7J{line-height:32px}.minidiv .ExCKkf{width:20px} .BKRPef{padding-right:4px}.ACRAdd{border-left:1px solid #dadce0;height:65%}.ACRAdd{display:none}.ACRAdd.M2vV3{display:block}          .XDyW0e{flex:1 0 auto;display:flex;cursor:pointer;align-items:center;border:0;background:transparent;outline:none;padding:0 8px;width:24px;line-height:44px}.goxjub{height:24px;width:24px;vertical-align:middle}.minidiv .XDyW0e{line-height:32px}.minidiv .goxjub{width:20px;height:20px}
# .CcAdNb{margin:auto}.QCzoEc{margin-top:3px;color:#9aa0a6}
#
# .gLFyf{background-color:transparent;border:none;margin:0;padding:0;color:rgba(0,0,0,.87);word-wrap:break-word;outline:none;display:flex;flex:100%;-webkit-tap-highlight-color:transparent;margin-top:-37px;height:34px;font-size:16px;}.minidiv .gLFyf{margin-top:-35px;}.a4bIc{display:flex;flex:1;flex-wrap:wrap}.YacQv{color:transparent;flex:100%;white-space:pre;height:34px;font-size:16px;}.YacQv span{background:url("/images/experiments/wavy-underline.png") repeat-x scroll 0 100% transparent;padding:0 0 10px 0;}
#
# .dRYYxd{display:flex;flex:0 0 auto;margin-top:-5px;align-items:stretch;flex-direction:row}.minidiv .dRYYxd{margin-top:0} .BKRPef{background:transparent;align-items:center;flex:1 0 auto;flex-direction:row;display:flex;cursor:pointer}.vOY7J{background:transparent;border:0;align-items:center;flex:1 0 auto;cursor:pointer;display:none;height:100%;line-height:44px;outline:none;padding:0 12px}.M2vV3{display:flex}.ExCKkf{height:100%;color:#70757a;vertical-align:middle;outline:none}.minidiv .vOY7J{line-height:32px}.minidiv .ExCKkf{width:20px} .BKRPef{padding-right:4px}.ACRAdd{border-left:1px solid #dadce0;height:65%}.ACRAdd{display:none}.ACRAdd.M2vV3{display:block}          .XDyW0e{flex:1 0 auto;display:flex;cursor:pointer;align-items:center;border:0;background:transparent;outline:none;padding:0 8px;width:24px;line-height:44px}.goxjub{height:24px;width:24px;vertical-align:middle}.minidiv .XDyW0e{line-height:32px}.minidiv .goxjub{width:20px;height:20px}
#
#
#
# .UUbT9{position:absolute;text-align:left;z-index:3;cursor:default;-webkit-user-select:none;width:100%;margin-top:-1px;}.aajZCb{display:flex;flex-direction:column;list-style-type:none;margin:0;padding:0;overflow:hidden;background:#fff;border-radius:0 0 24px 24px;box-shadow:0 4px 6px rgba(32,33,36,.28);border:0;padding-bottom:4px;}.minidiv .aajZCb{border-bottom-left-radius:16px;border-bottom-right-radius:16px}.mkHrUc{display:flex;}.h3L8Ub .rLrQHf{padding-bottom:16px}.h3L8Ub .rLrQHf{margin-right:30px}.h3L8Ub .rLrQHf{width:44%}.erkvQe{padding-bottom:8px;flex:auto;}.RjPuVb{height:1px;margin:0 26px 0 0;}.S3nFnd{display:flex}.S3nFnd .RjPuVb,.S3nFnd .aajZCb{flex:0 0 auto}.lh87ke:link,.lh87ke:visited{color:#1a0dab;cursor:pointer;font:11px arial,sans-serif;padding:0 5px;margin-top:-10px;text-decoration:none;flex:auto;align-self:flex-end;margin:0 16px 5px 0}.lh87ke:hover{text-decoration:underline}.xtSCL{border-top:1px solid #e8eaed;margin:0 20px 0 14px;padding-bottom:4px}.sb7{background:url() no-repeat ;min-height:0px;min-width:0px;height:0px;width:0px}.sb27{background:url(/images/searchbox/desktop_searchbox_sprites318_hr.webp) no-repeat 0 -21px;background-size:20px;min-height:20px;min-width:20px;height:20px;width:20px}.sb43{background:url(/images/searchbox/desktop_searchbox_sprites318_hr.webp) no-repeat 0 0;background-size:20px;min-height:20px;min-width:20px;height:20px;width:20px}.sb53.sb53{padding:0 4px;margin:0}.sb33{background:url(/images/searchbox/desktop_searchbox_sprites318_hr.webp) no-repeat 0 -42px;background-size:20px;height:20px;width:20px;}#shJ2Vb{display:none}.OBMEnb{padding:0;margin:0}.G43f7e{display:flex;flex-direction:column;min-width:0;padding:0}.Ye4jfc{flex-direction:row;flex-wrap:wrap}#ynRric{display:none}.ynRric{list-style-type:none;flex-direction:column;color:#70757a;font-family:Google Sans,arial,sans-serif-medium,sans-serif;font-size:14px;margin:0 20px 0 16px;padding:8px 0 8px 0;line-height:16px;width:100%}#YMXe{display:none}.sbct{display:flex;align-items:center;min-width:0;padding:0;}.eIPGRd{flex:auto;display:flex;align-items:center;margin:0 20px 0 14px}.pcTkSc{display:flex;flex:auto;flex-direction:column;min-width:0;padding:6px 0}.sbic{display:flex;align-items:center;margin:0 13px 0 1px;}.sbic.vYOkbe{background:center/contain no-repeat;border-radius:4px;min-height:32px;min-width:32px;margin:4px 7px 4px -5px;}.sbre .wM6W7d{line-height:18px}.ClJ9Yb{line-height:12px;font-size:13px;color:#80868b;margin-top:2px}.wM6W7d{display:flex;font-size:16px;color:#212121;flex:auto;align-items:center;word-break:break-word;padding-right:8px}.minidiv .wM6W7d{font-size:14px}.WggQGd{color:#52188c}.wM6W7d span{flex:auto}.AQZ9Vd{display:flex;align-self:stretch;}.JCHpcb:hover{color:#1a73e8;text-decoration:underline;}.JCHpcb{color:#80868b;font:13px arial,sans-serif;cursor:pointer;align-self:center}.sbhl{background:#eee;}@media (hover:hover){.sbai{visibility:hidden}.sbhl .sbai{visibility:inherit}}.mus_pc{display:block;margin:6px 0}.mus_il{font-family:Arial,HelveticaNeue-Light,HelveticaNeue,Helvetica;padding-top:7px;position:relative}.mus_il:first-child{padding-top:0}.mus_il_at{margin-left:10px}.mus_il_st{right:52px;position:absolute}.mus_il_i{align:left;margin-right:10px}.mus_it3{margin-bottom:3px;max-height:24px;vertical-align:bottom}.mus_it5{height:24px;width:24px;vertical-align:bottom;margin-left:10px;margin-right:10px;transform:rotate(90deg)}.mus_tt3{color:#767676;font-size:12px;vertical-align:top}.mus_tt5{color:#d93025;font-size:14px}.mus_tt6{color:#188038;font-size:14px}.mus_tt8{font-size:16px;font-family:Arial,sans-serif}.mus_tt17{color:#212121;font-size:20px}.mus_tt18{color:#212121;font-size:28px}.mus_tt19{color:#767676;font-size:12px}.mus_tt20{color:#767676;font-size:14px}.mus_tt23{color:#767676;font-size:18px}Delete .lJ9FBc{height:70px}.lJ9FBc input[type="submit"],.gbqfba{background-color:#f8f9fa;border:1px solid #f8f9fa;border-radius:4px;color:#3c4043;font-family:arial,sans-serif;font-size:14px;margin:11px 4px;padding:0 16px;li ...
#
# #shJ2Vb{display:none}.OBMEnb{padding:0;margin:0}.G43f7e{display:flex;flex-direction:column;min-width:0;padding:0}.Ye4jfc{flex-direction:row;flex-wrap:wrap}#ynRric{display:none}.ynRric{list-style-type:none;flex-direction:column;color:#70757a;font-family:Google Sans,arial,sans-serif-medium,sans-serif;font-size:14px;margin:0 20px 0 16px;padding:8px 0 8px 0;line-height:16px;width:100%}#YMXe{display:none}.sbct{display:flex;align-items:center;min-width:0;padding:0;}.eIPGRd{flex:auto;display:flex;align-items:center;margin:0 20px 0 14px}.pcTkSc{display:flex;flex:auto;flex-direction:column;min-width:0;padding:6px 0}.sbic{display:flex;align-items:center;margin:0 13px 0 1px;}.sbic.vYOkbe{background:center/contain no-repeat;border-radius:4px;min-height:32px;min-width:32px;margin:4px 7px 4px -5px;}.sbre .wM6W7d{line-height:18px}.ClJ9Yb{line-height:12px;font-size:13px;color:#80868b;margin-top:2px}.wM6W7d{display:flex;font-size:16px;color:#212121;flex:auto;align-items:center;word-break:break-word;padding-right:8px}.minidiv .wM6W7d{font-size:14px}.WggQGd{color:#52188c}.wM6W7d span{flex:auto}.AQZ9Vd{display:flex;align-self:stretch;}.JCHpcb:hover{color:#1a73e8;text-decoration:underline;}.JCHpcb{color:#80868b;font:13px arial,sans-serif;cursor:pointer;align-self:center}.sbhl{background:#eee;}@media (hover:hover){.sbai{visibility:hidden}.sbhl .sbai{visibility:inherit}}.mus_pc{display:block;margin:6px 0}.mus_il{font-family:Arial,HelveticaNeue-Light,HelveticaNeue,Helvetica;padding-top:7px;position:relative}.mus_il:first-child{padding-top:0}.mus_il_at{margin-left:10px}.mus_il_st{right:52px;position:absolute}.mus_il_i{align:left;margin-right:10px}.mus_it3{margin-bottom:3px;max-height:24px;vertical-align:bottom}.mus_it5{height:24px;width:24px;vertical-align:bottom;margin-left:10px;margin-right:10px;transform:rotate(90deg)}.mus_tt3{color:#767676;font-size:12px;vertical-align:top}.mus_tt5{color:#d93025;font-size:14px}.mus_tt6{color:#188038;font-size:14px}.mus_tt8{font-size:16px;font-family:Arial,sans-serif}.mus_tt17{color:#212121;font-size:20px}.mus_tt18{color:#212121;font-size:28px}.mus_tt19{color:#767676;font-size:12px}.mus_tt20{color:#767676;font-size:14px}.mus_tt23{color:#767676;font-size:18px}Delete .lJ9FBc{height:70px}.lJ9FBc input[type="submit"],.gbqfba{background-color:#f8f9fa;border:1px solid #f8f9fa;border-radius:4px;color:#3c4043;font-family:arial,sans-serif;font-size:14px;margin:11px 4px;padding:0 16px;line-height:27px;height:36px;min-width:54px;text-align:center;cursor:pointer;user-select:none}.lJ9FBc input[type="submit"]:hover{box-shadow:0 1px 1px rgba(0,0,0,.1);background-color:#f8f9fa;border:1px solid #dadce0;color:#202124}.lJ9FBc input[type="submit"]:focus{border:1px solid #4285f4;outline:none}
#
#
#
#
# Delete
#
#
#
#
# Delete
# Delete
#  .lJ9FBc{height:70px}.lJ9FBc input[type="submit"],.gbqfba{background-color:#f8f9fa;border:1px solid #f8f9fa;border-radius:4px;color:#3c4043;font-family:arial,sans-serif;font-size:14px;margin:11px 4px;padding:0 16px;line-height:27px;height:36px;min-width:54px;text-align:center;cursor:pointer;user-select:none}.lJ9FBc input[type="submit"]:hover{box-shadow:0 1px 1px rgba(0,0,0,.1);background-color:#f8f9fa;border:1px solid #dadce0;color:#202124}.lJ9FBc input[type="submit"]:focus{border:1px solid #4285f4;outline:none}
# a.oBa0Fe{color:#70757a;float:right;font-style:italic;-webkit-tap-highlight-color:rgba(0,0,0,.00);tap-highlight-color:rgba(0,0,0,.00)}a.aciXEb{padding:0 5px;}.RTZ84b{color:#70757a;cursor:pointer;padding-right:8px}.XEKxtf{color:#70757a;float:right;font-size:12px;line-height:16px;padding-bottom:4px}Report inappropriate predictions
#
#
#      I'm Feeling CuriousI'm Feeling HungryI'm Feeling AdventurousI'm Feeling PlayfulI'm Feeling StellarI'm Feeling GenerousI'm Feeling DoodleyI'm Feeling TrendyI'm Feeling ArtisticI'm Feeling Funny
# I'm Feeling CuriousI'm Feeling HungryI'm Feeling AdventurousI'm Feeling PlayfulI'm Feeling StellarI'm Feeling GenerousI'm Feeling DoodleyI'm Feeling TrendyI'm Feeling ArtisticI'm Feeling Funny
# I'm Feeling CuriousI'm Feeling HungryI'm Feeling AdventurousI'm Feeling PlayfulI'm Feeling StellarI'm Feeling GenerousI'm Feeling DoodleyI'm Feeling TrendyI'm Feeling ArtisticI'm Feeling Funny
# I'm Feeling Curious
# I'm Feeling Hungry
# I'm Feeling Adventurous
# I'm Feeling Playful
# I'm Feeling Stellar
# I'm Feeling Generous
# I'm Feeling Doodley
# I'm Feeling Trendy
# I'm Feeling Artistic
# I'm Feeling Funny
#
#
# .vcVZ7d{text-align:center}
# .c93Gbe{background:#f2f2f2}.uU7dJb{padding:15px 30px;border-bottom:1px solid #dadce0;font-size:15px;color:#70757a}.SSwjIe{padding:0 20px}.KxwPGc{display:flex;flex-wrap:wrap;justify-content:space-between}@media only screen and (max-width:1200px){.KxwPGc{justify-content:space-evenly}}.pHiOh{display:block;padding:15px;white-space:nowrap}.pHiOh,a.pHiOh{color:#70757a}.ktLKi{white-space:nowrap;vertical-align:top}.Pb9hCb{height:14px;margin-right:6px}.ssOUyb{order:2}@media only screen and (max-width:1200px){.ssOUyb{order:0;width:100%;justify-content:center}}.waLeGd .ssOUyb{order:0;width:100%;justify-content:center}.AghGtd{justify-content:flex-start;min-width:30%;order:1}.iTjxkf{justify-content:flex-end;min-width:30%;order:3}AdvertisingBusiness How Search works Carbon neutral since 2007PrivacyTerms.ayzqOc:hover{text-decoration:underline}.cF4V5c{background-color:#fff}.cF4V5c g-menu-item{display:block;font-size:14px;line-height:23px;white-space:nowrap}.cF4V5c g-menu-item a,.cF4V5c .y0fQ9c{display:block;padding-top:4px;padding-bottom:4px;cursor:pointer}.cF4V5c g-menu-item a,.cF4V5c g-menu-item a:visited,.cF4V5c g-menu-item a:hover{text-decoration:inherit;color:inherit}.EwsJzb{display:block}.rIbAWc{cursor:pointer;display:inline-block}.B8Kd8d{position:absolute}.sAKBe{border-radius:8px;box-shadow:0 2px 10px 0 rgba(0,0,0,0.2)}Settings.gLSAk{border:none;display:block;outline:none;}.rShyOb{white-space:nowrap}.gLSAk{border-radius:8px}.gLSAk{padding:5px 0}.ErsxPb{display:block;position:relative}.znKVS{padding:0 16px;vertical-align:middle}.znKVS.tnhqA{padding:0}.tnhqA>*{padding:0 16px}.ohSfHb .znKVS{padding-left:28px}.ErsxPb:hover{cursor:pointer}.ErsxPb,.fbKdEb:hover{cursor:default}.dPaec,g-menu-item[disabled]{pointer-events:none;cursor:default}.dPaec{border-top:1px solid;height:0;margin:5px 0}.znKVS{line-height:23px}.fbKdEb{background-image:url(//ssl.gstatic.com/ui/v1/menu/checkmark2.png);background-repeat:no-repeat;background-position:left center}.gvybPb,.ErsxPb:active{background-color:rgba(0,0,0,0.1)}.dPaec,g-menu-item[disabled]{color:#cdcdcd !important}.dPaec{border-top-color:#dadce0}Search settingsAdvanced searchYour data in SearchSearch historySearch helpSend feedback.tFYjZe{align-items:center;display:flex;justify-content:space-between;padding-bottom:4px;padding-top:4px}.tFYjZe:hover .iOHNLb,.tFYjZe:focus .iOHNLb{opacity:1}.iOHNLb{color:#70757a;height:20px;margin-top:-2px;opacity:0;width:20px}Dark theme: Off
# AdvertisingBusiness How Search works Carbon neutral since 2007PrivacyTerms.ayzqOc:hover{text-decoration:underline}.cF4V5c{background-color:#fff}.cF4V5c g-menu-item{display:block;font-size:14px;line-height:23px;white-space:nowrap}.cF4V5c g-menu-item a,.cF4V5c .y0fQ9c{display:block;padding-top:4px;padding-bottom:4px;cursor:pointer}.cF4V5c g-menu-item a,.cF4V5c g-menu-item a:visited,.cF4V5c g-menu-item a:hover{text-decoration:inherit;color:inherit}.EwsJzb{display:block}.rIbAWc{cursor:pointer;display:inline-block}.B8Kd8d{position:absolute}.sAKBe{border-radius:8px;box-shadow:0 2px 10px 0 rgba(0,0,0,0.2)}Settings.gLSAk{border:none;display:block;outline:none;}.rShyOb{white-space:nowrap}.gLSAk{border-radius:8px}.gLSAk{padding:5px 0}.ErsxPb{display:block;position:relative}.znKVS{padding:0 16px;vertical-align:middle}.znKVS.tnhqA{padding:0}.tnhqA>*{padding:0 16px}.ohSfHb .znKVS{padding-left:28px}.ErsxPb:hover{cursor:pointer}.ErsxPb,.fbKdEb:hover{cursor:default}.dPaec,g-menu-item[disabled]{pointer-events:none;cursor:default}.dPaec{border-top:1px solid;height:0;margin:5px 0}.znKVS{line-height:23px}.fbKdEb{background-image:url(//ssl.gstatic.com/ui/v1/menu/checkmark2.png);background-repeat:no-repeat;background-position:left center}.gvybPb,.ErsxPb:active{background-color:rgba(0,0,0,0.1)}.dPaec,g-menu-item[disabled]{color:#cdcdcd !important}.dPaec{border-top-color:#dadce0}Search settingsAdvanced searchYour data in SearchSearch historySearch helpSend feedback.tFYjZe{align-items:center;display:flex;justify-content:space-between;padding-bottom:4px;padding-top:4px}.tFYjZe:hover .iOHNLb,.tFYjZe:focus .iOHNLb{opacity:1}.iOHNLb{color:#70757a;height:20px;margin-top:-2px;opacity:0;width:20px}Dark theme: Off
# AdvertisingBusiness How Search works
# Carbon neutral since 2007
# PrivacyTerms.ayzqOc:hover{text-decoration:underline}.cF4V5c{background-color:#fff}.cF4V5c g-menu-item{display:block;font-size:14px;line-height:23px;white-space:nowrap}.cF4V5c g-menu-item a,.cF4V5c .y0fQ9c{display:block;padding-top:4px;padding-bottom:4px;cursor:pointer}.cF4V5c g-menu-item a,.cF4V5c g-menu-item a:visited,.cF4V5c g-menu-item a:hover{text-decoration:inherit;color:inherit}.EwsJzb{display:block}.rIbAWc{cursor:pointer;display:inline-block}.B8Kd8d{position:absolute}.sAKBe{border-radius:8px;box-shadow:0 2px 10px 0 rgba(0,0,0,0.2)}Settings.gLSAk{border:none;display:block;outline:none;}.rShyOb{white-space:nowrap}.gLSAk{border-radius:8px}.gLSAk{padding:5px 0}.ErsxPb{display:block;position:relative}.znKVS{padding:0 16px;vertical-align:middle}.znKVS.tnhqA{padding:0}.tnhqA>*{padding:0 16px}.ohSfHb .znKVS{padding-left:28px}.ErsxPb:hover{cursor:pointer}.ErsxPb,.fbKdEb:hover{cursor:default}.dPaec,g-menu-item[disabled]{pointer-events:none;cursor:default}.dPaec{border-top:1px solid;height:0;margin:5px 0}.znKVS{line-height:23px}.fbKdEb{background-image:url(//ssl.gstatic.com/ui/v1/menu/checkmark2.png);background-repeat:no-repeat;background-position:left center}.gvybPb,.ErsxPb:active{background-color:rgba(0,0,0,0.1)}.dPaec,g-menu-item[disabled]{color:#cdcdcd !important}.dPaec{border-top-color:#dadce0}Search settingsAdvanced searchYour data in SearchSearch historySearch helpSend feedback.tFYjZe{align-items:center;display:flex;justify-content:space-between;padding-bottom:4px;padding-top:4px}.tFYjZe:hover .iOHNLb,.tFYjZe:focus .iOHNLb{opacity:1}.iOHNLb{color:#70757a;height:20px;margin-top:-2px;opacity:0;width:20px}Dark theme: Off
# Settings
# Settings
# .gLSAk{border:none;display:block;outline:none;}.rShyOb{white-space:nowrap}.gLSAk{border-radius:8px}.gLSAk{padding:5px 0}.ErsxPb{display:block;position:relative}.znKVS{padding:0 16px;vertical-align:middle}.znKVS.tnhqA{padding:0}.tnhqA>*{padding:0 16px}.ohSfHb .znKVS{padding-left:28px}.ErsxPb:hover{cursor:pointer}.ErsxPb,.fbKdEb:hover{cursor:default}.dPaec,g-menu-item[disabled]{pointer-events:none;cursor:default}.dPaec{border-top:1px solid;height:0;margin:5px 0}.znKVS{line-height:23px}.fbKdEb{background-image:url(//ssl.gstatic.com/ui/v1/menu/checkmark2.png);background-repeat:no-repeat;background-position:left center}.gvybPb,.ErsxPb:active{background-color:rgba(0,0,0,0.1)}.dPaec,g-menu-item[disabled]{color:#cdcdcd !important}.dPaec{border-top-color:#dadce0}Search settingsAdvanced searchYour data in SearchSearch historySearch helpSend feedback.tFYjZe{align-items:center;display:flex;justify-content:space-between;padding-bottom:4px;padding-top:4px}.tFYjZe:hover .iOHNLb,.tFYjZe:focus .iOHNLb{opacity:1}.iOHNLb{color:#70757a;height:20px;margin-top:-2px;opacity:0;width:20px}Dark theme: Off
# Search settings
# Advanced search
# Your data in Search
# Search history
# Search help
# Send feedback
# .tFYjZe{align-items:center;display:flex;justify-content:space-between;padding-bottom:4px;padding-top:4px}.tFYjZe:hover .iOHNLb,.tFYjZe:focus .iOHNLb{opacity:1}.iOHNLb{color:#70757a;height:20px;margin-top:-2px;opacity:0;width:20px}Dark theme: Off
# .tFYjZe{align-items:center;display:flex;justify-content:space-between;padding-bottom:4px;padding-top:4px}.tFYjZe:hover .iOHNLb,.tFYjZe:focus .iOHNLb{opacity:1}.iOHNLb{color:#70757a;height:20px;margin-top:-2px;opacity:0;width:20px}Dark theme: Off
# Dark theme: Off
# Dark theme: Off
#
#
# .Fgvgjc{height:0;overflow:hidden}.gTMtLb{z-index:1001;position:absolute;top:-1000px}this.gbar_=this.gbar_||{};(function(_){var window=this;
# try{
# _.ke=function(a,b,c){if(!a.o)if(c instanceof Array){c=_.Za(c);for(var d=c.next();!d.done;d=c.next())_.ke(a,b,d.value)}else{d=(0,_.y)(a.F,a,b);var e=a.B+c;a.B++;b.setAttribute("data-eqid",e);a.D[e]=d;b&&b.addEventListener?b.addEventListener(c,d,!1):b&&b.attachEvent?b.attachEvent("on"+c,d):a.A.log(Error("E`"+b))}};
#
# }catch(e){_._DumpException(e)}
# try{
# /*
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# _.le=function(){if(!_.n.addEventListener||!Object.defineProperty)return!1;var a=!1,b=Object.defineProperty({},"passive",{get:function(){a=!0}});try{_.n.addEventListener("test",function(){},b),_.n.removeEventListener("test",function(){},b)}catch(c){}return a}();
# _.me=_.Hb?"webkitTransitionEnd":"transitionend";
#
# }catch(e){_._DumpException(e)}
# try{
# var ne=document.querySelector(".gb_z .gb_A"),oe=document.querySelector("#gb.gb_Jc");ne&&!oe&&_.ke(_.be,ne,"click");
#
# }catch(e){_._DumpException(e)}
# try{
# var Zh=function(a){_.H.call(this);this.C=a;this.A=null;this.o={};this.D={};this.j={};this.B=null};_.w(Zh,_.H);_.$h=function(a){if(a.A)return a.A;for(var b in a.j)if(a.j[b].Le()&&a.j[b].Ib())return a.j[b];return null};_.k=Zh.prototype;_.k.hf=function(a){a&&_.$h(this)&&a!=_.$h(this)&&_.$h(this).Gd(!1);this.A=a};_.k.lg=function(a){a=this.j[a]||a;return _.$h(this)==a};_.k.ue=function(a,b){b=b.Pc();if(this.o[a]&&this.o[a][b])for(var c=0;c<this.o[a][b].length;c++)try{this.o[a][b][c]()}catch(d){this.C.log(d)}};
# _.k.xh=function(a){return!this.D[a.Pc()]};_.k.Fg=function(a){this.j[a]&&(_.$h(this)&&_.$h(this).Pc()==a||this.j[a].Gd(!0))};_.k.Ya=function(a){this.B=a;for(var b in this.j)this.j[b].Le()&&this.j[b].Ya(a)};_.k.af=function(a){this.j[a.Pc()]=a};_.k.me=function(a){return a in this.j?this.j[a]:null};var ai=new Zh(_.J);_.Cd("dd",ai);
#
# }catch(e){_._DumpException(e)}
# try{
# var Bj=document.querySelector(".gb_Ma .gb_A"),Cj=document.querySelector("#gb.gb_Jc");Bj&&!Cj&&_.ke(_.be,Bj,"click");
#
# }catch(e){_._DumpException(e)}
# })(this.gbar_);
# // Google Inc.
# this.gbar_=this.gbar_||{};(function(_){var window=this;
# try{
# /*
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# _.pe=function(a,b){return 0<=(0,_.vb)(a,b)};_.qe=function(a){var b=typeof a;return"object"!=b?b:a?Array.isArray(a)?"array":b:"null"};_.re=function(a){var b=_.qe(a);return"array"==b||"object"==b&&"number"==typeof a.length};_.se=function(a,b){var c=Array.prototype.slice.call(arguments,1);return function(){var d=c.slice();d.push.apply(d,arguments);return a.apply(this,d)}};try{(new self.OffscreenCanvas(0,0)).getContext("2d")}catch(a){}_.te=_.C||_.Hb;
# _.ue=function(a,b){this.width=a;this.height=b};_.k=_.ue.prototype;_.k.aspectRatio=function(){return this.width/this.height};_.k.hc=function(){return!(this.width*this.height)};_.k.ceil=function(){this.width=Math.ceil(this.width);this.height=Math.ceil(this.height);return this};_.k.floor=function(){this.width=Math.floor(this.width);this.height=Math.floor(this.height);return this};_.k.round=function(){this.width=Math.round(this.width);this.height=Math.round(this.height);return this};
# var we,ze;_.ve=function(a,b){return(b||document).getElementsByTagName(String(a))};_.xe=function(a,b){_.Qa(b,function(c,d){c&&"object"==typeof c&&c.Qb&&(c=c.wb());"style"==d?a.style.cssText=c:"class"==d?a.className=c:"for"==d?a.htmlFor=c:we.hasOwnProperty(d)?a.setAttribute(we[d],c):0==d.lastIndexOf("aria-",0)||0==d.lastIndexOf("data-",0)?a.setAttribute(d,c):a[d]=c})};
# we={cellpadding:"cellPadding",cellspacing:"cellSpacing",colspan:"colSpan",frameborder:"frameBorder",height:"height",maxlength:"maxLength",nonce:"nonce",role:"role",rowspan:"rowSpan",type:"type",usemap:"useMap",valign:"vAlign",width:"width"};_.Ae=function(a,b){var c=b[1],d=_.ye(a,String(b[0]));c&&("string"===typeof c?d.className=c:Array.isArray(c)?d.className=c.join(" "):_.xe(d,c));2<b.length&&ze(a,d,b);return d};
# ze=function(a,b,c){function d(h){h&&b.appendChild("string"===typeof h?a.createTextNode(h):h)}for(var e=2;e<c.length;e++){var f=c[e];if(!_.re(f)||_.mb(f)&&0<f.nodeType)d(f);else{a:{if(f&&"number"==typeof f.length){if(_.mb(f)){var g="function"==typeof f.item||"string"==typeof f.item;break a}if("function"===typeof f){g="function"==typeof f.item;break a}}g=!1}_.wb(g?_.ma(f):f,d)}}};_.Be=function(a){return _.ye(document,a)};
# _.ye=function(a,b){b=String(b);"application/xhtml+xml"===a.contentType&&(b=b.toLowerCase());return a.createElement(b)};_.Ce=function(a){for(var b;b=a.firstChild;)a.removeChild(b)};_.De=function(a){return _.mb(a)&&1==a.nodeType};_.Ee=function(a){return 9==a.nodeType?a:a.ownerDocument||a.document};_.Fe=function(a,b){for(var c=0;a;){if(b(a))return a;a=a.parentNode;c++}return null};
#
# }catch(e){_._DumpException(e)}
# try{
# _.Gj=function(a){_.G.call(this,a)};_.w(_.Gj,_.G);
#
# }catch(e){_._DumpException(e)}
# try{
# _.Hj=function(a,b,c){a.rel=c;-1!=c.toLowerCase().indexOf("stylesheet")?(a.href=_.Uc(b),(b=_.rd(a.ownerDocument&&a.ownerDocument.defaultView))&&a.setAttribute("nonce",b)):a.href=b instanceof _.Sc?_.Uc(b):b instanceof _.Wc?_.Xc(b):_.Xc(_.bd(b))};
#
# }catch(e){_._DumpException(e)}
# try{
# /*
#
#  SPDX-License-Identifier: Apache-2.0
# */
# var Ij;try{new URL("s://g"),Ij=!0}catch(a){Ij=!1}_.Jj=Ij;
#
# }catch(e){_._DumpException(e)}
# try{
# _.Kj=function(a){var b,c,d=null==(c=(b=(a.ownerDocument&&a.ownerDocument.defaultView||window).document).querySelector)?void 0:c.call(b,"script[nonce]");(b=d?d.nonce||d.getAttribute("nonce")||"":"")&&a.setAttribute("nonce",b)};_.Lj=function(a){var b=_.Qc();a=b?b.createScriptURL(a):a;return new _.Sc(a,_.Rc)};
# /*
#
#  SPDX-License-Identifier: Apache-2.0
# */
#
# }catch(e){_._DumpException(e)}
# try{
# var Mj=function(a,b,c){_.ae.log(46,{att:a,max:b,url:c})},Oj=function(a,b,c){_.ae.log(47,{att:a,max:b,url:c});a<b?Nj(a+1,b):_.J.log(Error("ha`"+a+"`"+b),{url:c})},Nj=function(a,b){if(Pj){var c=_.Be("SCRIPT");c.async=!0;c.type="text/javascript";c.charset="UTF-8";c.src=_.Tc(Pj);_.Kj(c);c.onload=_.se(Mj,a,b,c.src);c.onerror=_.se(Oj,a,b,c.src);_.ae.log(45,{att:a,max:b,url:c.src});_.ve("HEAD")[0].appendChild(c)}},Qj=function(a){_.G.call(this,a)};_.w(Qj,_.G);
# var Rj=_.F(_.Xd,Qj,17)||new Qj,Sj,Pj=(Sj=_.F(Rj,_.Gj,1))?_.Lj(_.D(Sj,4)||""):null,Tj,Uj=(Tj=_.F(Rj,_.Gj,2))?_.Lj(_.D(Tj,4)||""):null,Vj=function(){Nj(1,2);if(Uj){var a=_.Be("LINK");a.setAttribute("type","text/css");_.Hj(a,Uj,"stylesheet");var b=_.rd();b&&a.setAttribute("nonce",b);_.ve("HEAD")[0].appendChild(a)}};
# (function(){var a=_.Yd();if(_.E(a,18))Vj();else{var b=_.D(a,19)||0;window.addEventListener("load",function(){window.setTimeout(Vj,b)})}})();
#
# }catch(e){_._DumpException(e)}
# })(this.gbar_);
# // Google Inc.
#
# .gTMtLb{z-index:1001;position:absolute;top:-1000px}
#
#
#
# Google apps

# %% [markdown]
# # test Selenium

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import ChromiumOptions
options = ChromiumOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
# options.add_argument('--headless')
# options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

driver = webdriver.Chrome('../chromedriver', options=options)
driver.execute_cdp_cmd("Page.addScriptToEvaluateOnNewDocument", {
    "source": "Object.defineProperty(navigator, 'webdriver', {get: () => undefined})"
})
# Out:
# [autoreload of TwitterSearch failed: Traceback (most recent call last):
#   File "/mnt/d/prog/anaconda3/envs/res/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/mnt/d/prog/anaconda3/envs/res/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/mnt/d/prog/anaconda3/envs/res/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/mnt/d/prog/anaconda3/envs/res/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
#   File "<frozen importlib._bootstrap_external>", line 791, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/hermione/src/research/ai-scholar-toolbox/TwitterSearch.py", line 48
#     elif str_type == 'gs_url':
#     ^
# IndentationError: expected an indented block
# ]
# /mnt/d/prog/anaconda3/envs/res/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   # Remove the CWD from sys.path while we load stuff.
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# /tmp/ipykernel_2149/1184067846.py in <module>
#       8 options.add_argument('--disable-dev-shm-usage')
#       9
# ---> 10 driver = webdriver.Chrome('../chromedriver', options=options)
#      11 driver.execute_cdp_cmd("Page.addScriptToEvaluateOnNewDocument", {
#      12     "source": "Object.defineProperty(navigator, 'webdriver', {get: () => undefined})"
#
# /mnt/d/prog/anaconda3/envs/res/lib/python3.7/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      70                          port, options,
#      71                          service_args, desired_capabilities,
# ---> 72                          service_log_path, service, keep_alive)
#
# /mnt/d/prog/anaconda3/envs/res/lib/python3.7/site-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      95                     browser_name=browser_name, vendor_prefix=vendor_prefix,
#      96                     keep_alive=keep_alive, ignore_proxy=_ignore_proxy),
# ---> 97                 options=options)
#      98         except Exception:
#      99             self.quit()
#
# /mnt/d/prog/anaconda3/envs/res/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     275         self._authenticator_id = None
#     276         self.start_client()
# --> 277         self.start_session(capabilities, browser_profile)
#     278
#     279     def __repr__(self):
#
# /mnt/d/prog/anaconda3/envs/res/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in start_session(self, capabilities, browser_profile)
#     368         w3c_caps = _make_w3c_caps(capabilities)
#     369         parameters = {"capabilities": w3c_caps}
# --> 370         response = self.execute(Command.NEW_SESSION, parameters)
#     371         if 'sessionId' not in response:
#     372             response = response['value']
#
# /mnt/d/prog/anaconda3/envs/res/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     433         response = self.command_executor.execute(driver_command, params)
#     434         if response:
# --> 435             self.error_handler.check_response(response)
#     436             response['value'] = self._unwrap_value(
#     437                 response.get('value', None))
#
# /mnt/d/prog/anaconda3/envs/res/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: unknown error: DevToolsActivePort file doesn't exist
# Stacktrace:
# #0 0x563a84bd3cd3 <unknown>
# #1 0x563a849db968 <unknown>
# #2 0x563a84a02e92 <unknown>
# #3 0x563a849ff370 <unknown>
# #4 0x563a849fb8fa <unknown>
# #5 0x563a84a3694a <unknown>
# #6 0x563a84a30aa3 <unknown>
# #7 0x563a84a063fa <unknown>
# #8 0x563a84a07555 <unknown>
# #9 0x563a84c1b2bd <unknown>
# #10 0x563a84c1f418 <unknown>
# #11 0x563a84c0536e <unknown>
# #12 0x563a84c20078 <unknown>
# #13 0x563a84bf9bb0 <unknown>
# #14 0x563a84c3cd58 <unknown>
# #15 0x563a84c3ced8 <unknown>
# #16 0x563a84c56cfd <unknown>
# #17 0x7f40dee47609 <unknown>

# %%
driver.get('http://zive.info/')
page = driver.page_source
soup = BeautifulSoup(page)

# %%
soup
# Out:
# <html><head><title>** zive.info **</title><meta content="" name="description"/><meta content="" name="keywords"/></head><frameset border="0" rows="100%,*"><frame frameborder="0" src="http://web.media.mit.edu/~zive/"/></frameset></html>

# %%
tmp_all = driver.find_elements(By.TAG_NAME, 'a')

# %%
tmp_all
# Out:
# []

# %%
driver.find_elements(By.CLASS_NAME, 'item')
# Out:
# []

# %%
for item in tmp_all:
    print(item.get_attribute('href'))
